# %% [markdown]
# <a href="https://colab.research.google.com/github/shhuangmust/AI/blob/110-2/14.n_grams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # N-Grams
# - 了解單一字詞表示方式，接下來則是語言模型的表示。語言模型是由"字詞/字句"所構成，所以要透過組合單一字詞成為其他有意義的"字詞/字句"
# - 組合的過程稱之為n-grams，單一字詞為1-gram，兩個字詞組成有意義的"字詞/字句"稱之為2-grams，依此類推
# - 本範例利用情緒分析範例，示範如何把評論詞切成n-grams的前處理過程
# - 前處理過程包含：1. 去除標點符號(punctuation) 2. 去除停用詞(stopwords，無意義之詞，例如"的"、"了"...之類)
# - 接下來產生單字詞unigram，雙字詞bigram，三字詞trigram

# %% [markdown]
# **SENTIMENT ANALYSIS FOR FINANCIAL NEWS FROM THE PERSPECTIVE OF A RETIAL INVESTOR**
#
# **->3 categories:**
#
#
# -positive
#
# -negative
#
# -neutral
#
# DATASET:
#
# https://www.kaggle.com/ankurzing/sentiment-analysis-for-financial-news

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

plt.style.use(style='seaborn')
# %matplotlib inline

# %%
df=pd.read_csv('all-data.csv',encoding = "ISO-8859-1", header=None, names = ['Sentiment', 'News Headline'])
df.head()
# Out:
#   Sentiment                                      News Headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sentiment      4846 non-null   object
#  1   News Headline  4846 non-null   object
# dtypes: object(2)
# memory usage: 75.8+ KB

# %%
df.isna().sum()
# Out:
# Sentiment        0
# News Headline    0
# dtype: int64

# %%
df['Sentiment'].value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: Sentiment, dtype: int64

# %% [markdown]
# **Feature extraction**

# %%
y=df['Sentiment'].values
y.shape
# Out:
# (4846,)

# %%
x=df['News Headline'].values
x.shape
# Out:
# (4846,)

# %% [markdown]
# **Train-test split**

# %%
from sklearn.model_selection import train_test_split

# %%
(x_train,x_test,y_train,y_test)=train_test_split(x,y,test_size=0.4)

# %%
x_train.shape
# Out:
# (2907,)

# %%
y_train.shape
# Out:
# (2907,)

# %%
x_test.shape
# Out:
# (1939,)

# %%
y_test.shape
# Out:
# (1939,)

# %%
x_train
# Out:
# array(["It will also strengthen Ruukki 's offshore business .",
#        "Efore 's results for the last quarter showed an even faster improvement as the company managed to better source its components .",
#        "The new location is n't the only change Wellmont has in store for its air transport service .",
#        ...,
#        "For the fiscal year ending September 30 , 2009 the revenue from these customers was $ 10.012 million or around 11.0 % of the transportation group 's revenue .",
#        'The veneer and plywood industry in Sweden is quite small despite the raw material resources .',
#        'According to Scanfil , demand for telecommunications network products has fluctuated significantly in the third quarter of 2006 , and the situation is expected to remain unstable for the rest of the year .'],
#       dtype=object)

# %%
df1=pd.DataFrame(x_train)
df1=df1.rename(columns={0:'news'})

df2=pd.DataFrame(y_train)
df2=df2.rename(columns={0:'sentiment'})
df_train=pd.concat([df1,df2],axis=1)

df_train.head()
# Out:
#                                                 news sentiment
# 0  It will also strengthen Ruukki 's offshore bus...  positive
# 1  Efore 's results for the last quarter showed a...  positive
# 2  The new location is n't the only change Wellmo...   neutral
# 3  In parallel , TeliaSonera has decided to condu...   neutral
# 4  Ruukki Romania , the local arm of Finnish meta...  positive

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   news       2907 non-null   object
#  1   sentiment  2907 non-null   object
# dtypes: object(2)
# memory usage: 45.5+ KB

# %%
df3=pd.DataFrame(x_test)
df3=df3.rename(columns={0:'news'})

df4=pd.DataFrame(y_test)
df4=df2.rename(columns={0:'sentiment'})
df_test=pd.concat([df3,df4],axis=1)

df_test.head()
# Out:
#                                                 news sentiment
# 0          The company website is www.ahlstrom.com .  positive
# 1  The Finland-based company says it will move in...  positive
# 2  Small investors have voiced fears that the sha...   neutral
# 3  The company 's goal is to achieve annual savin...   neutral
# 4               No financial details were reported .  positive

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   news       1939 non-null   object
#  1   sentiment  2907 non-null   object
# dtypes: object(2)
# memory usage: 45.5+ KB

# %% [markdown]
# **Pre-processing**

# %%
#removing punctuations
#library that contains punctuation
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
  if(type(text)==float):
    return text
  ans=""  
  for i in text:     
    if i not in string.punctuation:
      ans+=i    
  return ans

#storing the puntuation free text in a new column called clean_msg
df_train['news']= df_train['news'].apply(lambda x:remove_punctuation(x))
df_test['news']= df_test['news'].apply(lambda x:remove_punctuation(x))

# %%
df_train.head()
#punctuations are removed from news column in train dataset
# Out:
#                                                 news sentiment
# 0  It will also strengthen Ruukki s offshore busi...  positive
# 1  Efore s results for the last quarter showed an...  positive
# 2  The new location is nt the only change Wellmon...   neutral
# 3  In parallel  TeliaSonera has decided to conduc...   neutral
# 4  Ruukki Romania  the local arm of Finnish metal...  positive

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#method to generate n-grams:
#params:
#text-the text for which we have to generate n-grams
#ngram-number of grams to be generated from the text(1,2,3,4 etc., default value=1)


def generate_N_grams(text,ngram=1):
  words=[word for word in text.split(" ") if word not in set(stopwords.words('english'))]  
  print("Sentence after removing stopwords:",words)
  temp=zip(*[words[i:] for i in range(0,ngram)])
  ans=[' '.join(ngram) for ngram in temp]
  return ans

# %%
#sample!
generate_N_grams("The sun rises in the east",3)
# Out:
# Sentence after removing stopwords: ['The', 'sun', 'rises', 'east']
# ['The sun rises', 'sun rises east']

# %% [markdown]
# **Create unigrams**

# %%
from collections import defaultdict

# %%
positiveValues=defaultdict(int)
negativeValues=defaultdict(int)
neutralValues=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text):
    positiveValues[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text):
    negativeValues[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text):
    neutralValues[word]+=1
# Out:
# Sentence after removing stopwords: ['It', 'also', 'strengthen', 'Ruukki', 'offshore', 'business', '']
# Sentence after removing stopwords: ['Efore', 'results', 'last', 'quarter', 'showed', 'even', 'faster', 'improvement', 'company', 'managed', 'better', 'source', 'components', '']
# Sentence after removing stopwords: ['Ruukki', 'Romania', '', 'local', 'arm', 'Finnish', 'metal', 'producer', 'Ruukki', '', 'increased', 'capital', '900000', 'euro', '', '', '114', 'mln', '', 'cash', 'contribution', '', 'reported', 'September', '19', '', '2006', '']
# Sentence after removing stopwords: ['The', 'representative', 'body', 'Swedish', 'Meats', 'approved', 'improved', 'offer', 'Finnish', 'HK', 'Ruokatalo', 'acquire', 'company', '']
# Sentence after removing stopwords: ['In', 'third', 'quarter', '2010', '', 'net', 'sales', 'increased', '52', '', 'EUR', '2055', 'mn', '', 'operating', 'profit', '349', '', 'EUR', '235', 'mn', '']
# Sentence after removing stopwords: ['Our', 'superior', 'customer', 'centricity', 'expertise', 'digital', 'services', 'set', 'us', 'apart', 'competitors', '']
# Sentence after removing stopwords: ['This', 'much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'Finland', 'Canada', '']
# Sentence after removing stopwords: ['Finnish', 'lifting', 'equipment', 'maker', 'Konecranes', 'Oyj', 'said', 'July', '30', '', '2008', 'net', 'profit', 'rose', '712', 'mln', 'euro', '', '', '1111', 'mln', '', 'first', 'half', '2008', '571', 'mln', 'euro', '', '', '891', 'mln', '', 'period', '2007', '']
# Sentence after removing stopwords: ['Both', 'net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history', '']
# Sentence after removing stopwords: ['The', 'estimated', 'synergy', 'benefits', 'least', 'EUR7m', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'Swedish', 'construction', 'markets', 'still', 'experiencing', 'estimated', '4', '', 'annual', 'growth', '2008', '']
# Sentence after removing stopwords: ['Besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', '', '', 'Paavel', 'said', '']
# Sentence after removing stopwords: ['', 'Very', 'recommendable', '', 'Nokian', 'Z', 'G2', 'according', '', 'ADAC', 'judgement', '', 'latest', 'summer', 'tyre', 'test', 'German', 'automobile', 'association', 'ADAC', '']
# Sentence after removing stopwords: ['Sales', 'rose', '10', 'pct', '566', 'mln', 'eur', 'back', 'strong', 'volume', 'favourable', 'currency', 'effects', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'company', 'operating', 'profit', 'grew', '432', '', 'EUR', '6', 'million', '']
# Sentence after removing stopwords: ['Finland', 'Neste', 'Oil', 'awarded', 'Chemical', 'Industry', 'Federation', 'Finland', 'Innovation', 'Award', 'NExBTL', 'technology', '', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat', '']
# Sentence after removing stopwords: ['SRV', 'raise', 'holding', 'company', 'summer', '2008', '', 'majority', '']
# Sentence after removing stopwords: ['Rautaruukki', 'Corporation', 'Stock', 'exchange', 'release', '3', 'December', '2009', '12', 'noon', 'Ruukki', 'construction', 'engineering', 'divisions', 'improve', 'adjust', 'operations', 'Finland', '']
# Sentence after removing stopwords: ['Jens', 'SchulteBockum', '', 'Vodafone', 'global', 'director', 'terminals', '', 'said', 'company', 'expects', 'sell', 'one', 'two', 'million', 'Vodafone', '125', '225', 'models', 'first', 'year', 'launch', '', 'potentially', 'tens', 'millions', 'lifetime', 'device', '']
# Sentence after removing stopwords: ['Finnishowned', 'contract', 'manufacturer', 'electronics', 'Elcoteq', 'Hungary', 'Kft', 'announced', 'plans', 'recruit', '650', 'new', 'staffers', 'fulfill', 'new', 'orders', 'Pcs', '', 'company', 'two', 'plants', '']
# Sentence after removing stopwords: ['The', 'Australian', 'company', 'Mirabela', 'Nickel', 'awarded', 'Outokumpu', 'Technology', 'contract', 'grinding', 'technology', 'nickel', 'sulfide', 'project', 'Bahia', 'State', '', 'Brazil', '']
# Sentence after removing stopwords: ['', 'Consumers', 'well', 'received', 'packed', 'fresh', 'meat', '']
# Sentence after removing stopwords: ['Fiskars', 'strong', 'portfolio', 'international', 'brands', '', 'include', 'Fiskars', '', 'Iittala', '', 'Gerber', '', 'Silva', 'Buster', '']
# Sentence after removing stopwords: ['Nokia', 'Elisa', 'work', 'together', 'bring', 'superior', 'mobile', 'gaming', 'experience', 'Elisa', 'customers', '']
# Sentence after removing stopwords: ['The', 'company', 'established', '3G', 'base', 'station', '17000', 'feet', 'foot', 'Mount', 'Everest', 'enable', 'mountain', 'climbers', '29035foot', 'summit', 'surf', 'Internet', 'even', 'send', 'videos', 'exploits', '']
# Sentence after removing stopwords: ['Finnish', 'Outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'OZK', 'Kardzhali', 'zinc', 'smelter', 'Bulgaria', '']
# Sentence after removing stopwords: ['A', 'Helsinki', '', 'ELIiV', 'today', 'reported', 'EPS', 'EUR1', '13', '2009', '', 'increase', 'EPS', 'EUR1', '12', '2008', '']
# Sentence after removing stopwords: ['Q1', '2010', '18', 'May', '2010', '', 'Finnish', 'electrical', 'components', 'maker', 'Salcomp', 'Oy', '', 'HEL', '', 'SAL1V', '', 'said', 'today', 'turned', 'net', 'profit', 'EUR1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'EUR2m', 'corresponding', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['In', 'JanuarySeptember', '2010', '', 'Fiskars', '', 'net', 'profit', 'went', '14', '', 'yearonyear', 'EUR', '654', 'million', 'net', 'sales', 'EUR', '5253', 'million', 'EUR', '4877', 'million', '']
# Sentence after removing stopwords: ['The', 'transaction', 'line', 'Aspo', 'strategy', 'expand', 'Baltic', 'Sea', 'region', 'eastern', 'markets', '']
# Sentence after removing stopwords: ['', 'UPMKymmene', 'upgraded', '', 'inline', '', '', 'underperform', '', 'Goldman', 'Sachs', '']
# Sentence after removing stopwords: ['The', 'Lithuanian', 'beer', 'market', 'made', '1441', 'million', 'liters', 'January', '', 'rise', '08', 'percent', 'yearearlier', 'figure', '', 'Lithuanian', 'Brewers', '', 'Association', 'reporting', 'citing', 'results', 'members', '']
# Sentence after removing stopwords: ['We', 'capitalize', 'experience', 'number', 'similar', 'bridge', 'projects', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['', 'The', 'CHF', 'great', 'product', '']
# Sentence after removing stopwords: ['The', 'group', 'expand', 'chain', 'include', '45', 'stores', '']
# Sentence after removing stopwords: ['We', 'aim', 'ensure', 'Vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', '', '', 'comments', 'Vacon', 'Plc', 'President', 'CEO', 'Vesa', 'Laisi', '']
# Sentence after removing stopwords: ['The', 'cooperation', 'double', 'The', 'Switch', 'converter', 'capacity', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', '', 'EPS', '', 'first', 'quarter', '2007', 'amounted', 'EUR0', '07', '', 'EUR0', '04', '']
# Sentence after removing stopwords: ['1', 'Block', 'lamp', 'Harri', 'Koskinen', 'light', 'introduced', '1996', 'bestseller', 'ever', 'since', '']
# Sentence after removing stopwords: ['Nordea', 'sees', 'return', 'positive', 'growth', 'Baltic', 'countries', '2011', '']
# Sentence after removing stopwords: ['3', 'January', '2011', '', 'Finnish', 'flag', 'carrier', 'Finnair', 'Oyj', '', 'HEL', '', 'FIA1S', '', 'said', 'today', 'sealed', 'nineyear', 'sale', 'leaseback', 'agreement', 'newest', 'Airbus', 'A330', 'aircraft', 'syndication', 'Japanese', 'operating', 'lease', 'market', '']
# Sentence after removing stopwords: ['Growth', 'expected', 'continue', '2008', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'guided', 'EBIT', 'sales', 'growth', '20', 'pct', '10', 'pct', 'respectively', 'year', '']
# Sentence after removing stopwords: ['The', 'program', 'target', 'structural', 'cost', 'reductions', 'EUR', '30mn', '2009', '']
# Sentence after removing stopwords: ['Revenue', 'grew', '12', 'percent', '', '', 'x20ac', '', '36', 'billion', '', 'US', '45', 'billion', '', '']
# Sentence after removing stopwords: ['', 'The', 'second', 'quarter', '2010', 'firstquarter', 'growth', 'net', 'sales', 'since', 'third', 'quarter', 'of2008', '', '', 'said', 'Magnus', 'Rosen', '', 'Ramirent', 'CEO', '']
# Sentence after removing stopwords: ['The', 'stock', 'price', 'rose', '700', 'ores', '09', '', 'close', 'SEK77', '65', '', 'ending', 'twoday', 'streak', 'losses', '']
# Sentence after removing stopwords: ['Hkan', 'Dahlstr¦m', '', 'head', 'mobility', 'services', 'TeliaSonera', '', 'forecast', 'mobile', 'data', 'volume', 'TeliaSonera', 'network', 'Sweden', 'rise', 'eightfold', '200000', 'TB', '2014', '']
# Sentence after removing stopwords: ['Press', 'release', '9', 'October', '2009', 'Ruukki', 'signed', 'contract', 'deliver', 'install', 'steel', 'structures', 'bridge', 'Kyronsalmi', 'strait', 'Savonlinna', '', 'Finland', '']
# Sentence after removing stopwords: ['Finland', 'leading', 'metals', 'group', 'Outokumpu', 'said', 'fourthquarter', 'net', 'profit', 'tripled', 'back', 'strong', 'global', 'demand', 'stainless', 'steel', '', 'soaring', 'base', 'metal', 'prices', 'proceeds', 'sale', 'technology', 'unit', '']
# Sentence after removing stopwords: ['Previously', '', 'EB', 'delivered', 'custom', 'solution', 'LG', 'Electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators', '']
# Sentence after removing stopwords: ['Finnish', 'telecoms', 'software', 'developer', 'Tecnomen', 'Oyj', 'said', 'December', '5', '', '2006', '', '33', 'mln', '', '25', 'mln', 'euro', '', 'order', 'supply', 'expansion', 'charging', 'messaging', 'systems', 'mobile', 'fixed', 'networks', 'Brasil', 'Telecom', '']
# Sentence after removing stopwords: ['Kesko', 'pursues', 'strategy', 'healthy', '', 'focused', 'growth', 'concentrating', 'sales', 'services', 'consumercustomers', '']
# Sentence after removing stopwords: ['Ixonos', 'estimates', 'hire', '20', 'specialists', 'mechanical', 'engineering', '', 'electronics', 'design', '', 'RD', 'new', 'unit', 'Jyvaeskylae', 'end', '2009', '']
# Sentence after removing stopwords: ['', 'Our', 'customer', 'satisfied', 'Basware', 'Invoice', 'Automation', 'solution', 'extends', 'implementation', 'new', 'geographies', '']
# Sentence after removing stopwords: ['Salo', '', 'Finland', '', '29', 'August', '2006', '', 'Benefon', 'today', 'announced', 'plans', 'strengthen', 'inhouse', 'technology', 'platform', '', 'licensing', 'complete', 'mobile', 'software', 'platform', '', 'Opna', '', 'longstanding', 'technology', 'partner', '', 'Pollex', '']
# Sentence after removing stopwords: ['Profit', 'per', 'share', 'EUR', '103', '', 'EUR', '087', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Retail', 'wholesale', 'group', 'Kesko', 'reported', 'net', 'sales', '6594', 'mln', 'eur', 'February', '', 'increase', '108', 'pct', 'yearonyear', '']
# Sentence after removing stopwords: ['', 'We', 'pleased', 'working', 'Fujitsu', 'NTT', 'DoCoMo', 'advance', 'progress', 'LTE', '', '', 'said', 'Juergen', 'Walter', '', 'Head', 'Converged', 'Core', '', 'Nokia', 'Siemens', 'Networks', '']
# Sentence after removing stopwords: ['SINGAPORE', '', 'ICIS', '', '', '', '1', '', 'Kemira', 'Indian', 'water', 'infrastructure', 'firm', '', '2', '', 'IVRCL', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'Andhra', 'Pradesh', 'state', '', 'India', '', 'Finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'Tuesday', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'totalled', 'EUR', '20', 'mn', '', 'compared', 'loss', 'EUR', '1592', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['London', 'leading', 'shares', 'today', 'jumped', 'almost', '100', 'points', '', '17', '', '', 'market', 'opened', '']
# Sentence after removing stopwords: ['Net', 'sales', 'increased', 'EUR193', '3', 'EUR179', '9', 'pretax', 'profit', 'rose', '342', '', 'EUR43', '1', '', 'EUR1', '', 'USD1', '4', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['A', 'new', 'production', 'line', 'completed', 'contract', 'production', 'hormone', 'treatments', '']
# Sentence after removing stopwords: ['Kaupthing', 'forecasts', 'significant', 'price', 'increase', 'printing', 'paper', '2007', '']
# Sentence after removing stopwords: ['Rautaruukki', 'said', 'construction', 'group', 'YIT', 'awarded', '25', 'mln', 'eur', 'contract', 'supply', 'steel', 'structures', 'new', 'bridge', 'spanning', 'Kemijoki', 'river', 'Northern', 'Finland', '']
# Sentence after removing stopwords: ['When', 'open', 'next', 'year', '', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat', '']
# Sentence after removing stopwords: ['It', 'also', 'strong', 'assets', 'electronic', 'media', '', 'employing', '18500', 'increase', '9', 'percent', 'last', 'year', '']
# Sentence after removing stopwords: ['These', 'companies', 'able', 'keep', 'market', 'positions', '']
# Sentence after removing stopwords: ['A', 'memorandum', 'understanding', 'cooperation', 'Finnish', 'Global', 'Chemical', 'Company', 'KEMIRA', 'Vietnam', 'National', 'Chemicals', 'Group', '', 'Vinachem', '', 'signed', 'occasion', '']
# Sentence after removing stopwords: ['Furthermore', '', 'Bunge', 'also', 'sign', 'licensing', 'agreement', 'Sunnuntai', 'Carlshamn', 'Mejeri', 'brands', '']
# Sentence after removing stopwords: ['', 'IH', '', 'move', 'enhance', 'growth', '']
# Sentence after removing stopwords: ['Q1', '10', '19', 'April', '2010', '', 'Finnish', 'forest', 'machinery', 'equipment', 'maker', 'Ponsse', 'Oyj', 'HEL', '', 'PON1V', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'EUR6', '3', 'first', 'quarter', '2010', '', 'EUR9', '6', 'loss', 'year', 'earlier', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['Also', '', 'bringing', '', 'right', 'kind', 'people', '', 'upgrade', 'human', 'resources', '']
# Sentence after removing stopwords: ['In', 'release', '', 'Company', 'said', 'Vocollect', 'T2', 'customers', 'North', 'America', 'take', 'advantage', 'Voice', 'Directed', 'Warehousing', 'solution', 'increase', 'warehouse', 'efficiency', 'productivity', 'gains', 'discounted', 'price', '']
# Sentence after removing stopwords: ['Olvi', '', 'controls', '94', 'percent', 'stake', 'Ragutis', 'A', 'Le', 'Coq', '', 'said', 'annual', 'report', 'published', 'earlier', 'year', 'Lithuanian', 'brewery', 'sales', 'reached', '1504', 'million', 'euros', 'last', 'year', '', 'rise', '204', 'percent', '1249', 'million', 'euros', '2004', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['In', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'loss', 'narrowed', 'EUR', '415000', 'EUR', '74', 'million', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['The', 'District', 'Court', 'Helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005', '']
# Sentence after removing stopwords: ['EPS', 'continuing', 'operations', 'came', '030', 'eur', '', '017', '']
# Sentence after removing stopwords: ['Production', 'expand', 'Elcoteq', 'locations', 'including', 'Mexico', 'Hungary', '2010', '']
# Sentence after removing stopwords: ['Advertising', 'circulation', 'revenues', 'grew', '34', '', '04', '', '', 'respectively', '']
# Sentence after removing stopwords: ['It', 'solid', 'credit', 'compared', 'DZ', 'Bank', 'Rabobank', '']
# Sentence after removing stopwords: ['The', 'longstanding', 'partnership', 'commitment', 'enable', 'parties', 'develop', 'respective', 'operations', '', 'ESL', 'Shipping', 'also', 'opportunity', 'update', 'fleet', 'improve', 'efficiency', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Metso', 'said', 'upgrade', 'one', 'UPMKymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'Jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', '', 'machine', 'process', 'controls', 'quality', 'measurements', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'net', 'sales', 'rose', '8', '', 'yearonyear', 'EUR64', '3', '', 'due', 'business', 'acquisitions', 'realized', 'first', 'half', '200809', '', 'effect', 'EUR10', '9', 'review', 'period', '']
# Sentence after removing stopwords: ['Exports', 'grew', '165', 'percent', '191', 'million', 'liters', '']
# Sentence after removing stopwords: ['', 'The', 'lowering', 'prices', 'us', 'competitors', 'shows', 'real', 'estate', 'market', 'stabilised', 'returned', 'balance', 'apartments', 'acquiring', 'fair', 'price', 'eyes', 'clients', '']
# Sentence after removing stopwords: ['Sales', 'Latin', 'America', 'increased', '42', '', 'EUR', '432mn', '', 'total', '87', 'mn', 'mobile', 'devices', 'sold', 'area', '', 'representing', 'increase', '32', '', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'supply', 'WCDMA', '3GHSPA', 'radio', 'network', '', 'including', 'modular', '', 'high', 'capacity', 'Nokia', 'Flexi', 'WCDMA', 'base', 'station', 'East', 'Java', '', 'Bali', '', 'Sumatra', 'Batam', '']
# Sentence after removing stopwords: ['In', 'first', 'quarter', '2010', '', 'marktomarket', 'result', 'pretax', 'profit', 'EUR', '133', 'million', 'versus', 'loss', 'EUR', '32', 'million', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', '', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'Klabin', 'Tel\x97maco', 'Borba', 'mill', 'Brazilian', 'state', 'Paranè', '']
# Sentence after removing stopwords: ['Our', 'standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'Itella', '']
# Sentence after removing stopwords: ['Finnair', 'PLC', 'carried', 'record', '88', 'million', 'passengers', '2006', '', 'increase', '35', 'percent', 'previous', 'year', '', 'Finnish', 'national', 'carrier', 'reported', 'Tuesday', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', 'EPS', 'amounted', 'EUR0', '03', '', 'loss', 'EUR0', '08', '']
# Sentence after removing stopwords: ['Orion', 'Pharma', 'operating', 'profit', 'increased', '425', '', '2004', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Dec', '11', '', '2008', '', 'Finnish', 'construction', 'engineering', 'company', 'Outotec', 'Oyj', '', 'OMX', '', 'OTE1V', '', 'said', 'today', 'EUR', '28', 'million', '', 'USD', '368', '', 'order', 'expand', 'phosphate', 'concentrator', 'Siilinjarvi', 'Norwegian', 'minera']
# Sentence after removing stopwords: ['By', 'cutting', 'number', 'plants', '', 'group', 'trim', 'fixed', 'costs', '']
# Sentence after removing stopwords: ['KESKO', 'FOOD', 'LTD', 'PRESS', 'RELEASE', '04012006', 'AT', '1300', 'Kesko', 'Food', 'Ltd', 'launching', 'major', 'TV', 'campaign', 'recruit', 'many', 'one', 'hundred', 'new', 'Kfood', 'retailers', '']
# Sentence after removing stopwords: ['Estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'margin', 'increased', '112', '', '117', '', '']
# Sentence after removing stopwords: ['Cash', 'flow', 'operations', 'totalled', 'EUR', '74', 'mn', '', 'compared', 'negative', 'EUR', '686', 'mn', 'second', 'quarter', '2008', '']
# Sentence after removing stopwords: ['In', 'addition', '', 'Kone', 'signed', 'twoyear', 'maintenance', 'contract', 'escalators', '']
# Sentence after removing stopwords: ['Finnish', 'elevators', 'escalators', 'maker', 'KONE', 'Corporation', 'said', 'Tuesday', '', '18', 'March', '', 'received', 'major', 'order', 'Sir', 'Robert', 'McAlpine', 'supply', 'elevators', 'escalators', 'Watermark', 'Place', 'project', 'City', 'London', '']
# Sentence after removing stopwords: ['UPMKymmene', 'generated', 'thirtyone', 'consecutive', 'quarters', 'positive', 'EBITDA', '']
# Sentence after removing stopwords: ['Mr', 'Priit', 'Kasak', '', 'Balti', 'Metsamasina', 'owner', '', 'said', 'Rakverebased', 'company', 'wishes', 'increase', 'Valmet', 'market', 'share', '27', '', 'third', 'couple', 'years', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'thirdquarter', 'pretax', 'profit', 'doubled', 'EUR', '197mn', '']
# Sentence after removing stopwords: ['narrows', 'EUR2', '8', '9mo', '09', '29', 'October', '2009', '', 'Finnish', 'software', 'hardware', 'developer', 'Elektrobit', 'Oyj', 'HEL', '', 'EBG1V', '', 'EB', '', 'said', 'today', 'net', 'loss', 'narrowed', 'EUR2', '8', 'first', 'nine', 'months', '2009', 'EUR35', '6', 'period', 'year', 'ago', '']
# Sentence after removing stopwords: ['Tim', 'Cockroft', 'brings', 'excellent', 'track', 'record', '18', 'years', 'experience', '', 'moreover', '', 'Tim', 'successfully', 'developed', 'Capital', 'Markets', 'operations', 'Kaupthing', 'Singer', '', 'Friedlander', 'involving', 'corporate', 'finance', 'broking', 'focus', 'midmarket', 'companies', '']
# Sentence after removing stopwords: ['The', 'company', 'net', 'profit', 'amounted', 'EE', '555', 'mn', '', '36', '', '2004', '']
# Sentence after removing stopwords: ['VDW', 'combined', 'LXE', 'devices', 'enhances', 'productivity', '', 'enabling', 'workers', 'use', 'single', 'device', 'perform', 'voice', '', 'scanning', 'keyboard', 'functions', '']
# Sentence after removing stopwords: ['The', 'longterm', 'contract', 'global', '']
# Sentence after removing stopwords: ['In', 'Homeware', 'area', '', 'Fiskars', 'provides', 'leading', 'branded', 'products', 'home', '', 'kitchen', '', 'interior', 'design', '']
# Sentence after removing stopwords: ['The', 'loss', 'third', 'quarter', '2007', 'EUR', '03', 'mn', 'smaller', 'loss', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'airline', 'Finnair', 'deal', 'UK', 'public', 'sector', 'official', 'airline', 'flights', 'London', 'Heathrow', 'Osaka', 'Japan', '', 'well', 'flights', 'Manchester', 'UK', 'Helsinki', 'Finland', '']
# Sentence after removing stopwords: ['Finnish', 'Ahlstrom', 'Corporation', 'double', 'investments', 'new', 'specialty', 'glassfiber', 'reinforcement', 'plant', 'South', 'Carolina', '', 'US', '']
# Sentence after removing stopwords: ['Speaking', 'justdrinks', 'today', '', 'spokesperson', 'Olvi', 'said', '', '', 'We', 'performed', 'well', 'four', 'countries', 'operate', '', 'namely', '', 'Finland', '', 'Estonia', '', 'Latvia', 'Lithuania', '', '']
# Sentence after removing stopwords: ['The', 'company', 'strength', 'Apetit', 'brand', '']
# Sentence after removing stopwords: ['Both', 'loans', 'used', 'finance', 'strategic', 'investments', 'shopping', 'center', 'redevelopment', 'projects', 'refinancing', 'maturing', 'debt', '']
# Sentence after removing stopwords: ['In', 'fourth', 'quarter', '2009', '', 'Atria', 'net', 'loss', 'shrank', 'EUR', '12', 'million', 'EUR', '59', 'million', 'net', 'sales', 'contracted', 'EUR', '3404', 'million', 'EUR', '3611', 'million', '']
# Sentence after removing stopwords: ['European', 'traffic', 'grew', 'nearly', '30', '', '']
# Sentence after removing stopwords: ['The', 'CL51', 'designed', 'measure', 'cloud', 'base', 'height', 'vertical', 'visibility', 'weather', 'conditions', '', 'makes', 'ideal', 'instrument', 'meteorological', 'applications', 'rely', 'reliable', 'cloud', 'height', 'detection', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '1034', 'mn', 'EUR', '232', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Nokian', 'Tyres', 'reported', 'fourth', 'quarter', 'pretax', 'profit', '615', 'mln', 'eur', '', '486', 'mln', 'back', 'strong', 'sales', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'increased', '45', '', 'EUR', '314', 'mn', 'EUR', '300', 'mn', '2004', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'Nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout', '']
# Sentence after removing stopwords: ['Atria', 'Group', 'leading', 'Scandinavian', 'meat', 'products', 'group', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'accounts', '50', '', 'poultry', 'sales', 'Finland', '', 'profitability', 'good', 'level', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'property', 'portfolio', 'doubled', 'result', 'Kapiteeli', 'acquisition', 'totalled', 'EUR', '26862', '12597', 'million', '']
# Sentence after removing stopwords: ['Finland', 'Poyry', 'Energy', 'contract', 'advise', 'builders', 'new', 'cogeneration', 'power', 'plant', 'Lithuania', 'secondbiggest', 'city', 'Kaunas', 'supervise', 'construction', 'process', '']
# Sentence after removing stopwords: ['Finnair', 'expands', '', 'Finnair', 'plans', 'add', 'flights', 'routes', 'Hong', 'Kong', '', 'India', 'Russia', '']
# Sentence after removing stopwords: ['One', 'installed', 'elevators', 'doubledeck', 'elevator', '', 'enables', 'efficient', 'use', 'building', 'core', 'space', '']
# Sentence after removing stopwords: ['According', 'company', '', 'operating', 'profit', '', 'excluding', 'nonrecurring', 'items', '', 'fourth', 'quarter', '2009', 'significantly', 'better', 'expected', '', 'also', 'better', 'figures', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', '', 'buy', '', 'recommendation', 'reiterated', '']
# Sentence after removing stopwords: ['Other', 'carriers', 'handset', 'makers', 'spin', 'positive', 'event', 'raise', 'interest', 'higherend', 'phones', 'pricier', 'data', 'plans', '']
# Sentence after removing stopwords: ['The', 'Ministry', 'Water', 'Tanzania', 'awarded', 'Poyry', 'water', 'sanitation', 'engineering', 'assignment', 'rehabilitation', 'extension', 'water', 'supply', 'sanitation', 'infrastructure', 'Bukoba', 'Musoma', '', 'situated', 'Lake', 'Victoria', 'northern', 'Tanzania', '']
# Sentence after removing stopwords: ['Dubbed', 'Nokia', 'Money', 'Solutions', '', 'company', 'officials', 'say', 'initiative', 'would', 'seek', 'bridge', 'gap', 'banked', 'unbanked', 'developing', 'countries', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Eesti', '', 'retailer', 'wholesaler', 'grain', '', 'agricultural', 'warehousing', 'machinery', 'accessories', '', 'net', 'sales', '81', 'million', 'euros', '2007', '', 'increase', 'onetenth', 'preceding', 'year', '']
# Sentence after removing stopwords: ['Most', 'increase', 'net', 'sales', 'due', 'acquisition', 'Swedish', 'Silva', 'produces', 'garden', 'tools', 'boats', '']
# Sentence after removing stopwords: ['UPMKymmene', 'generated', 'seventeen', 'consecutive', 'quarters', 'positive', 'Cash', 'Flow', 'Operations', '']
# Sentence after removing stopwords: ['The', 'company', 'aims', 'maintain', 'trend', 'profitability', 'current', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'Talentum', 'reports', 'operating', 'profit', 'increased', 'EUR', '205', 'mn', '2005', 'EUR', '93', 'mn', '2004', '', 'net', 'sales', 'totaled', 'EUR', '1033', 'mn', '', 'EUR', '964', 'mn', '']
# Sentence after removing stopwords: ['After', 'takeover', '', 'Cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'Latvian', 'market', '']
# Sentence after removing stopwords: ['9', 'September', '2010', '', 'Finnish', 'stationery', 'gift', 'retailer', 'Tiimari', 'HEL', '', 'TII1V', 'said', 'today', 'net', 'sales', 'rose', '2', '', 'yearonyear', 'EUR5', '7', 'August', '2010', '', 'driven', 'growth', 'Finland', '', 'demand', 'Baltics', 'remained', 'weak', '']
# Sentence after removing stopwords: ['The', 'offer', 'represents', 'premium', '24', '', 'stock', 'closing', 'price', 'Friday', '']
# Sentence after removing stopwords: ['Finland', 'national', 'carrier', 'Finnair', 'PLC', 'carried', 'record', '85', 'million', 'passengers', '2005', '', 'increase', '45', 'percent', 'previous', 'year', '', 'airline', 'reported', 'Tuesday', '']
# Sentence after removing stopwords: ['The', 'stock', 'new', 'machines', 'reasonably', 'small', 'new', 'orders', 'bring', 'work', '']
# Sentence after removing stopwords: ['The', 'optimization', 'steel', 'components', 'heating', 'process', 'reduce', 'energy', 'consumption', '']
# Sentence after removing stopwords: ['I', 'looking', 'forward', 'contribute', 'SRV', 'success', 'competence', '', '', 'says', 'Taneli', 'Hassinen', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'insurance', 'company', 'Pohjola', 'Finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', '', 'traffic', 'safety', '']
# Sentence after removing stopwords: ['The', 'Finnish', 'group', 'anticipates', 'sales', 'gain', 'EUR42m', 'tax', 'expenses', '']
# Sentence after removing stopwords: ['We', 'pleased', 'fine', 'cooperation', 'two', 'countries', 'recent', 'times', '', 'said', '']
# Sentence after removing stopwords: ['After', 'transaction', '', 'Alma', 'Media', 'raised', 'stake', 'Talentum', '3065', '', 'shares', '3112', '', 'voting', 'rights', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['Overall', '', '50', 'percent', 'respondents', 'confident', 'security', 'banking', 'online', '']
# Sentence after removing stopwords: ['The', 'agreement', 'signed', 'Biohit', 'Healthcare', 'Ltd', '', 'UKbased', 'subsidiary', 'Biohit', 'Oyj', '', 'Finnish', 'public', 'company', 'develops', '', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'announce', 'support', 'Intel', 'based', 'handheld', 'platforms', '', 'capabilities', 'made', 'development', 'easier', 'faster', '']
# Sentence after removing stopwords: ['Ruukki', 'signed', 'contract', 'Norwegian', 'company', 'Veidekke', 'Entreprenor', 'AS', '']
# Sentence after removing stopwords: ['Compared', 'FTSE', '100', 'index', '', 'rose', '283', 'points', '05', '', 'day', '', 'relative', 'price', 'change', '23', '', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['The', 'EBITDA', 'EUR116m', 'compared', 'EUR115m', '', 'corresponding', 'EBITDA', 'margin', '33', '', '']
# Sentence after removing stopwords: ['For', 'current', 'year', '', 'Raute', 'expects', 'net', 'sales', 'increase', 'operating', 'result', '', 'positive', '']
# Sentence after removing stopwords: ['The', 'company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', '', 'adding', '', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year', '', '']
# Sentence after removing stopwords: ['The', 'company', 'operating', 'income', '', 'EBIT', '', 'totalled', 'EUR', '00', 'mn', '', 'EUR', '03', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'Kalmar', 'received', 'significant', 'order', 'US', 'Department', 'Defense', '']
# Sentence after removing stopwords: ['These', 'moderate', 'significant', 'changes', 'resulted', 'significant', '2432', '', 'reduction', 'estimated', 'CVD', 'risk', '']
# Sentence after removing stopwords: ['', 'The', 'priority', '2009', 'strengthen', 'company', 'balance', 'sheet', 'increase', 'cash', 'flow', '', '', 'CEO', 'Hannu', 'Krook', 'said', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '1019', 'mn', 'EUR', '1007', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['The', 'company', 'consolidated', 'operating', 'profit', 'amounted', 'EUR', '1586', 'mn', '', 'EUR', '414', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Turnover', 'rose', 'EUR21m', 'EUR17m', '']
# Sentence after removing stopwords: ['Diluted', 'EPS', 'rose', 'EUR3', '68', 'EUR0', '50', '']
# Sentence after removing stopwords: ['OriolaKD', 'expects', 'invoicing', '2008', 'higher', 'comparable', 'invoicing', '2007', '']
# Sentence after removing stopwords: ['CEO', 'company', 'Tarmo', 'Noop', 'said', 'growth', 'sale', 'premium', 'beers', 'biggest', '']
# Sentence after removing stopwords: ['Sales', 'climbed', '192', 'pct', '1002', 'bln', 'eur', '', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure', '']
# Sentence after removing stopwords: ['Sales', 'Department', 'Store', 'Division', 'increased', '15', '', 'sales', 'clothing', 'store', 'subsidiary', 'Seppala', 'increased', '8', '', 'Meanwhile', 'sales', 'Hobby', 'Hall', 'decreased', '12', '', '']
# Sentence after removing stopwords: ['The', 'terms', 'financing', 'approved', 'Annual', 'General', 'Meeting', 'Company', 'held', 'June', '30', '', '2010', '']
# Sentence after removing stopwords: ['', 'They', 'would', 'invest', 'physical', 'infrastructure', '', 'would', 'also', 'provide', 'knowhow', 'managing', 'developing', 'science', 'technology', 'parks', '', '', 'said', 'Sunrise', 'Valley', 'director', 'Andrius', 'Bagdonas', '']
# Sentence after removing stopwords: ['The', 'Group', 'aims', 'increase', 'net', 'sales', 'comparable', 'operating', 'profit', '2006', '']
# Sentence after removing stopwords: ['Finnish', 'food', 'company', 'Raisio', 'Oyj', 'HEL', '', 'RAIVV', 'said', 'today', 'buy', 'British', 'snacks', 'confectionery', 'company', 'Big', 'Bear', 'Group', 'plc', 'enterprise', 'value', 'EUR', '953', 'million', 'USD', '1299', '']
# Sentence after removing stopwords: ['The', 'original', 'name', 'Componenta', 'ml', '', 'subsidiary', 'Finnish', 'Componenta', 'Group', '', 'changed', 'ml', 'Components', 'company', 'seen', '63', '', 'growth', 'Q1', '2010', '', 'comparison', 'Q1', '2009', '']
# Sentence after removing stopwords: ['SysOpen', 'Digia', 'Plc', '', 'Press', 'release', '', '7', 'February', '2006', 'IBM', 'Finland', 'rewarded', 'distinguished', 'partner', 'companies', '2005', '']
# Sentence after removing stopwords: ['Under', 'terms', 'offtake', 'agreement', 'Talvivaara', '', 'Cameco', 'provide', 'upfront', 'investment', '', 'maximum', '', '60', 'million', '', 'cover', 'construction', 'cost', 'uranium', 'extraction', 'circuit', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'Kauppalehti', 'group', 'rose', 'EUR', '15', 'mn', 'EUR', '13', 'mn', '', 'Marketplaces', 'EUR', '13', 'mn', 'EUR', '10', 'mn', 'third', 'quarter', '2006', '']
# Sentence after removing stopwords: ['The', 'upgrade', 'intended', 'raise', 'network', 'capacity', '450', 'MHz', '630', 'MHz', 'several', 'cities', '', 'enabling', 'bidirectional', 'services', 'digital', 'television', 'well', 'broadband', 'data', '']
# Sentence after removing stopwords: ['Thus', 'method', 'cut', 'working', 'costs', '', 'fasten', 'planning', 'building', 'processes', '']
# Sentence after removing stopwords: ['Ragutis', '', 'controlled', 'Finnish', 'brewery', '', 'reported', '54percent', 'rise', 'beer', 'sales', '1044', 'million', 'litres', 'held', '1109percent', 'market', 'share', '']
# Sentence after removing stopwords: ['Vaisala', 'also', 'said', 'expects', 'net', 'sales', 'EUR', '2532', 'million', '2010', '', 'compared', 'EUR', '2522', 'million', 'recorded', '2009', '']
# Sentence after removing stopwords: ['Repeats', 'sees', '2008', 'EBITA', '18', 'pct', 'sales', '']
# Sentence after removing stopwords: ['Glaston', '', 'headquartered', 'Tampere', '', 'Finland', '', 'growing', '', 'international', 'glass', 'technology', 'company', '']
# Sentence after removing stopwords: ['The', 'amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'Company', '']
# Sentence after removing stopwords: ['Viking', 'Line', 'head', 'Jan', 'Kaarstroem', 'told', 'TT', 'company', 'ferries', 'well', 'equipped', 'handle', 'ice', 'passengers', 'safe', '']
# Sentence after removing stopwords: ['Diluted', 'loss', 'per', 'share', 'stood', 'EUR', '015', 'versus', 'EUR', '026', '']
# Sentence after removing stopwords: ['The', 'Basware', 'Connectivity', 'services', 'allow', 'companies', 'handle', 'purchase', 'pay', 'processes', 'online', 'make', 'internal', 'processes', 'efficient', '', '', 'said', 'CEO', 'Ilkka', 'Sihvo', '', 'Basware', 'Corporation', '']
# Sentence after removing stopwords: ['Profit', 'period', 'EUR', '156', 'mn', 'compared', 'EUR', '141', 'mn', '2007', '']
# Sentence after removing stopwords: ['', 'We', 'happy', 'working', 'Rapala', 'encourage', 'boaters', 'anglers', 'introduce', 'newcomers', 'sport', '', '', 'said', 'RBFF', 'President', '', 'CEO', 'Frank', 'Peterson', '']
# Sentence after removing stopwords: ['Ruukki', 'delivery', 'volumes', 'selling', 'prices', 'showed', 'favourable', 'development', 'company', 'comparable', 'net', 'sales', 'grew', '50', '', 'yearonyear', 'EUR647m', '', 'CEO', 'Sakari', 'Tamminen', 'said', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'threemonth', 'period', 'increased', 'EUR1', '2', '', 'revenue', 'increased', 'EUR20', '2', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'ElectrowattEkono', 'Philippines', '', 'Inc', 'also', 'awarded', 'threeyear', 'operation', 'maintenance', '', 'OM', '', 'contract', 'FR', 'Cement', 'Corporation', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'Latin', 'America', '']
# Sentence after removing stopwords: ['Cramo', 'Group', 'financial', 'targets', '20102013', 'sales', 'growth', 'higher', '10', 'percent', 'per', 'year', '', 'return', 'equity', '15', 'percent', '']
# Sentence after removing stopwords: ['Those', 'partially', 'offset', '186', 'mln', 'eur', 'gain', 'sale', 'Celbi', 'pulp', 'plant', 'Portugal', '']
# Sentence after removing stopwords: ['Arvo', 'Vuorenmaa', '', 'Loviisa', 'plant', 'general', 'manager', 'said', 'application', 'new', 'licence', '', 'standard', '', 'procedure', '', 'quite', 'confident', '', 'approval', 'granted', '']
# Sentence after removing stopwords: ['', 'I', 'pleased', 'Bjorn', 'Wahlroos', 'accepted', 'nomination', '']
# Sentence after removing stopwords: ['Finnair', 'able', 'operate', 'leisure', 'flights', 'despite', 'strike', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '052', 'versus', 'EUR', '009', '']
# Sentence after removing stopwords: ['At', 'time', '', 'sales', 'development', 'Russia', 'boosted', 'opening', 'Stockmann', 'Nevsky', 'Centre', 'St', 'Petersburg', '']
# Sentence after removing stopwords: ['Cost', 'savings', 'rise', '20', 'mln', 'eur', 'year', '2007', '', 'OKO', 'said', '']
# Sentence after removing stopwords: ['Known', 'Post', 'Bank', '', 'concept', 'would', 'see', 'Fidelity', 'Bank', 'rolling', '75', 'offices', 'Ghana', 'Post', 'premises', '', 'provide', 'financial', 'services', 'people', '']
# Sentence after removing stopwords: ['The', 'soapstone', 'deposits', 'Medvezhyegorsk', 'area', 'expected', 'increase', 'Tulikivi', 'current', 'reserves', 'considerably', '']
# Sentence after removing stopwords: ['Finnish', 'financial', 'software', 'developer', 'Basware', 'Oyj', 'said', 'today', 'provide', 'invoice', 'automation', '', 'IA', '', 'solution', 'unnamed', 'major', 'retail', 'company', 'USA', 'deal', '', 'worth', 'EUR300', '000', '']
# Sentence after removing stopwords: ['Acquisitions', 'made', 'businesses', 'well', 'integrated', '']
# Sentence after removing stopwords: ['Cargotec', 'Corporation', '', 'Press', 'Release', '', 'April', '28', '', '2008', '200', 'pm', 'Finnish', 'time', 'Cargotec', 'MacGREGOR', 'business', 'area', 'providing', 'marine', 'cargo', 'handling', 'offshore', 'load', 'handling', 'solutions', 'received', 'significant', 'hatch', 'cover', 'orders', 'bulk', 'carriers', '']
# Sentence after removing stopwords: ['The', 'groups', 'turnover', 'full', 'fiscal', 'year', 'expected', 'show', 'slight', 'increase', 'previous', 'fiscal', 'year', '']
# Sentence after removing stopwords: ['Sales', 'rose', '3009', 'mln', 'eur', 'compared', 'last', 'year', '2761', 'mln', 'eur', 'line', '299', 'mln', 'eur', 'consensus', 'figure', '']
# Sentence after removing stopwords: ['', 'We', 'tailored', 'solutions', 'meet', 'Solel', 'technical', 'requirements', '', 'result', 'costeffective', 'manufacturing', 'highestquality', 'reflectors', '', '']
# Sentence after removing stopwords: ['Last', 'month', '', 'Outokumpu', 'sold', '80', 'percent', 'technology', 'unit', '', 'Outokumpu', 'Technology', 'Oyj', '', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Finnish', 'pharmaceuticals', 'company', 'Orion', 'net', 'sales', 'rose', 'EUR', '190mn', 'first', 'quarter', '2009', 'EUR', '180mn', 'first', 'quarter', '2008', '']
# Sentence after removing stopwords: ['Kalmar', 'awarded', 'new', '5year', 'contract', 'supply', 'Rough', 'Terrain', 'Container', 'Handler', 'RTCH', '']
# Sentence after removing stopwords: ['Nokian', 'Capacitors', '', 'equipment', 'used', 'raise', 'capacity', 'reliability', 'Indian', 'grid', '']
# Sentence after removing stopwords: ['Talentum', 'expects', 'net', 'sales', 'core', 'business', 'increase', '2008', '', 'compared', '2007', '']
# Sentence after removing stopwords: ['The', 'move', 'aimed', 'boosting', 'sales', '', 'costefficiency', 'market', 'share', 'Finland', '']
# Sentence after removing stopwords: ['Operating', 'income', 'rose', 'EUR', '6964', 'mn', 'EUR', '6003', 'mn', '2009', '']
# Sentence after removing stopwords: ['Net', 'sales', 'increased', 'EUR655m', 'April', 'June', '2010', 'EUR438m', 'year', 'earlier', '']
# Sentence after removing stopwords: ['The', 'company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'EUR', '671', 'million', '']
# Sentence after removing stopwords: ['Wartsila', 'contract', 'October', '2007', 'plant', 'installed', 'Manturovo', 'Kostroma', 'region', 'Russia', '', '600', 'km', 'northeast', 'Moscow', '', 'Russia', '']
# Sentence after removing stopwords: ['Jarmo', 'Honkamaa', '', 'head', 'oil', 'refining', 'business', 'Neste', 'Oil', '', 'says', 'situation', 'looks', 'promising', 'viewpoint', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'saw', 'net', 'profit', 'jump', 'EUR2', '1', 'last', 'quarter', '2010', 'EUR995', '000', 'period', '2009', '']
# Sentence after removing stopwords: ['Profit', 'taxes', 'EUR', '01', 'mn', '', 'compared', 'EUR', '04', 'mn', 'previous', 'year', '']
# Sentence after removing stopwords: ['When', 'situation', 'normalises', '', 'company', 'able', 'increase', 'amount', 'residential', 'units', 'sale', 'St', 'Petersburg', 'Moscow', '', 'particular', '']
# Sentence after removing stopwords: ['According', 'SeppÆnen', '', 'new', 'technology', 'UMTS900', 'solution', 'network', 'building', 'costs', 'onethird', 'lower', 'building', '35', 'G', 'networks', '', 'operating', '2100', 'MHz', 'frequency', '']
# Sentence after removing stopwords: ['Uponor', 'made', 'operating', 'profit', 'EUR', '1510', 'mn', '', 'EUR', '1437', 'mn', '', 'made', '2007', 'record', 'year', '']
# Sentence after removing stopwords: ['UPMKymmene', 'working', 'closely', 'shipping', 'agents', 'reduce', 'fuel', 'consumption', 'greenhouse', 'gas', 'emissions', '']
# Sentence after removing stopwords: ['', 'Our', 'strategic', 'cooperation', 'Rentakran', 'brings', 'us', 'new', 'customers', 'alreadyworking', 'relationships', 'authorities', 'new', 'territories', '', '', 'said', 'Jarmo', 'Laasanen', '', 'senior', 'manager', 'Cramo', '']
# Sentence after removing stopwords: ['To', 'prove', 'efficiency', 'China', 'Mobile', 'system', '', 'Rod', 'Baber', '', 'English', 'climber', '', 'climbed', 'Mount', 'Everest', 'summit', 'successfully', 'made', 'calls', '']
# Sentence after removing stopwords: ['Biohit', 'already', 'services', 'many', 'current', 'Genesis', 'customers', 'customer', 'base', 'expected', 'expand', 'result', 'agreement', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '029', 'EUR', '005', '']
# Sentence after removing stopwords: ['We', 'proud', 'able', 'use', 'kind', 'innovative', 'mobile', 'service', 'voting', 'elections', '']
# Sentence after removing stopwords: ['Marimekko', 'Group', 'fullyear', 'net', 'sales', 'estimated', 'increase', '10', '', '']
# Sentence after removing stopwords: ['Componenta', 'objective', 'agreement', 'increase', 'business', 'existing', 'production', 'lines', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Shares', 'closed', 'higher', '', 'led', 'Nokia', 'announced', 'plans', 'team', 'Sanyo', 'manufacture', '3G', 'handsets', '', 'Nokian', 'Tyres', 'fourthquarter', 'earnings', 'report', 'beat', 'analysts', '', 'expectations', '', 'dealers', 'said', '']
# Sentence after removing stopwords: ['Construction', 'volumes', 'meanwhile', 'grow', 'rate', '1015', 'percent', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'Suominen', 'Corporation', 'specialises', 'wet', 'wipes', '', 'nonwovens', '', 'flexible', 'packaging', 'reports', 'net', 'sales', 'EUR', '441', 'mn', 'second', 'quarter', '2010', '', 'EUR', '433', 'mn', 'second', 'quarter', '2009', '']
# Sentence after removing stopwords: ['', 'The', 'additional', 'flight', 'linking', 'Mumbai', 'Helsinki', 'dictated', 'strong', 'traffic', 'demand', 'Asia', 'Europe', '']
# Sentence after removing stopwords: ['STORA', 'ENSO', '', 'NORSKE', 'SKOG', '', 'MREAL', '', 'UPMKYMMENE', 'Credit', 'Suisse', 'First', 'Boston', '', 'CFSB', '', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'Nordic', 'forestry', 'groups', '']
# ...
# Sentence after removing stopwords: ['Calls', 'switchboard', 'directory', 'services', 'decreased', 'significantly', 'since', 'employees', 'uptodate', 'contact', 'information', 'colleagues', 'customers', 'phone', 'place', 'call', 'directly', '']
# Sentence after removing stopwords: ['Also', '', 'Westpac', 'issue', 'benchmark', '', '18', 'month', 'FRN', 'deal', 'Euros', '']
# Sentence after removing stopwords: ['Sales', 'local', 'currencies', 'decreased', '05', 'percent', 'number', 'subscribers', 'rose', '127', 'million', 'total', '1476', 'million', 'end', 'fourth', 'quarter', '', 'company', 'said', '']
# Sentence after removing stopwords: ['BG', 'Crane', 'strong', 'customer', 'base', 'onroad', 'load', 'handling', 'related', 'installation', 'service', 'businesses', '']
# Sentence after removing stopwords: ['Why', 'subscribe', 'magazine', '']
# Sentence after removing stopwords: ['Atria', 'chose', 'DeLight', 'attract', 'consumers', '2545', 'age', 'group', 'Atria', 'Fresh', 'range', 'microwaveable', 'meals', '']
# Sentence after removing stopwords: ['The', 'largest', 'construction', 'company', 'Finland', '', 'YIT', 'Corporation', '', 'acquire', '70', '', 'shares', 'Slovak', 'construction', 'company', 'Reding', 'Bratislava', '']
# Sentence after removing stopwords: ['The', 'final', 'price', 'specified', '14', 'May', '2010', '', 'acquiring', 'company', 'said', '']
# Sentence after removing stopwords: ['Previously', '', 'Grimaldi', 'held', '4643', 'pct', 'stake', 'Finnish', 'company', 'following', 'takeover', 'bid', 'launched', 'November', '2006', '']
# Sentence after removing stopwords: ['The', 'figure', 'includes', 'change', 'fair', 'value', 'property', 'portfolio', '', 'EUR', '262', 'million', '']
# Sentence after removing stopwords: ['Nokia', 'OYJ', 'production', 'site', 'Bochum', '', 'Germany', '', 'posted', 'profit', 'interest', '134', 'mln', 'eur', '2007', '', 'Capital', 'reported', 'excerpt', 'article', 'released', 'tomorrow', '', 'citing', 'internal', 'documents', '']
# Sentence after removing stopwords: ['The', 'construction', 'project', 'scheduled', 'start', 'second', 'quarter', '2009', 'new', 'building', 'scheduled', 'place', 'end', '2010', '']
# Sentence after removing stopwords: ['The', 'Nokia', 'Music', 'Store', 'begins', 'trading', 'Tuesday', '', 'selling', 'singles', 'albums', 'well', 'live', 'music', 'streaming', '']
# Sentence after removing stopwords: ['BAWAG', '', 'Is', 'issue', 'benchmark', '', 'covered', 'deal', '']
# Sentence after removing stopwords: ['The', 'third', 'quarter', 'result', 'also', 'includes', '400000', 'euro', '', '', '575000', '', 'provision', 'downsizing', 'lure', 'manufacturing', 'Ireland', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'quarter', 'AprilJune', '2006', 'amounted', 'EUR182', '2', 'sales', 'EUR3', '62', 'bn', '']
# Sentence after removing stopwords: ['Thus', 'group', 'balance', 'sheet', 'EUR25', '8', 'goodwill', '', 'company', 'added', '']
# Sentence after removing stopwords: ['Delivery', 'due', 'second', 'half', '2011', '']
# Sentence after removing stopwords: ['Philips', 'available', 'comment', 'report', '']
# Sentence after removing stopwords: ['Thus', 'group', 'balance', 'sheet', 'EUR', '258', 'million', 'goodwill', '', 'company', 'added', '']
# Sentence after removing stopwords: ['According', 'HK', 'Ruokatalo', '', 'almost', 'meat', 'used', 'company', 'comes', 'Finland', '']
# Sentence after removing stopwords: ['The', 'devices', 'would', 'launched', 'Chinese', 'market', 'late', '2006', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'bank', 'leasing', 'arm', 'Nordea', 'Liising', 'ended', 'year', 'profit', '44', 'million', 'euros', '']
# Sentence after removing stopwords: ['We', 'went', 'market', 'yield', 'guidance', '725', '', 'area', '', 'gave', 'us', 'flexibility', 'go', '18th', '']
# Sentence after removing stopwords: ['When', 'investment', 'place', '', 'Atria', 'plans', 'expand', 'Moscow', 'market', '']
# Sentence after removing stopwords: ['Via', 'plant', '', 'Belgian', 'company', 'feed', '84', 'MW', 'electricity', 'distribution', 'grid', 'able', 'deliver', '14', 'MW', 'heat', '']
# Sentence after removing stopwords: ['The', 'ECB', 'mainly', 'target', 'inflation', '']
# Sentence after removing stopwords: ['A', 'merger', 'UPM', 'FinnishSwedish', 'Stora', 'Enso', 'likely', 'either', '']
# Sentence after removing stopwords: ['The', 'amendment', 'incur', 'additional', 'costs', '']
# Sentence after removing stopwords: ['Tyrvaan', 'Sanomat', '', 'published', 'twice', 'week', 'Tyrvaan', 'Sanomat', 'Oy', '', 'appears', 'Sastamala', 'Kiikoinen', '']
# Sentence after removing stopwords: ['Aldata', 'Share', 'Space', 'Optimization', 'Vision', 'Apollo', 'User', 'Group', '2009', 'Category', 'Management', 'Association', 'Conferences', '', 'Company', 'Will', 'Unveil', 'New', 'Solution', 'Combines', 'Business', 'Intelligence', 'Space', 'Planning', 'Data', 'Conferences']
# Sentence after removing stopwords: ['Meanwhile', '', 'Alfa', 'owns', '251', '', 'MegaFon', 'Altimo', '', '499', '', 'Turkcell', 'via', '185', '', 'stake', 'Cukurova', 'Holding', '']
# Sentence after removing stopwords: ['business', 'sectors', 'building', 'construction', '', 'infrastructure', 'construction', 'technical', 'building', 'services', '']
# Sentence after removing stopwords: ['The', 'company', 'says', 'difficult', 'estimate', 'market', 'situation', 'whole', 'year', '2009', '']
# Sentence after removing stopwords: ['JuhaPekka', 'Weckstr¦m', 'appointed', 'President', 'telecom', 'group', 'TeliaSonera', 'Finland', 'succeed', 'Esa', 'Rautalinko', '']
# Sentence after removing stopwords: ['The', 'technology', 'become', 'available', 'businesses', 'fourth', 'quarter', '', 'Nokia', 'said', '']
# Sentence after removing stopwords: ['The', 'reductions', 'implemented', 'mainly', 'course', 'first', 'half', '2009', '']
# Sentence after removing stopwords: ['KONE', '', 'headquartered', 'Espoo', '', 'Finland', '', 'one', 'world', 'leading', 'elevator', 'escalator', 'companies', '']
# Sentence after removing stopwords: ['Combined', 'Basware', 'Enterprise', 'Purchase', 'Pay', 'portfolio', '', 'provides', 'high', 'level', 'automation', 'procurement', 'invoice', 'workflows', '']
# Sentence after removing stopwords: ['The', 'firm', 'builds', 'components', 'mobile', 'phones', 'communications', 'products', '']
# Sentence after removing stopwords: ['In', 'Baltic', 'countries', '', 'Atria', 'target', 'organic', 'growth', '']
# Sentence after removing stopwords: ['The', 'broker', 'started', 'UPMKymmene', '', 'Stora', 'Enso', 'Sappi', '', 'equalweight', '', 'recommendations', 'Holmen', 'Norske', 'Skog', '', 'underweight', '', 'ratings', '']
# Sentence after removing stopwords: ['The', 'EUR', '07', 'million', 'nonrecurring', 'expenses', 'recorded', 'third', 'quarter', '']
# Sentence after removing stopwords: ['The', 'Court', 'decision', 'also', 'promote', 'genuine', 'competition', 'services']
# Sentence after removing stopwords: ['The', 'guidance', 'set', '90', 'basis', 'points', 'midswaps', '', 'report', 'said', '']
# Sentence after removing stopwords: ['The', 'company', 'supports', 'global', 'customers', 'developing', 'new', 'technologies', 'offers', 'fast', 'route', 'product', 'development', 'applications', 'volume', 'production', '']
# Sentence after removing stopwords: ['Therefore', '', 'Phase', 'III', 'research', 'conducted', 'Abbott', '']
# Sentence after removing stopwords: ['Liquid', 'handling', 'products', 'include', 'electronic', 'mechanical', 'pipettes', '', 'disposable', 'tips', 'well', 'pipette', 'maintenance', 'calibration', 'services', 'research', 'institutions', '', 'healthcare', 'industrial', 'laboratories', '']
# Sentence after removing stopwords: ['It', '', 'fingerfriendly', '', '', 'opinion', '', 'really', 'fast', '']
# Sentence after removing stopwords: ['We', 'look', 'forward', 'take', 'part', 'future', 'development', 'company', '', '', 'says', 'Tomas', 'Billing', '', 'President', 'Nordstjernan', '']
# Sentence after removing stopwords: ['BasWare', 'headquartered', 'Espoo', '', 'Finland', '']
# Sentence after removing stopwords: ['The', 'new', 'chain', '700', 'discount', 'stores', '250', 'supermarkets', '']
# Sentence after removing stopwords: ['Its', 'total', 'annual', 'revenue', 'comes', '160', 'mln', 'zloty', '', '', '569', 'mln42', '3', 'mln', 'euro', '', '']
# Sentence after removing stopwords: ['The', 'building', 'complex', 'consists', 'highquality', 'office', 'retail', 'space', 'totalling', '49200', 'square', 'metres', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Our', 'key', 'geographical', 'markets', 'Europe', '', 'Russian', 'Federation', '', 'MiddleEast', '', 'SouthAfrica', 'Japan', '']
# Sentence after removing stopwords: ['OMEO', '', 'wwwomeose', '', 'employs', '55', 'expects', 'net', 'sales', '23', 'mln', 'euro', '', '', '298', 'mln', '', 'fiscal', '20062007', '', 'ending', 'April', '30', '', '2007', '']
# Sentence after removing stopwords: ['Unit', 'prices', 'straddle', 'carriers', 'vary', 'EUR700', '000', 'EUR900', '000', '', 'company', 'added', '']
# Sentence after removing stopwords: ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '82', 'mn', '']
# Sentence after removing stopwords: ['The', 'company', 'continuous', 'need', 'alloys', 'nickel', '', 'ferrochrome', '', 'molybdenum', 'manganese', 'production', '', 'said', 'Talvivaara', '']
# Sentence after removing stopwords: ['MILAN', '', 'AFX', '', '', 'The', 'Italian', 'shipping', 'group', 'Grimaldi', 'increased', 'stake', 'Finnish', 'company', 'Finnlines', '354', 'pct', '305', 'pct', 'held', 'June', '', 'according', 'news', 'agency', 'ANSA', '']
# Sentence after removing stopwords: ['In', 'end', '', 'Sanoma', 'News', 'wants', 'secure', 'foundation', 'savings', '']
# Sentence after removing stopwords: ['The', 'closing', 'transaction', 'took', 'place', 'today', '']
# Sentence after removing stopwords: ['', 'BG', 'Crane', 'strong', 'partner', 'Hiab', 'Australia', 'many', 'years', '']
# Sentence after removing stopwords: ['The', 'transaction', '', 'includes', 'US', '15', 'billion', 'euro1', 'billion', 'cash', '', 'vendor', 'notes', 'share', 'purchases', '', 'expected', 'completed', 'first', 'quarter', '2008', '', 'FinnishSwedish', 'paper', 'maker', 'said', '']
# Sentence after removing stopwords: ['The', 'continued', 'operations', 'mean', 'structure', 'restructuring', 'Aspocomp', 'group', 'including', 'Aspocomp', 'Oulu', 'headquarter', 'operations', '']
# Sentence after removing stopwords: ['The', 'company', 'earlier', 'said', 'considering', 'different', 'strategic', 'options', 'struggling', 'lowcost', 'mobile', 'operator', '', 'including', 'divestment', 'holding', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'Martela', 'offers', 'comprehensive', 'service', 'cover', 'entire', 'process', 'change', 'initial', 'inventory', 'design', 'removal', 'maintenance', '']
# Sentence after removing stopwords: ['One', 'also', 'apply', 'jobs', 'directly', 'iPad', '', 'select', 'CV', 'attach', 'covering', 'letter', 'appropriate', 'position', '']
# Sentence after removing stopwords: ['These', 'sections', 'put', 'place', 'form', 'loadbearing', 'steel', 'structure', 'bridge', '', '', 'says', 'Sami', 'Eronen', '', 'Senior', 'Vice', 'President', '', 'Infrastructure', 'Northern', 'Europe', '', 'Ruukki', 'Construction', '']
# Sentence after removing stopwords: ['Cohen', '', 'Steers', '', 'Inc', '', '5', '534', '626', 'shares', 'representing', '4985', '', 'share', 'capital', 'voting', 'rights', '']
# Sentence after removing stopwords: ['The', 'podcast', '', 'sees', 'Harple', 'provide', 'lowdown', 'GyPSii', 'platform', '', 'takes', 'someone', 'location', 'demographic', 'information', 'produce', 'contextual', 'index', 'world', 'around', '']
# Sentence after removing stopwords: ['compensation', 'news', '', 'opinions', 'distributions', '']
# Sentence after removing stopwords: ['One', 'even', 'receive', 'spot', 'alerts', 'soon', 'jobs', 'posted', '', 'putting', 'front', 'queue', 'opportunities', '']
# Sentence after removing stopwords: ['According', 'report', '', 'Elisa', 'DNA', 'joint', 'market', 'share', 'Finland', 'telecom', 'market', '59', '', '']
# Sentence after removing stopwords: ['Pharmaceutical', 'market', 'Italy', 'Global', 'Research', '', 'Data', 'Services', 'published', 'recently', 'market', 'analysis', 'pharmaceutical', 'markets', 'Italy', '']
# Sentence after removing stopwords: ['The', 'commission', 'found', 'evidence', 'several', 'meetings', 'discuss', 'cartel', '', 'including', 'one', 'Brussels', 'restaurant', 'November', '1997', 'companies', 'discussed', 'price', 'increases', '']
# Sentence after removing stopwords: ['We', 'also', 'pleased', 'welcome', 'new', 'employees', 'Tieto', '', '']
# Sentence after removing stopwords: ['The', 'business', 'idea', 'Budget', 'Sport', 'offer', 'customers', 'wide', 'range', 'highquality', 'sports', 'equipment', 'clothing', 'low', 'prices', '', 'company', 'said', '']
# Sentence after removing stopwords: ['POYRY', 'PLCCompany', 'Announcement', '10', 'December', '2010', '410', 'pm', 'Pursuant', 'Poyry', 'PLC', 'stock', 'option', 'program', '2004', '', '63', '792', 'new', 'shares', 'company', 'subscribed', 'since', '27', 'October', '2010', 'stock', 'options', '2004B', '']
# Sentence after removing stopwords: ['Anttila', 'online', 'department', 'store', '', 'NetAnttila', '', 'established', 'position', 'bestknown', '', 'visited', 'shopped', 'online', 'store', 'Finland', '', '']
# Sentence after removing stopwords: ['The', 'Annual', 'Report', 'contains', 'financial', 'statements', '', 'consolidated', 'financial', 'statements', '', 'report', 'Board', 'Directors', 'auditor', 'report', '']
# Sentence after removing stopwords: ['The', 'Group', 'consolidated', 'net', 'sales', '2008', 'totaled', '34', 'billion', 'euros', 'employs', 'approximately', '13000', 'persons', '']
# Sentence after removing stopwords: ['The', 'StoneGate', 'product', 'centrally', 'manageable', 'suited', 'physical', 'virtual', 'environments', '']
# Sentence after removing stopwords: ['The', 'handset', 'maker', 'disclose', 'financial', 'details', '']
# Sentence after removing stopwords: ['Local', 'government', 'commissioner', 'ml', '', 'Kurt', 'Svensson', '', 'says', 'contact', 'management', 'Finnish', 'company', 'Componenta', 'find', 'alternatives', 'company', 'decision', 'close', 'plant', 'ml', '']
# Sentence after removing stopwords: ['As', 'consequence', 'Works', 'Council', 'withdrawn', 'petition', 'suspend', 'reorganisation', '']
# Sentence after removing stopwords: ['Finnish', 'investment', 'group', 'Neomarkka', 'Oyj', '', 'HEL', '', 'NEMBV', '', 'said', 'today', 'buy', 'former', 'production', 'facilities', 'Kuitu', 'Finland', 'Ltd', '', 'part', 'negotiations', 'option', 'invest', 'specialty', 'cellulose', 'fiber', 'business', '']
# Sentence after removing stopwords: ['Ulefos', 'Group', 'leading', 'supplier', 'manhole', 'covers', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['Okmetic', 'global', 'customer', 'base', 'sales', 'network', '', 'production', 'plants', 'Finland', 'US', 'contract', 'manufacturers', 'Japan', 'China', '']
# Sentence after removing stopwords: ['OPPohjola', 'Group', 'capital', 'adequacy', 'ratio', 'Act', 'Credit', 'Institutions', 'stood', '121', '', 'Tier', '1', 'ratio', '121', '', '']
# Sentence after removing stopwords: ['Entire', 'paper', 'mills', 'may', 'set', '', 'especially', 'new', 'EU', 'member', 'states', '']
# Sentence after removing stopwords: ['These', 'companies', '20000', 'sq', 'office', 'commercial', 'building', 'substantial', 'amount', 'building', 'right', 'new', 'shopping', 'center', 'Liljeholmen', '', 'Stockholm', '']
# Sentence after removing stopwords: ['For', 'fiscal', 'year', 'ending', 'September', '30', '', '2009', 'revenue', 'customers', '', '10012', 'million', 'around', '110', '', 'transportation', 'group', 'revenue', '']
# Sentence after removing stopwords: ['The', 'veneer', 'plywood', 'industry', 'Sweden', 'quite', 'small', 'despite', 'raw', 'material', 'resources', '']

# %%
positiveValues
#output is a dictionary-list of words in news column and the count of each of these words in train dataset where sentiment=positive
# Out:
# defaultdict(int,
#             {'It': 10,
#              'also': 26,
#              'strengthen': 10,
#              'Ruukki': 12,
#              'offshore': 4,
#              'business': 24,
#              '': 2207,
#              'Efore': 2,
#              'results': 4,
#              'last': 22,
#              'quarter': 62,
#              'showed': 3,
#              'even': 3,
#              'faster': 2,
#              'improvement': 6,
#              'company': 135,
#              'managed': 2,
#              'better': 5,
#              'source': 1,
#              'components': 4,
#              'Romania': 2,
#              'local': 7,
#              'arm': 1,
#              'Finnish': 110,
#              'metal': 4,
#              'producer': 3,
#              'increased': 53,
#              'capital': 12,
#              '900000': 1,
#              'euro': 29,
#              '114': 4,
#              'mln': 62,
#              'cash': 6,
#              'contribution': 2,
#              'reported': 12,
#              'September': 11,
#              '19': 7,
#              '2006': 34,
#              'The': 168,
#              'representative': 4,
#              'body': 1,
#              'Swedish': 9,
#              'Meats': 1,
#              'approved': 4,
#              'improved': 11,
#              'offer': 3,
#              'HK': 2,
#              'Ruokatalo': 2,
#              'acquire': 5,
#              'In': 39,
#              'third': 14,
#              '2010': 64,
#              'net': 98,
#              'sales': 105,
#              '52': 2,
#              'EUR': 228,
#              '2055': 1,
#              'mn': 129,
#              'operating': 44,
#              'profit': 99,
#              '349': 2,
#              '235': 2,
#              'Our': 5,
#              'superior': 2,
#              'customer': 7,
#              'centricity': 1,
#              'expertise': 6,
#              'digital': 4,
#              'services': 34,
#              'set': 5,
#              'us': 5,
#              'apart': 1,
#              'competitors': 2,
#              'This': 10,
#              'much': 2,
#              'process': 8,
#              'using': 3,
#              'virgin': 1,
#              'paper': 11,
#              'requires': 1,
#              'less': 1,
#              'transportation': 2,
#              'wood': 5,
#              'pulp': 4,
#              'places': 1,
#              'like': 1,
#              'Finland': 45,
#              'Canada': 1,
#              'lifting': 2,
#              'equipment': 16,
#              'maker': 22,
#              'Konecranes': 4,
#              'Oyj': 49,
#              'said': 126,
#              'July': 9,
#              '30': 12,
#              '2008': 55,
#              'rose': 49,
#              '712': 1,
#              '1111': 1,
#              'first': 36,
#              'half': 4,
#              '571': 1,
#              '891': 1,
#              'period': 80,
#              '2007': 41,
#              'Both': 11,
#              'record': 11,
#              'high': 4,
#              'history': 3,
#              'estimated': 11,
#              'synergy': 1,
#              'benefits': 1,
#              'least': 3,
#              'EUR7m': 1,
#              'annually': 3,
#              'construction': 19,
#              'markets': 9,
#              'still': 4,
#              'experiencing': 1,
#              '4': 10,
#              'annual': 9,
#              'growth': 26,
#              'Besides': 1,
#              'share': 33,
#              'meat': 3,
#              'various': 1,
#              'sausages': 1,
#              'offering': 8,
#              'number': 9,
#              'new': 44,
#              'tastes': 1,
#              'grill': 1,
#              'products': 22,
#              'shish': 1,
#              'kebabs': 1,
#              'segment': 1,
#              'Paavel': 1,
#              'Very': 1,
#              'recommendable': 1,
#              'Nokian': 7,
#              'Z': 1,
#              'G2': 1,
#              'according': 3,
#              'ADAC': 3,
#              'judgement': 1,
#              'latest': 3,
#              'summer': 2,
#              'tyre': 1,
#              'test': 3,
#              'German': 1,
#              'automobile': 2,
#              'association': 3,
#              'Sales': 13,
#              '10': 16,
#              'pct': 14,
#              '566': 1,
#              'eur': 19,
#              'back': 3,
#              'strong': 13,
#              'volume': 7,
#              'favourable': 3,
#              'currency': 3,
#              'effects': 1,
#              'reporting': 4,
#              'grew': 18,
#              '432': 1,
#              '6': 15,
#              'million': 114,
#              'Neste': 3,
#              'Oil': 4,
#              'awarded': 23,
#              'Chemical': 3,
#              'Industry': 2,
#              'Federation': 1,
#              'Innovation': 1,
#              'Award': 1,
#              'NExBTL': 1,
#              'technology': 26,
#              'enables': 4,
#              'biodiesel': 2,
#              'produced': 2,
#              'vegetable': 1,
#              'oil': 5,
#              'animal': 2,
#              'fat': 2,
#              'SRV': 3,
#              'raise': 5,
#              'holding': 3,
#              'majority': 1,
#              'Rautaruukki': 6,
#              'Corporation': 27,
#              'Stock': 2,
#              'exchange': 4,
#              'release': 9,
#              '3': 17,
#              'December': 8,
#              '2009': 68,
#              '12': 11,
#              'noon': 1,
#              'engineering': 11,
#              'divisions': 2,
#              'improve': 11,
#              'adjust': 2,
#              'operations': 28,
#              'Jens': 1,
#              'SchulteBockum': 1,
#              'Vodafone': 2,
#              'global': 9,
#              'director': 5,
#              'terminals': 1,
#              'expects': 11,
#              'sell': 5,
#              'one': 10,
#              'two': 11,
#              '125': 2,
#              '225': 1,
#              'models': 2,
#              'year': 75,
#              'launch': 7,
#              'potentially': 1,
#              'tens': 1,
#              'millions': 1,
#              'lifetime': 1,
#              'device': 3,
#              'Finnishowned': 1,
#              'contract': 39,
#              'manufacturer': 9,
#              'electronics': 4,
#              'Elcoteq': 4,
#              'Hungary': 3,
#              'Kft': 1,
#              'announced': 12,
#              'plans': 9,
#              'recruit': 2,
#              '650': 1,
#              'staffers': 1,
#              'fulfill': 1,
#              'orders': 13,
#              'Pcs': 1,
#              'plants': 4,
#              'Australian': 1,
#              'Mirabela': 2,
#              'Nickel': 1,
#              'Outokumpu': 6,
#              'Technology': 5,
#              'grinding': 2,
#              'nickel': 2,
#              'sulfide': 1,
#              'project': 10,
#              'Bahia': 2,
#              'State': 1,
#              'Brazil': 3,
#              'Consumers': 1,
#              'well': 19,
#              'received': 10,
#              'packed': 1,
#              'fresh': 1,
#              'Fiskars': 9,
#              'portfolio': 3,
#              'international': 7,
#              'brands': 3,
#              'include': 4,
#              'Iittala': 1,
#              'Gerber': 1,
#              'Silva': 2,
#              'Buster': 1,
#              'Nokia': 21,
#              'Elisa': 6,
#              'work': 4,
#              'together': 1,
#              'bring': 5,
#              'mobile': 20,
#              'gaming': 1,
#              'experience': 7,
#              'customers': 20,
#              'established': 4,
#              '3G': 5,
#              'base': 7,
#              'station': 3,
#              '17000': 1,
#              'feet': 1,
#              'foot': 1,
#              'Mount': 2,
#              'Everest': 2,
#              'enable': 4,
#              'mountain': 1,
#              'climbers': 1,
#              '29035foot': 1,
#              'summit': 2,
#              'surf': 1,
#              'Internet': 3,
#              'send': 2,
#              'videos': 1,
#              'exploits': 2,
#              'Outotec': 5,
#              'supply': 23,
#              'zinc': 3,
#              'roaster': 1,
#              'gas': 2,
#              'cleaning': 1,
#              'sulphuric': 2,
#              'acid': 2,
#              'plant': 17,
#              'OZK': 1,
#              'Kardzhali': 1,
#              'smelter': 1,
#              'Bulgaria': 3,
#              'A': 8,
#              'Helsinki': 15,
#              'ELIiV': 1,
#              'today': 38,
#              'EPS': 11,
#              'EUR1': 9,
#              '13': 11,
#              'increase': 51,
#              'Q1': 4,
#              '18': 9,
#              'May': 10,
#              'electrical': 3,
#              'Salcomp': 1,
#              'Oy': 11,
#              'HEL': 27,
#              'SAL1V': 1,
#              'turned': 3,
#              'versus': 8,
#              'loss': 38,
#              'EUR2m': 2,
#              'corresponding': 35,
#              'JanuarySeptember': 7,
#              'went': 7,
#              '14': 6,
#              'yearonyear': 20,
#              '654': 2,
#              '5253': 1,
#              '4877': 1,
#              'transaction': 4,
#              'line': 10,
#              'Aspo': 8,
#              'strategy': 11,
#              'expand': 8,
#              'Baltic': 8,
#              'Sea': 2,
#              'region': 4,
#              'eastern': 1,
#              'UPMKymmene': 6,
#              'upgraded': 4,
#              'inline': 1,
#              'underperform': 1,
#              'Goldman': 1,
#              'Sachs': 1,
#              'Lithuanian': 6,
#              'beer': 8,
#              'market': 44,
#              'made': 7,
#              '1441': 1,
#              'liters': 8,
#              'January': 7,
#              'rise': 11,
#              '08': 3,
#              'percent': 40,
#              'yearearlier': 2,
#              'figure': 3,
#              'Brewers': 2,
#              'Association': 2,
#              'citing': 1,
#              'members': 3,
#              'We': 23,
#              'capitalize': 1,
#              'similar': 1,
#              'bridge': 7,
#              'projects': 6,
#              'Nordic': 9,
#              'countries': 11,
#              'CHF': 1,
#              'great': 2,
#              'product': 8,
#              'group': 31,
#              'chain': 6,
#              '45': 10,
#              'stores': 2,
#              'aim': 4,
#              'ensure': 3,
#              'Vacon': 4,
#              'good': 12,
#              'shape': 2,
#              'expenditure': 1,
#              'starts': 1,
#              'pick': 1,
#              'comments': 3,
#              'Plc': 10,
#              'President': 6,
#              'CEO': 16,
#              'Vesa': 1,
#              'Laisi': 1,
#              'cooperation': 15,
#              'double': 3,
#              'Switch': 2,
#              'converter': 2,
#              'capacity': 14,
#              'Earnings': 3,
#              'per': 21,
#              'amounted': 6,
#              'EUR0': 11,
#              '07': 2,
#              '04': 5,
#              '1': 24,
#              'Block': 1,
#              'lamp': 1,
#              'Harri': 1,
#              'Koskinen': 1,
#              'light': 1,
#              'introduced': 2,
#              '1996': 1,
#              'bestseller': 1,
#              'ever': 1,
#              'since': 7,
#              'Nordea': 9,
#              'sees': 2,
#              'return': 5,
#              'positive': 10,
#              '2011': 14,
#              'flag': 1,
#              'carrier': 5,
#              'Finnair': 13,
#              'FIA1S': 2,
#              'sealed': 2,
#              'nineyear': 1,
#              'sale': 10,
#              'leaseback': 1,
#              'agreement': 37,
#              'newest': 1,
#              'Airbus': 3,
#              'A330': 1,
#              'aircraft': 2,
#              'syndication': 1,
#              'Japanese': 1,
#              'lease': 2,
#              'Growth': 2,
#              'expected': 14,
#              'continue': 6,
#              'Previously': 3,
#              'guided': 1,
#              'EBIT': 6,
#              '20': 11,
#              'respectively': 13,
#              'program': 4,
#              'target': 6,
#              'structural': 1,
#              'cost': 12,
#              'reductions': 1,
#              '30mn': 1,
#              'Revenue': 2,
#              'x20ac': 4,
#              '36': 8,
#              'billion': 12,
#              'US': 15,
#              'second': 22,
#              'firstquarter': 1,
#              'of2008': 1,
#              'Magnus': 1,
#              'Rosen': 1,
#              'Ramirent': 6,
#              'stock': 10,
#              'price': 11,
#              '700': 2,
#              'ores': 1,
#              '09': 2,
#              'close': 2,
#              'SEK77': 1,
#              '65': 3,
#              'ending': 1,
#              'twoday': 1,
#              'streak': 1,
#              'losses': 1,
#              'Hkan': 1,
#              'Dahlstr¦m': 1,
#              'head': 7,
#              'mobility': 1,
#              'TeliaSonera': 4,
#              'forecast': 3,
#              'data': 10,
#              'network': 16,
#              'Sweden': 5,
#              'eightfold': 1,
#              '200000': 1,
#              'TB': 1,
#              '2014': 1,
#              'Press': 6,
#              '9': 10,
#              'October': 11,
#              'signed': 36,
#              'deliver': 9,
#              'install': 4,
#              'steel': 14,
#              'structures': 2,
#              'Kyronsalmi': 1,
#              'strait': 1,
#              'Savonlinna': 1,
#              'leading': 12,
#              'metals': 3,
#              'fourthquarter': 2,
#              'tripled': 3,
#              'demand': 7,
#              'stainless': 5,
#              'soaring': 1,
#              'prices': 3,
#              'proceeds': 1,
#              'unit': 9,
#              'EB': 2,
#              'delivered': 3,
#              'custom': 2,
#              'solution': 11,
#              'LG': 1,
#              'Electronics': 1,
#              'making': 3,
#              'commercially': 1,
#              'available': 2,
#              'terminal': 2,
#              'vendors': 2,
#              'wireless': 2,
#              'operators': 8,
#              'telecoms': 3,
#              'software': 13,
#              'developer': 9,
#              'Tecnomen': 1,
#              '5': 13,
#              '33': 5,
#              '25': 4,
#              'order': 18,
#              'expansion': 7,
#              'charging': 2,
#              'messaging': 2,
#              'systems': 16,
#              'fixed': 3,
#              'networks': 6,
#              'Brasil': 2,
#              'Telecom': 3,
#              'Kesko': 10,
#              'pursues': 1,
#              'healthy': 1,
#              'focused': 1,
#              'concentrating': 1,
#              'consumercustomers': 1,
#              'Ixonos': 3,
#              'estimates': 7,
#              'hire': 1,
#              'specialists': 1,
#              'mechanical': 1,
#              'design': 7,
#              'RD': 4,
#              'Jyvaeskylae': 2,
#              'end': 12,
#              'satisfied': 3,
#              'Basware': 9,
#              'Invoice': 3,
#              'Automation': 3,
#              'extends': 1,
#              'implementation': 1,
#              'geographies': 1,
#              'Salo': 1,
#              '29': 6,
#              'August': 8,
#              'Benefon': 2,
#              'inhouse': 1,
#              'platform': 5,
#              'licensing': 3,
#              'complete': 3,
#              'Opna': 1,
#              'longstanding': 2,
#              'partner': 4,
#              'Pollex': 1,
#              'Profit': 6,
#              '103': 2,
#              '087': 1,
#              'HELSINKI': 7,
#              'AFX': 5,
#              'Retail': 1,
#              'wholesale': 2,
#              '6594': 1,
#              'February': 7,
#              '108': 1,
#              'pleased': 9,
#              'working': 8,
#              'Fujitsu': 2,
#              'NTT': 1,
#              'DoCoMo': 1,
#              'advance': 1,
#              'progress': 1,
#              'LTE': 1,
#              'Juergen': 1,
#              'Walter': 1,
#              'Head': 3,
#              'Converged': 1,
#              'Core': 1,
#              'Siemens': 3,
#              'Networks': 4,
#              'SINGAPORE': 1,
#              'ICIS': 1,
#              'Kemira': 5,
#              'Indian': 5,
#              'water': 5,
#              'infrastructure': 3,
#              'firm': 6,
#              '2': 12,
#              'IVRCL': 3,
#              'agreed': 7,
#              'form': 3,
#              'join': 1,
#              'venture': 3,
#              'includes': 2,
#              'inorganic': 1,
#              'coagulant': 1,
#              'manufacturing': 8,
#              'facility': 7,
#              'Andhra': 1,
#              'Pradesh': 1,
#              'state': 2,
#              'India': 8,
#              'treatment': 2,
#              'chemicals': 2,
#              'Tuesday': 9,
#              'Pretax': 4,
#              'totalled': 11,
#              'compared': 33,
#              '1592': 1,
#              'fourth': 9,
#              'Commission': 1,
#              'applauded': 1,
#              'applying': 1,
#              'factbased': 1,
#              'datadriven': 1,
#              'approach': 4,
#              'providing': 6,
#              'clarity': 1,
#              'future': 3,
#              'petitions': 1,
#              'London': 4,
#              'shares': 5,
#              'jumped': 5,
#              'almost': 2,
#              '100': 5,
#              'points': 6,
#              '17': 3,
#              'opened': 3,
#              'Net': 12,
#              'EUR193': 1,
#              'EUR179': 1,
#              'pretax': 7,
#              '342': 2,
#              'EUR43': 1,
#              'USD1': 2,
#              'terms': 6,
#              'profitability': 6,
#              'earnings': 7,
#              'best': 6,
#              'Chief': 4,
#              'Executive': 2,
#              'VeliMatti': 1,
#              'Mattila': 1,
#              'production': 14,
#              'completed': 6,
#              'hormone': 1,
#              'treatments': 1,
#              'Kaupthing': 4,
#              'forecasts': 2,
#              'significant': 20,
#              'printing': 4,
#              'YIT': 13,
#              'spanning': 1,
#              'Kemijoki': 1,
#              'river': 1,
#              'Northern': 3,
#              'When': 2,
#              'open': 3,
#              'next': 6,
#              'largest': 15,
#              'world': 10,
#              'produce': 2,
#              'diesel': 2,
#              'fuel': 4,
#              'renewable': 1,
#              'feedstock': 1,
#              'palm': 2,
#              'assets': 4,
#              'electronic': 2,
#              'media': 3,
#              'employing': 1,
#              '18500': 1,
#              'These': 3,
#              'companies': 20,
#              'able': 10,
#              'keep': 1,
#              'positions': 1,
#              'memorandum': 3,
#              'understanding': 3,
#              'Global': 2,
#              'Company': 8,
#              'KEMIRA': 1,
#              'Vietnam': 2,
#              'National': 2,
#              'Chemicals': 1,
#              'Group': 24,
#              'Vinachem': 1,
#              'occasion': 1,
#              'Furthermore': 3,
#              'Bunge': 2,
#              'sign': 1,
#              'Sunnuntai': 1,
#              'Carlshamn': 1,
#              'Mejeri': 1,
#              'IH': 1,
#              'move': 3,
#              'enhance': 3,
#              'April': 6,
#              'forest': 8,
#              'machinery': 8,
#              'Ponsse': 5,
#              'PON1V': 1,
#              'swing': 1,
#              'EUR6': 3,
#              'EUR9': 1,
#              'earlier': 16,
#              'buy': 6,
#              'Danish': 2,
#              'Rose': 1,
#              'Poultry': 1,
#              'AS': 7,
#              'EUR23': 1,
#              'combination': 2,
#              'Also': 1,
#              'bringing': 3,
#              'right': 3,
#              'kind': 2,
#              'people': 4,
#              'upgrade': 4,
#              'human': 1,
#              'resources': 3,
#              'Vocollect': 1,
#              'T2': 1,
#              'North': 8,
#              'America': 8,
#              'take': 2,
#              'advantage': 1,
#              'Voice': 1,
#              'Directed': 1,
#              'Warehousing': 1,
#              'warehouse': 2,
#              'efficiency': 7,
#              'productivity': 2,
#              'gains': 1,
#              'discounted': 1,
#              'Olvi': 5,
#              'controls': 2,
#              '94': 2,
#              'stake': 6,
#              'Ragutis': 4,
#              'Le': 1,
#              'Coq': 1,
#              'report': 6,
#              'published': 2,
#              'brewery': 3,
#              'reached': 5,
#              '1504': 1,
#              'euros': 12,
#              '204': 1,
#              '1249': 1,
#              '2004': 14,
#              'BasWare': 3,
#              'Ilkka': 2,
#              'Sihvo': 2,
#              'conjunction': 1,
#              'Interim': 1,
#              'Report': 2,
#              'As': 4,
#              'whole': 4,
#              'succeeded': 2,
#              'nine': 16,
#              'months': 17,
#              'narrowed': 9,
#              '415000': 1,
#              '74': 5,
#              'District': 1,
#              'Court': 1,
#              'dismissed': 1,
#              'charges': 1,
#              'court': 2,
#              'instance': 1,
#              '2005': 24,
#              'continuing': 1,
#              'came': 2,
#              '030': 1,
#              '017': 1,
#              'Production': 3,
#              'locations': 5,
#              'including': 8,
#              'Mexico': 3,
#              'Advertising': 1,
#              'circulation': 1,
#              'revenues': 5,
#              '34': 2,
#              'solid': 2,
#              'credit': 2,
#              'DZ': 1,
#              'Bank': 15,
#              'Rabobank': 1,
#              'partnership': 5,
#              'commitment': 2,
#              'parties': 4,
#              'develop': 3,
#              'respective': 2,
#              'ESL': 2,
#              'Shipping': 3,
#              'opportunity': 2,
#              'update': 1,
#              'fleet': 3,
#              'Metso': 6,
#              'four': 6,
#              'machines': 4,
#              'latter': 1,
#              'mill': 4,
#              'Jaemsaenkoski': 1,
#              'coating': 1,
#              'color': 1,
#              'system': 10,
#              'machine': 2,
#              'quality': 5,
#              'measurements': 1,
#              '8': 11,
#              'EUR64': 1,
#              'due': 5,
#              'acquisitions': 2,
#              'realized': 2,
#              '200809': 1,
#              'effect': 4,
#              'EUR10': 3,
#              'review': 2,
#              'Exports': 2,
#              '165': 1,
#              '191': 1,
#              'lowering': 1,
#              'shows': 1,
#              'real': 2,
#              'estate': 2,
#              'stabilised': 1,
#              'returned': 3,
#              'balance': 3,
#              'apartments': 1,
#              'acquiring': 4,
#              'fair': 6,
#              'eyes': 1,
#              'clients': 4,
#              'Latin': 4,
#              '42': 2,
#              '432mn': 1,
#              'total': 13,
#              '87': 2,
#              'devices': 3,
#              'sold': 4,
#              'area': 11,
#              'representing': 4,
#              '32': 3,
#              'Clothing': 2,
#              'retail': 5,
#              'SeppÆlÆ': 2,
#              '1552': 1,
#              '311': 1,
#              '171': 1,
#              'WCDMA': 2,
#              '3GHSPA': 1,
#              'radio': 4,
#              'modular': 1,
#              'Flexi': 1,
#              'East': 3,
#              'Java': 1,
#              'Bali': 1,
#              'Sumatra': 1,
#              'Batam': 1,
#              'marktomarket': 1,
#              'result': 14,
#              '133': 1,
#              'handling': 8,
#              'bleaching': 1,
#              'lines': 3,
#              'rebuild': 2,
#              'kraft': 1,
#              'liner': 1,
#              'washing': 1,
#              'Klabin': 1,
#              'Tel\x97maco': 1,
#              'Borba': 1,
#              'Brazilian': 2,
#              'Paranè': 1,
#              'standardised': 1,
#              'met': 1,
#              'reception': 1,
#              'among': 1,
#              'Itella': 1,
#              'PLC': 2,
#              'carried': 4,
#              '88': 1,
#              'passengers': 4,
#              '35': 5,
#              'previous': 8,
#              'national': 2,
#              '03': 4,
#              'Orion': 5,
#              'Pharma': 1,
#              '425': 1,
#              'ADP': 7,
#              'News': 8,
#              'Dec': 2,
#              '11': 6,
#              'OMX': 16,
#              'OTE1V': 1,
#              '28': 5,
#              'USD': 14,
#              '368': 2,
#              'phosphate': 1,
#              'concentrator': 1,
#              'Siilinjarvi': 1,
#              'Norwegian': 5,
#              'minera': 1,
#              'By': 4,
#              'cutting': 4,
#              'trim': 1,
#              'costs': 10,
#              'KESKO': 2,
#              'FOOD': 1,
#              'LTD': 3,
#              'PRESS': 3,
#              'RELEASE': 5,
#              '04012006': 1,
#              'AT': 4,
#              '1300': 1,
#              'Food': 3,
#              'Ltd': 8,
#              'launching': 1,
#              'major': 7,
#              'TV': 1,
#              'campaign': 2,
#              'many': 3,
#              'hundred': 1,
#              'Kfood': 1,
#              'retailers': 1,
#              'Estonia': 3,
#              'overall': 3,
#              'three': 2,
#              '130': 1,
#              'Operating': 26,
#              'margin': 7,
#              '112': 1,
#              '117': 2,
#              'Cash': 4,
#              'flow': 7,
#              'negative': 4,
#              '686': 1,
#              'addition': 8,
#              'Kone': 5,
#              'twoyear': 1,
#              'maintenance': 7,
#              'escalators': 6,
#              'elevators': 7,
#              'KONE': 4,
#              'March': 5,
#              'Sir': 1,
#              'Robert': 1,
#              'McAlpine': 1,
#              'Watermark': 1,
#              'Place': 1,
#              'City': 1,
#              'generated': 2,
#              'thirtyone': 1,
#              'consecutive': 2,
#              'quarters': 2,
#              'EBITDA': 5,
#              'Mr': 3,
#              'Priit': 1,
#              'Kasak': 1,
#              'Balti': 1,
#              'Metsamasina': 1,
#              'owner': 2,
#              'Rakverebased': 1,
#              'wishes': 1,
#              'Valmet': 1,
#              '27': 8,
#              'couple': 2,
#              'years': 11,
#              'Stora': 4,
#              'Enso': 3,
#              'thirdquarter': 2,
#              'doubled': 2,
#              '197mn': 1,
#              'narrows': 1,
#              'EUR2': 6,
#              '9mo': 1,
#              'hardware': 2,
#              'Elektrobit': 1,
#              'EBG1V': 1,
#              'EUR35': 1,
#              ...})

# %%
positiveValues.items()
#o/p is a dictionary with the word in news column as key and its count within the train dataset as its corresponding value
# Out:
# dict_items([('It', 10), ('also', 26), ('strengthen', 10), ('Ruukki', 12), ('offshore', 4), ('business', 24), ('', 2207), ('Efore', 2), ('results', 4), ('last', 22), ('quarter', 62), ('showed', 3), ('even', 3), ('faster', 2), ('improvement', 6), ('company', 135), ('managed', 2), ('better', 5), ('source', 1), ('components', 4), ('Romania', 2), ('local', 7), ('arm', 1), ('Finnish', 110), ('metal', 4), ('producer', 3), ('increased', 53), ('capital', 12), ('900000', 1), ('euro', 29), ('114', 4), ('mln', 62), ('cash', 6), ('contribution', 2), ('reported', 12), ('September', 11), ('19', 7), ('2006', 34), ('The', 168), ('representative', 4), ('body', 1), ('Swedish', 9), ('Meats', 1), ('approved', 4), ('improved', 11), ('offer', 3), ('HK', 2), ('Ruokatalo', 2), ('acquire', 5), ('In', 39), ('third', 14), ('2010', 64), ('net', 98), ('sales', 105), ('52', 2), ('EUR', 228), ('2055', 1), ('mn', 129), ('operating', 44), ('profit', 99), ('349', 2), ('235', 2), ('Our', 5), ('superior', 2), ('customer', 7), ('centricity', 1), ('expertise', 6), ('digital', 4), ('services', 34), ('set', 5), ('us', 5), ('apart', 1), ('competitors', 2), ('This', 10), ('much', 2), ('process', 8), ('using', 3), ('virgin', 1), ('paper', 11), ('requires', 1), ('less', 1), ('transportation', 2), ('wood', 5), ('pulp', 4), ('places', 1), ('like', 1), ('Finland', 45), ('Canada', 1), ('lifting', 2), ('equipment', 16), ('maker', 22), ('Konecranes', 4), ('Oyj', 49), ('said', 126), ('July', 9), ('30', 12), ('2008', 55), ('rose', 49), ('712', 1), ('1111', 1), ('first', 36), ('half', 4), ('571', 1), ('891', 1), ('period', 80), ('2007', 41), ('Both', 11), ('record', 11), ('high', 4), ('history', 3), ('estimated', 11), ('synergy', 1), ('benefits', 1), ('least', 3), ('EUR7m', 1), ('annually', 3), ('construction', 19), ('markets', 9), ('still', 4), ('experiencing', 1), ('4', 10), ('annual', 9), ('growth', 26), ('Besides', 1), ('share', 33), ('meat', 3), ('various', 1), ('sausages', 1), ('offering', 8), ('number', 9), ('new', 44), ('tastes', 1), ('grill', 1), ('products', 22), ('shish', 1), ('kebabs', 1), ('segment', 1), ('Paavel', 1), ('Very', 1), ('recommendable', 1), ('Nokian', 7), ('Z', 1), ('G2', 1), ('according', 3), ('ADAC', 3), ('judgement', 1), ('latest', 3), ('summer', 2), ('tyre', 1), ('test', 3), ('German', 1), ('automobile', 2), ('association', 3), ('Sales', 13), ('10', 16), ('pct', 14), ('566', 1), ('eur', 19), ('back', 3), ('strong', 13), ('volume', 7), ('favourable', 3), ('currency', 3), ('effects', 1), ('reporting', 4), ('grew', 18), ('432', 1), ('6', 15), ('million', 114), ('Neste', 3), ('Oil', 4), ('awarded', 23), ('Chemical', 3), ('Industry', 2), ('Federation', 1), ('Innovation', 1), ('Award', 1), ('NExBTL', 1), ('technology', 26), ('enables', 4), ('biodiesel', 2), ('produced', 2), ('vegetable', 1), ('oil', 5), ('animal', 2), ('fat', 2), ('SRV', 3), ('raise', 5), ('holding', 3), ('majority', 1), ('Rautaruukki', 6), ('Corporation', 27), ('Stock', 2), ('exchange', 4), ('release', 9), ('3', 17), ('December', 8), ('2009', 68), ('12', 11), ('noon', 1), ('engineering', 11), ('divisions', 2), ('improve', 11), ('adjust', 2), ('operations', 28), ('Jens', 1), ('SchulteBockum', 1), ('Vodafone', 2), ('global', 9), ('director', 5), ('terminals', 1), ('expects', 11), ('sell', 5), ('one', 10), ('two', 11), ('125', 2), ('225', 1), ('models', 2), ('year', 75), ('launch', 7), ('potentially', 1), ('tens', 1), ('millions', 1), ('lifetime', 1), ('device', 3), ('Finnishowned', 1), ('contract', 39), ('manufacturer', 9), ('electronics', 4), ('Elcoteq', 4), ('Hungary', 3), ('Kft', 1), ('announced', 12), ('plans', 9), ('recruit', 2), ('650', 1), ('staffers', 1), ('fulfill', 1), ('orders', 13), ('Pcs', 1), ('plants', 4), ('Australian', 1), ('Mirabela', 2), ('Nickel', 1), ('Outokumpu', 6), ('Technology', 5), ('grinding', 2), ('nickel', 2), ('sulfide', 1), ('project', 10), ('Bahia', 2), ('State', 1), ('Brazil', 3), ('Consumers', 1), ('well', 19), ('received', 10), ('packed', 1), ('fresh', 1), ...

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive=pd.DataFrame(sorted(positiveValues.items(),key=lambda x:x[1],reverse=True))
df_negative=pd.DataFrame(sorted(negativeValues.items(),key=lambda x:x[1],reverse=True))
df_neutral=pd.DataFrame(sorted(neutralValues.items(),key=lambda x:x[1],reverse=True))

# %%
pd1=df_positive[0][:10]
pd2=df_positive[1][:10]

ned1=df_negative[0][:10]
ned2=df_negative[1][:10]

nud1=df_neutral[0][:10]
nud2=df_neutral[1][:10]


plt.figure(1,figsize=(16,4))

plt.bar(pd1,pd2, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-UNIGRAM ANALYSIS")

plt.savefig("positive-unigram.png")
plt.show()

# %%
df_positive.head(10)
# Out:
#          0     1
# 0           2207
# 1      EUR   228
# 2      The   168
# 3  company   135
# 4       mn   129
# 5     said   126
# 6  million   114
# 7  Finnish   110
# 8    sales   105
# 9   profit    99

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1,ned2, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-UNIGRAM ANALYSIS")

plt.savefig("negative-unigram.png")
plt.show()

# %%
df_negative.head(10)
# Out:
#          0     1
# 0           1057
# 1      EUR   194
# 2       mn   136
# 3   profit    82
# 4      The    66
# 5  company    61
# 6  Finnish    61
# 7    sales    60
# 8  million    56
# 9     2008    54

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1,nud2, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-UNIGRAM ANALYSIS")

plt.savefig("neutral-unigram.png")
plt.show()

# %%
df_neutral.head(10)
# Out:
#           0     1
# 0            4361
# 1       The   575
# 2   company   294
# 3      said   143
# 4   Finland   137
# 5   Finnish   127
# 6       EUR   118
# 7   million   108
# 8  business    96
# 9     sales    95

# %% [markdown]
# **Creating bigrams**

# %%
positiveValues2=defaultdict(int)
negativeValues2=defaultdict(int)
neutralValues2=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text,2):
    positiveValues2[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text,2):
    negativeValues2[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text,2):
    neutralValues2[word]+=1
# Out:
# Sentence after removing stopwords: ['It', 'also', 'strengthen', 'Ruukki', 'offshore', 'business', '']
# Sentence after removing stopwords: ['Efore', 'results', 'last', 'quarter', 'showed', 'even', 'faster', 'improvement', 'company', 'managed', 'better', 'source', 'components', '']
# Sentence after removing stopwords: ['Ruukki', 'Romania', '', 'local', 'arm', 'Finnish', 'metal', 'producer', 'Ruukki', '', 'increased', 'capital', '900000', 'euro', '', '', '114', 'mln', '', 'cash', 'contribution', '', 'reported', 'September', '19', '', '2006', '']
# Sentence after removing stopwords: ['The', 'representative', 'body', 'Swedish', 'Meats', 'approved', 'improved', 'offer', 'Finnish', 'HK', 'Ruokatalo', 'acquire', 'company', '']
# Sentence after removing stopwords: ['In', 'third', 'quarter', '2010', '', 'net', 'sales', 'increased', '52', '', 'EUR', '2055', 'mn', '', 'operating', 'profit', '349', '', 'EUR', '235', 'mn', '']
# Sentence after removing stopwords: ['Our', 'superior', 'customer', 'centricity', 'expertise', 'digital', 'services', 'set', 'us', 'apart', 'competitors', '']
# Sentence after removing stopwords: ['This', 'much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'Finland', 'Canada', '']
# Sentence after removing stopwords: ['Finnish', 'lifting', 'equipment', 'maker', 'Konecranes', 'Oyj', 'said', 'July', '30', '', '2008', 'net', 'profit', 'rose', '712', 'mln', 'euro', '', '', '1111', 'mln', '', 'first', 'half', '2008', '571', 'mln', 'euro', '', '', '891', 'mln', '', 'period', '2007', '']
# Sentence after removing stopwords: ['Both', 'net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history', '']
# Sentence after removing stopwords: ['The', 'estimated', 'synergy', 'benefits', 'least', 'EUR7m', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'Swedish', 'construction', 'markets', 'still', 'experiencing', 'estimated', '4', '', 'annual', 'growth', '2008', '']
# Sentence after removing stopwords: ['Besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', '', '', 'Paavel', 'said', '']
# Sentence after removing stopwords: ['', 'Very', 'recommendable', '', 'Nokian', 'Z', 'G2', 'according', '', 'ADAC', 'judgement', '', 'latest', 'summer', 'tyre', 'test', 'German', 'automobile', 'association', 'ADAC', '']
# Sentence after removing stopwords: ['Sales', 'rose', '10', 'pct', '566', 'mln', 'eur', 'back', 'strong', 'volume', 'favourable', 'currency', 'effects', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'company', 'operating', 'profit', 'grew', '432', '', 'EUR', '6', 'million', '']
# Sentence after removing stopwords: ['Finland', 'Neste', 'Oil', 'awarded', 'Chemical', 'Industry', 'Federation', 'Finland', 'Innovation', 'Award', 'NExBTL', 'technology', '', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat', '']
# Sentence after removing stopwords: ['SRV', 'raise', 'holding', 'company', 'summer', '2008', '', 'majority', '']
# Sentence after removing stopwords: ['Rautaruukki', 'Corporation', 'Stock', 'exchange', 'release', '3', 'December', '2009', '12', 'noon', 'Ruukki', 'construction', 'engineering', 'divisions', 'improve', 'adjust', 'operations', 'Finland', '']
# Sentence after removing stopwords: ['Jens', 'SchulteBockum', '', 'Vodafone', 'global', 'director', 'terminals', '', 'said', 'company', 'expects', 'sell', 'one', 'two', 'million', 'Vodafone', '125', '225', 'models', 'first', 'year', 'launch', '', 'potentially', 'tens', 'millions', 'lifetime', 'device', '']
# Sentence after removing stopwords: ['Finnishowned', 'contract', 'manufacturer', 'electronics', 'Elcoteq', 'Hungary', 'Kft', 'announced', 'plans', 'recruit', '650', 'new', 'staffers', 'fulfill', 'new', 'orders', 'Pcs', '', 'company', 'two', 'plants', '']
# Sentence after removing stopwords: ['The', 'Australian', 'company', 'Mirabela', 'Nickel', 'awarded', 'Outokumpu', 'Technology', 'contract', 'grinding', 'technology', 'nickel', 'sulfide', 'project', 'Bahia', 'State', '', 'Brazil', '']
# Sentence after removing stopwords: ['', 'Consumers', 'well', 'received', 'packed', 'fresh', 'meat', '']
# Sentence after removing stopwords: ['Fiskars', 'strong', 'portfolio', 'international', 'brands', '', 'include', 'Fiskars', '', 'Iittala', '', 'Gerber', '', 'Silva', 'Buster', '']
# Sentence after removing stopwords: ['Nokia', 'Elisa', 'work', 'together', 'bring', 'superior', 'mobile', 'gaming', 'experience', 'Elisa', 'customers', '']
# Sentence after removing stopwords: ['The', 'company', 'established', '3G', 'base', 'station', '17000', 'feet', 'foot', 'Mount', 'Everest', 'enable', 'mountain', 'climbers', '29035foot', 'summit', 'surf', 'Internet', 'even', 'send', 'videos', 'exploits', '']
# Sentence after removing stopwords: ['Finnish', 'Outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'OZK', 'Kardzhali', 'zinc', 'smelter', 'Bulgaria', '']
# Sentence after removing stopwords: ['A', 'Helsinki', '', 'ELIiV', 'today', 'reported', 'EPS', 'EUR1', '13', '2009', '', 'increase', 'EPS', 'EUR1', '12', '2008', '']
# Sentence after removing stopwords: ['Q1', '2010', '18', 'May', '2010', '', 'Finnish', 'electrical', 'components', 'maker', 'Salcomp', 'Oy', '', 'HEL', '', 'SAL1V', '', 'said', 'today', 'turned', 'net', 'profit', 'EUR1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'EUR2m', 'corresponding', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['In', 'JanuarySeptember', '2010', '', 'Fiskars', '', 'net', 'profit', 'went', '14', '', 'yearonyear', 'EUR', '654', 'million', 'net', 'sales', 'EUR', '5253', 'million', 'EUR', '4877', 'million', '']
# Sentence after removing stopwords: ['The', 'transaction', 'line', 'Aspo', 'strategy', 'expand', 'Baltic', 'Sea', 'region', 'eastern', 'markets', '']
# Sentence after removing stopwords: ['', 'UPMKymmene', 'upgraded', '', 'inline', '', '', 'underperform', '', 'Goldman', 'Sachs', '']
# Sentence after removing stopwords: ['The', 'Lithuanian', 'beer', 'market', 'made', '1441', 'million', 'liters', 'January', '', 'rise', '08', 'percent', 'yearearlier', 'figure', '', 'Lithuanian', 'Brewers', '', 'Association', 'reporting', 'citing', 'results', 'members', '']
# Sentence after removing stopwords: ['We', 'capitalize', 'experience', 'number', 'similar', 'bridge', 'projects', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['', 'The', 'CHF', 'great', 'product', '']
# Sentence after removing stopwords: ['The', 'group', 'expand', 'chain', 'include', '45', 'stores', '']
# Sentence after removing stopwords: ['We', 'aim', 'ensure', 'Vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', '', '', 'comments', 'Vacon', 'Plc', 'President', 'CEO', 'Vesa', 'Laisi', '']
# Sentence after removing stopwords: ['The', 'cooperation', 'double', 'The', 'Switch', 'converter', 'capacity', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', '', 'EPS', '', 'first', 'quarter', '2007', 'amounted', 'EUR0', '07', '', 'EUR0', '04', '']
# Sentence after removing stopwords: ['1', 'Block', 'lamp', 'Harri', 'Koskinen', 'light', 'introduced', '1996', 'bestseller', 'ever', 'since', '']
# Sentence after removing stopwords: ['Nordea', 'sees', 'return', 'positive', 'growth', 'Baltic', 'countries', '2011', '']
# Sentence after removing stopwords: ['3', 'January', '2011', '', 'Finnish', 'flag', 'carrier', 'Finnair', 'Oyj', '', 'HEL', '', 'FIA1S', '', 'said', 'today', 'sealed', 'nineyear', 'sale', 'leaseback', 'agreement', 'newest', 'Airbus', 'A330', 'aircraft', 'syndication', 'Japanese', 'operating', 'lease', 'market', '']
# Sentence after removing stopwords: ['Growth', 'expected', 'continue', '2008', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'guided', 'EBIT', 'sales', 'growth', '20', 'pct', '10', 'pct', 'respectively', 'year', '']
# Sentence after removing stopwords: ['The', 'program', 'target', 'structural', 'cost', 'reductions', 'EUR', '30mn', '2009', '']
# Sentence after removing stopwords: ['Revenue', 'grew', '12', 'percent', '', '', 'x20ac', '', '36', 'billion', '', 'US', '45', 'billion', '', '']
# Sentence after removing stopwords: ['', 'The', 'second', 'quarter', '2010', 'firstquarter', 'growth', 'net', 'sales', 'since', 'third', 'quarter', 'of2008', '', '', 'said', 'Magnus', 'Rosen', '', 'Ramirent', 'CEO', '']
# Sentence after removing stopwords: ['The', 'stock', 'price', 'rose', '700', 'ores', '09', '', 'close', 'SEK77', '65', '', 'ending', 'twoday', 'streak', 'losses', '']
# Sentence after removing stopwords: ['Hkan', 'Dahlstr¦m', '', 'head', 'mobility', 'services', 'TeliaSonera', '', 'forecast', 'mobile', 'data', 'volume', 'TeliaSonera', 'network', 'Sweden', 'rise', 'eightfold', '200000', 'TB', '2014', '']
# Sentence after removing stopwords: ['Press', 'release', '9', 'October', '2009', 'Ruukki', 'signed', 'contract', 'deliver', 'install', 'steel', 'structures', 'bridge', 'Kyronsalmi', 'strait', 'Savonlinna', '', 'Finland', '']
# Sentence after removing stopwords: ['Finland', 'leading', 'metals', 'group', 'Outokumpu', 'said', 'fourthquarter', 'net', 'profit', 'tripled', 'back', 'strong', 'global', 'demand', 'stainless', 'steel', '', 'soaring', 'base', 'metal', 'prices', 'proceeds', 'sale', 'technology', 'unit', '']
# Sentence after removing stopwords: ['Previously', '', 'EB', 'delivered', 'custom', 'solution', 'LG', 'Electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators', '']
# Sentence after removing stopwords: ['Finnish', 'telecoms', 'software', 'developer', 'Tecnomen', 'Oyj', 'said', 'December', '5', '', '2006', '', '33', 'mln', '', '25', 'mln', 'euro', '', 'order', 'supply', 'expansion', 'charging', 'messaging', 'systems', 'mobile', 'fixed', 'networks', 'Brasil', 'Telecom', '']
# Sentence after removing stopwords: ['Kesko', 'pursues', 'strategy', 'healthy', '', 'focused', 'growth', 'concentrating', 'sales', 'services', 'consumercustomers', '']
# Sentence after removing stopwords: ['Ixonos', 'estimates', 'hire', '20', 'specialists', 'mechanical', 'engineering', '', 'electronics', 'design', '', 'RD', 'new', 'unit', 'Jyvaeskylae', 'end', '2009', '']
# Sentence after removing stopwords: ['', 'Our', 'customer', 'satisfied', 'Basware', 'Invoice', 'Automation', 'solution', 'extends', 'implementation', 'new', 'geographies', '']
# Sentence after removing stopwords: ['Salo', '', 'Finland', '', '29', 'August', '2006', '', 'Benefon', 'today', 'announced', 'plans', 'strengthen', 'inhouse', 'technology', 'platform', '', 'licensing', 'complete', 'mobile', 'software', 'platform', '', 'Opna', '', 'longstanding', 'technology', 'partner', '', 'Pollex', '']
# Sentence after removing stopwords: ['Profit', 'per', 'share', 'EUR', '103', '', 'EUR', '087', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Retail', 'wholesale', 'group', 'Kesko', 'reported', 'net', 'sales', '6594', 'mln', 'eur', 'February', '', 'increase', '108', 'pct', 'yearonyear', '']
# Sentence after removing stopwords: ['', 'We', 'pleased', 'working', 'Fujitsu', 'NTT', 'DoCoMo', 'advance', 'progress', 'LTE', '', '', 'said', 'Juergen', 'Walter', '', 'Head', 'Converged', 'Core', '', 'Nokia', 'Siemens', 'Networks', '']
# Sentence after removing stopwords: ['SINGAPORE', '', 'ICIS', '', '', '', '1', '', 'Kemira', 'Indian', 'water', 'infrastructure', 'firm', '', '2', '', 'IVRCL', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'Andhra', 'Pradesh', 'state', '', 'India', '', 'Finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'Tuesday', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'totalled', 'EUR', '20', 'mn', '', 'compared', 'loss', 'EUR', '1592', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['London', 'leading', 'shares', 'today', 'jumped', 'almost', '100', 'points', '', '17', '', '', 'market', 'opened', '']
# Sentence after removing stopwords: ['Net', 'sales', 'increased', 'EUR193', '3', 'EUR179', '9', 'pretax', 'profit', 'rose', '342', '', 'EUR43', '1', '', 'EUR1', '', 'USD1', '4', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['A', 'new', 'production', 'line', 'completed', 'contract', 'production', 'hormone', 'treatments', '']
# Sentence after removing stopwords: ['Kaupthing', 'forecasts', 'significant', 'price', 'increase', 'printing', 'paper', '2007', '']
# Sentence after removing stopwords: ['Rautaruukki', 'said', 'construction', 'group', 'YIT', 'awarded', '25', 'mln', 'eur', 'contract', 'supply', 'steel', 'structures', 'new', 'bridge', 'spanning', 'Kemijoki', 'river', 'Northern', 'Finland', '']
# Sentence after removing stopwords: ['When', 'open', 'next', 'year', '', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat', '']
# Sentence after removing stopwords: ['It', 'also', 'strong', 'assets', 'electronic', 'media', '', 'employing', '18500', 'increase', '9', 'percent', 'last', 'year', '']
# Sentence after removing stopwords: ['These', 'companies', 'able', 'keep', 'market', 'positions', '']
# Sentence after removing stopwords: ['A', 'memorandum', 'understanding', 'cooperation', 'Finnish', 'Global', 'Chemical', 'Company', 'KEMIRA', 'Vietnam', 'National', 'Chemicals', 'Group', '', 'Vinachem', '', 'signed', 'occasion', '']
# Sentence after removing stopwords: ['Furthermore', '', 'Bunge', 'also', 'sign', 'licensing', 'agreement', 'Sunnuntai', 'Carlshamn', 'Mejeri', 'brands', '']
# Sentence after removing stopwords: ['', 'IH', '', 'move', 'enhance', 'growth', '']
# Sentence after removing stopwords: ['Q1', '10', '19', 'April', '2010', '', 'Finnish', 'forest', 'machinery', 'equipment', 'maker', 'Ponsse', 'Oyj', 'HEL', '', 'PON1V', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'EUR6', '3', 'first', 'quarter', '2010', '', 'EUR9', '6', 'loss', 'year', 'earlier', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['Also', '', 'bringing', '', 'right', 'kind', 'people', '', 'upgrade', 'human', 'resources', '']
# Sentence after removing stopwords: ['In', 'release', '', 'Company', 'said', 'Vocollect', 'T2', 'customers', 'North', 'America', 'take', 'advantage', 'Voice', 'Directed', 'Warehousing', 'solution', 'increase', 'warehouse', 'efficiency', 'productivity', 'gains', 'discounted', 'price', '']
# Sentence after removing stopwords: ['Olvi', '', 'controls', '94', 'percent', 'stake', 'Ragutis', 'A', 'Le', 'Coq', '', 'said', 'annual', 'report', 'published', 'earlier', 'year', 'Lithuanian', 'brewery', 'sales', 'reached', '1504', 'million', 'euros', 'last', 'year', '', 'rise', '204', 'percent', '1249', 'million', 'euros', '2004', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['In', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'loss', 'narrowed', 'EUR', '415000', 'EUR', '74', 'million', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['The', 'District', 'Court', 'Helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005', '']
# Sentence after removing stopwords: ['EPS', 'continuing', 'operations', 'came', '030', 'eur', '', '017', '']
# Sentence after removing stopwords: ['Production', 'expand', 'Elcoteq', 'locations', 'including', 'Mexico', 'Hungary', '2010', '']
# Sentence after removing stopwords: ['Advertising', 'circulation', 'revenues', 'grew', '34', '', '04', '', '', 'respectively', '']
# Sentence after removing stopwords: ['It', 'solid', 'credit', 'compared', 'DZ', 'Bank', 'Rabobank', '']
# Sentence after removing stopwords: ['The', 'longstanding', 'partnership', 'commitment', 'enable', 'parties', 'develop', 'respective', 'operations', '', 'ESL', 'Shipping', 'also', 'opportunity', 'update', 'fleet', 'improve', 'efficiency', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Metso', 'said', 'upgrade', 'one', 'UPMKymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'Jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', '', 'machine', 'process', 'controls', 'quality', 'measurements', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'net', 'sales', 'rose', '8', '', 'yearonyear', 'EUR64', '3', '', 'due', 'business', 'acquisitions', 'realized', 'first', 'half', '200809', '', 'effect', 'EUR10', '9', 'review', 'period', '']
# Sentence after removing stopwords: ['Exports', 'grew', '165', 'percent', '191', 'million', 'liters', '']
# Sentence after removing stopwords: ['', 'The', 'lowering', 'prices', 'us', 'competitors', 'shows', 'real', 'estate', 'market', 'stabilised', 'returned', 'balance', 'apartments', 'acquiring', 'fair', 'price', 'eyes', 'clients', '']
# Sentence after removing stopwords: ['Sales', 'Latin', 'America', 'increased', '42', '', 'EUR', '432mn', '', 'total', '87', 'mn', 'mobile', 'devices', 'sold', 'area', '', 'representing', 'increase', '32', '', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'supply', 'WCDMA', '3GHSPA', 'radio', 'network', '', 'including', 'modular', '', 'high', 'capacity', 'Nokia', 'Flexi', 'WCDMA', 'base', 'station', 'East', 'Java', '', 'Bali', '', 'Sumatra', 'Batam', '']
# Sentence after removing stopwords: ['In', 'first', 'quarter', '2010', '', 'marktomarket', 'result', 'pretax', 'profit', 'EUR', '133', 'million', 'versus', 'loss', 'EUR', '32', 'million', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', '', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'Klabin', 'Tel\x97maco', 'Borba', 'mill', 'Brazilian', 'state', 'Paranè', '']
# Sentence after removing stopwords: ['Our', 'standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'Itella', '']
# Sentence after removing stopwords: ['Finnair', 'PLC', 'carried', 'record', '88', 'million', 'passengers', '2006', '', 'increase', '35', 'percent', 'previous', 'year', '', 'Finnish', 'national', 'carrier', 'reported', 'Tuesday', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', 'EPS', 'amounted', 'EUR0', '03', '', 'loss', 'EUR0', '08', '']
# Sentence after removing stopwords: ['Orion', 'Pharma', 'operating', 'profit', 'increased', '425', '', '2004', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Dec', '11', '', '2008', '', 'Finnish', 'construction', 'engineering', 'company', 'Outotec', 'Oyj', '', 'OMX', '', 'OTE1V', '', 'said', 'today', 'EUR', '28', 'million', '', 'USD', '368', '', 'order', 'expand', 'phosphate', 'concentrator', 'Siilinjarvi', 'Norwegian', 'minera']
# Sentence after removing stopwords: ['By', 'cutting', 'number', 'plants', '', 'group', 'trim', 'fixed', 'costs', '']
# Sentence after removing stopwords: ['KESKO', 'FOOD', 'LTD', 'PRESS', 'RELEASE', '04012006', 'AT', '1300', 'Kesko', 'Food', 'Ltd', 'launching', 'major', 'TV', 'campaign', 'recruit', 'many', 'one', 'hundred', 'new', 'Kfood', 'retailers', '']
# Sentence after removing stopwords: ['Estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'margin', 'increased', '112', '', '117', '', '']
# Sentence after removing stopwords: ['Cash', 'flow', 'operations', 'totalled', 'EUR', '74', 'mn', '', 'compared', 'negative', 'EUR', '686', 'mn', 'second', 'quarter', '2008', '']
# Sentence after removing stopwords: ['In', 'addition', '', 'Kone', 'signed', 'twoyear', 'maintenance', 'contract', 'escalators', '']
# Sentence after removing stopwords: ['Finnish', 'elevators', 'escalators', 'maker', 'KONE', 'Corporation', 'said', 'Tuesday', '', '18', 'March', '', 'received', 'major', 'order', 'Sir', 'Robert', 'McAlpine', 'supply', 'elevators', 'escalators', 'Watermark', 'Place', 'project', 'City', 'London', '']
# Sentence after removing stopwords: ['UPMKymmene', 'generated', 'thirtyone', 'consecutive', 'quarters', 'positive', 'EBITDA', '']
# Sentence after removing stopwords: ['Mr', 'Priit', 'Kasak', '', 'Balti', 'Metsamasina', 'owner', '', 'said', 'Rakverebased', 'company', 'wishes', 'increase', 'Valmet', 'market', 'share', '27', '', 'third', 'couple', 'years', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'thirdquarter', 'pretax', 'profit', 'doubled', 'EUR', '197mn', '']
# Sentence after removing stopwords: ['narrows', 'EUR2', '8', '9mo', '09', '29', 'October', '2009', '', 'Finnish', 'software', 'hardware', 'developer', 'Elektrobit', 'Oyj', 'HEL', '', 'EBG1V', '', 'EB', '', 'said', 'today', 'net', 'loss', 'narrowed', 'EUR2', '8', 'first', 'nine', 'months', '2009', 'EUR35', '6', 'period', 'year', 'ago', '']
# Sentence after removing stopwords: ['Tim', 'Cockroft', 'brings', 'excellent', 'track', 'record', '18', 'years', 'experience', '', 'moreover', '', 'Tim', 'successfully', 'developed', 'Capital', 'Markets', 'operations', 'Kaupthing', 'Singer', '', 'Friedlander', 'involving', 'corporate', 'finance', 'broking', 'focus', 'midmarket', 'companies', '']
# Sentence after removing stopwords: ['The', 'company', 'net', 'profit', 'amounted', 'EE', '555', 'mn', '', '36', '', '2004', '']
# Sentence after removing stopwords: ['VDW', 'combined', 'LXE', 'devices', 'enhances', 'productivity', '', 'enabling', 'workers', 'use', 'single', 'device', 'perform', 'voice', '', 'scanning', 'keyboard', 'functions', '']
# Sentence after removing stopwords: ['The', 'longterm', 'contract', 'global', '']
# Sentence after removing stopwords: ['In', 'Homeware', 'area', '', 'Fiskars', 'provides', 'leading', 'branded', 'products', 'home', '', 'kitchen', '', 'interior', 'design', '']
# Sentence after removing stopwords: ['The', 'loss', 'third', 'quarter', '2007', 'EUR', '03', 'mn', 'smaller', 'loss', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'airline', 'Finnair', 'deal', 'UK', 'public', 'sector', 'official', 'airline', 'flights', 'London', 'Heathrow', 'Osaka', 'Japan', '', 'well', 'flights', 'Manchester', 'UK', 'Helsinki', 'Finland', '']
# Sentence after removing stopwords: ['Finnish', 'Ahlstrom', 'Corporation', 'double', 'investments', 'new', 'specialty', 'glassfiber', 'reinforcement', 'plant', 'South', 'Carolina', '', 'US', '']
# Sentence after removing stopwords: ['Speaking', 'justdrinks', 'today', '', 'spokesperson', 'Olvi', 'said', '', '', 'We', 'performed', 'well', 'four', 'countries', 'operate', '', 'namely', '', 'Finland', '', 'Estonia', '', 'Latvia', 'Lithuania', '', '']
# Sentence after removing stopwords: ['The', 'company', 'strength', 'Apetit', 'brand', '']
# Sentence after removing stopwords: ['Both', 'loans', 'used', 'finance', 'strategic', 'investments', 'shopping', 'center', 'redevelopment', 'projects', 'refinancing', 'maturing', 'debt', '']
# Sentence after removing stopwords: ['In', 'fourth', 'quarter', '2009', '', 'Atria', 'net', 'loss', 'shrank', 'EUR', '12', 'million', 'EUR', '59', 'million', 'net', 'sales', 'contracted', 'EUR', '3404', 'million', 'EUR', '3611', 'million', '']
# Sentence after removing stopwords: ['European', 'traffic', 'grew', 'nearly', '30', '', '']
# Sentence after removing stopwords: ['The', 'CL51', 'designed', 'measure', 'cloud', 'base', 'height', 'vertical', 'visibility', 'weather', 'conditions', '', 'makes', 'ideal', 'instrument', 'meteorological', 'applications', 'rely', 'reliable', 'cloud', 'height', 'detection', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '1034', 'mn', 'EUR', '232', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Nokian', 'Tyres', 'reported', 'fourth', 'quarter', 'pretax', 'profit', '615', 'mln', 'eur', '', '486', 'mln', 'back', 'strong', 'sales', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'increased', '45', '', 'EUR', '314', 'mn', 'EUR', '300', 'mn', '2004', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'Nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout', '']
# Sentence after removing stopwords: ['Atria', 'Group', 'leading', 'Scandinavian', 'meat', 'products', 'group', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'accounts', '50', '', 'poultry', 'sales', 'Finland', '', 'profitability', 'good', 'level', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'property', 'portfolio', 'doubled', 'result', 'Kapiteeli', 'acquisition', 'totalled', 'EUR', '26862', '12597', 'million', '']
# Sentence after removing stopwords: ['Finland', 'Poyry', 'Energy', 'contract', 'advise', 'builders', 'new', 'cogeneration', 'power', 'plant', 'Lithuania', 'secondbiggest', 'city', 'Kaunas', 'supervise', 'construction', 'process', '']
# Sentence after removing stopwords: ['Finnair', 'expands', '', 'Finnair', 'plans', 'add', 'flights', 'routes', 'Hong', 'Kong', '', 'India', 'Russia', '']
# Sentence after removing stopwords: ['One', 'installed', 'elevators', 'doubledeck', 'elevator', '', 'enables', 'efficient', 'use', 'building', 'core', 'space', '']
# Sentence after removing stopwords: ['According', 'company', '', 'operating', 'profit', '', 'excluding', 'nonrecurring', 'items', '', 'fourth', 'quarter', '2009', 'significantly', 'better', 'expected', '', 'also', 'better', 'figures', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', '', 'buy', '', 'recommendation', 'reiterated', '']
# Sentence after removing stopwords: ['Other', 'carriers', 'handset', 'makers', 'spin', 'positive', 'event', 'raise', 'interest', 'higherend', 'phones', 'pricier', 'data', 'plans', '']
# Sentence after removing stopwords: ['The', 'Ministry', 'Water', 'Tanzania', 'awarded', 'Poyry', 'water', 'sanitation', 'engineering', 'assignment', 'rehabilitation', 'extension', 'water', 'supply', 'sanitation', 'infrastructure', 'Bukoba', 'Musoma', '', 'situated', 'Lake', 'Victoria', 'northern', 'Tanzania', '']
# Sentence after removing stopwords: ['Dubbed', 'Nokia', 'Money', 'Solutions', '', 'company', 'officials', 'say', 'initiative', 'would', 'seek', 'bridge', 'gap', 'banked', 'unbanked', 'developing', 'countries', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Eesti', '', 'retailer', 'wholesaler', 'grain', '', 'agricultural', 'warehousing', 'machinery', 'accessories', '', 'net', 'sales', '81', 'million', 'euros', '2007', '', 'increase', 'onetenth', 'preceding', 'year', '']
# Sentence after removing stopwords: ['Most', 'increase', 'net', 'sales', 'due', 'acquisition', 'Swedish', 'Silva', 'produces', 'garden', 'tools', 'boats', '']
# Sentence after removing stopwords: ['UPMKymmene', 'generated', 'seventeen', 'consecutive', 'quarters', 'positive', 'Cash', 'Flow', 'Operations', '']
# Sentence after removing stopwords: ['The', 'company', 'aims', 'maintain', 'trend', 'profitability', 'current', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'Talentum', 'reports', 'operating', 'profit', 'increased', 'EUR', '205', 'mn', '2005', 'EUR', '93', 'mn', '2004', '', 'net', 'sales', 'totaled', 'EUR', '1033', 'mn', '', 'EUR', '964', 'mn', '']
# Sentence after removing stopwords: ['After', 'takeover', '', 'Cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'Latvian', 'market', '']
# Sentence after removing stopwords: ['9', 'September', '2010', '', 'Finnish', 'stationery', 'gift', 'retailer', 'Tiimari', 'HEL', '', 'TII1V', 'said', 'today', 'net', 'sales', 'rose', '2', '', 'yearonyear', 'EUR5', '7', 'August', '2010', '', 'driven', 'growth', 'Finland', '', 'demand', 'Baltics', 'remained', 'weak', '']
# Sentence after removing stopwords: ['The', 'offer', 'represents', 'premium', '24', '', 'stock', 'closing', 'price', 'Friday', '']
# Sentence after removing stopwords: ['Finland', 'national', 'carrier', 'Finnair', 'PLC', 'carried', 'record', '85', 'million', 'passengers', '2005', '', 'increase', '45', 'percent', 'previous', 'year', '', 'airline', 'reported', 'Tuesday', '']
# Sentence after removing stopwords: ['The', 'stock', 'new', 'machines', 'reasonably', 'small', 'new', 'orders', 'bring', 'work', '']
# Sentence after removing stopwords: ['The', 'optimization', 'steel', 'components', 'heating', 'process', 'reduce', 'energy', 'consumption', '']
# Sentence after removing stopwords: ['I', 'looking', 'forward', 'contribute', 'SRV', 'success', 'competence', '', '', 'says', 'Taneli', 'Hassinen', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'insurance', 'company', 'Pohjola', 'Finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', '', 'traffic', 'safety', '']
# Sentence after removing stopwords: ['The', 'Finnish', 'group', 'anticipates', 'sales', 'gain', 'EUR42m', 'tax', 'expenses', '']
# Sentence after removing stopwords: ['We', 'pleased', 'fine', 'cooperation', 'two', 'countries', 'recent', 'times', '', 'said', '']
# Sentence after removing stopwords: ['After', 'transaction', '', 'Alma', 'Media', 'raised', 'stake', 'Talentum', '3065', '', 'shares', '3112', '', 'voting', 'rights', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['Overall', '', '50', 'percent', 'respondents', 'confident', 'security', 'banking', 'online', '']
# Sentence after removing stopwords: ['The', 'agreement', 'signed', 'Biohit', 'Healthcare', 'Ltd', '', 'UKbased', 'subsidiary', 'Biohit', 'Oyj', '', 'Finnish', 'public', 'company', 'develops', '', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'announce', 'support', 'Intel', 'based', 'handheld', 'platforms', '', 'capabilities', 'made', 'development', 'easier', 'faster', '']
# Sentence after removing stopwords: ['Ruukki', 'signed', 'contract', 'Norwegian', 'company', 'Veidekke', 'Entreprenor', 'AS', '']
# Sentence after removing stopwords: ['Compared', 'FTSE', '100', 'index', '', 'rose', '283', 'points', '05', '', 'day', '', 'relative', 'price', 'change', '23', '', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['The', 'EBITDA', 'EUR116m', 'compared', 'EUR115m', '', 'corresponding', 'EBITDA', 'margin', '33', '', '']
# Sentence after removing stopwords: ['For', 'current', 'year', '', 'Raute', 'expects', 'net', 'sales', 'increase', 'operating', 'result', '', 'positive', '']
# Sentence after removing stopwords: ['The', 'company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', '', 'adding', '', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year', '', '']
# Sentence after removing stopwords: ['The', 'company', 'operating', 'income', '', 'EBIT', '', 'totalled', 'EUR', '00', 'mn', '', 'EUR', '03', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'Kalmar', 'received', 'significant', 'order', 'US', 'Department', 'Defense', '']
# Sentence after removing stopwords: ['These', 'moderate', 'significant', 'changes', 'resulted', 'significant', '2432', '', 'reduction', 'estimated', 'CVD', 'risk', '']
# Sentence after removing stopwords: ['', 'The', 'priority', '2009', 'strengthen', 'company', 'balance', 'sheet', 'increase', 'cash', 'flow', '', '', 'CEO', 'Hannu', 'Krook', 'said', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '1019', 'mn', 'EUR', '1007', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['The', 'company', 'consolidated', 'operating', 'profit', 'amounted', 'EUR', '1586', 'mn', '', 'EUR', '414', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Turnover', 'rose', 'EUR21m', 'EUR17m', '']
# Sentence after removing stopwords: ['Diluted', 'EPS', 'rose', 'EUR3', '68', 'EUR0', '50', '']
# Sentence after removing stopwords: ['OriolaKD', 'expects', 'invoicing', '2008', 'higher', 'comparable', 'invoicing', '2007', '']
# Sentence after removing stopwords: ['CEO', 'company', 'Tarmo', 'Noop', 'said', 'growth', 'sale', 'premium', 'beers', 'biggest', '']
# Sentence after removing stopwords: ['Sales', 'climbed', '192', 'pct', '1002', 'bln', 'eur', '', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure', '']
# Sentence after removing stopwords: ['Sales', 'Department', 'Store', 'Division', 'increased', '15', '', 'sales', 'clothing', 'store', 'subsidiary', 'Seppala', 'increased', '8', '', 'Meanwhile', 'sales', 'Hobby', 'Hall', 'decreased', '12', '', '']
# Sentence after removing stopwords: ['The', 'terms', 'financing', 'approved', 'Annual', 'General', 'Meeting', 'Company', 'held', 'June', '30', '', '2010', '']
# Sentence after removing stopwords: ['', 'They', 'would', 'invest', 'physical', 'infrastructure', '', 'would', 'also', 'provide', 'knowhow', 'managing', 'developing', 'science', 'technology', 'parks', '', '', 'said', 'Sunrise', 'Valley', 'director', 'Andrius', 'Bagdonas', '']
# Sentence after removing stopwords: ['The', 'Group', 'aims', 'increase', 'net', 'sales', 'comparable', 'operating', 'profit', '2006', '']
# Sentence after removing stopwords: ['Finnish', 'food', 'company', 'Raisio', 'Oyj', 'HEL', '', 'RAIVV', 'said', 'today', 'buy', 'British', 'snacks', 'confectionery', 'company', 'Big', 'Bear', 'Group', 'plc', 'enterprise', 'value', 'EUR', '953', 'million', 'USD', '1299', '']
# Sentence after removing stopwords: ['The', 'original', 'name', 'Componenta', 'ml', '', 'subsidiary', 'Finnish', 'Componenta', 'Group', '', 'changed', 'ml', 'Components', 'company', 'seen', '63', '', 'growth', 'Q1', '2010', '', 'comparison', 'Q1', '2009', '']
# Sentence after removing stopwords: ['SysOpen', 'Digia', 'Plc', '', 'Press', 'release', '', '7', 'February', '2006', 'IBM', 'Finland', 'rewarded', 'distinguished', 'partner', 'companies', '2005', '']
# Sentence after removing stopwords: ['Under', 'terms', 'offtake', 'agreement', 'Talvivaara', '', 'Cameco', 'provide', 'upfront', 'investment', '', 'maximum', '', '60', 'million', '', 'cover', 'construction', 'cost', 'uranium', 'extraction', 'circuit', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'Kauppalehti', 'group', 'rose', 'EUR', '15', 'mn', 'EUR', '13', 'mn', '', 'Marketplaces', 'EUR', '13', 'mn', 'EUR', '10', 'mn', 'third', 'quarter', '2006', '']
# Sentence after removing stopwords: ['The', 'upgrade', 'intended', 'raise', 'network', 'capacity', '450', 'MHz', '630', 'MHz', 'several', 'cities', '', 'enabling', 'bidirectional', 'services', 'digital', 'television', 'well', 'broadband', 'data', '']
# Sentence after removing stopwords: ['Thus', 'method', 'cut', 'working', 'costs', '', 'fasten', 'planning', 'building', 'processes', '']
# Sentence after removing stopwords: ['Ragutis', '', 'controlled', 'Finnish', 'brewery', '', 'reported', '54percent', 'rise', 'beer', 'sales', '1044', 'million', 'litres', 'held', '1109percent', 'market', 'share', '']
# Sentence after removing stopwords: ['Vaisala', 'also', 'said', 'expects', 'net', 'sales', 'EUR', '2532', 'million', '2010', '', 'compared', 'EUR', '2522', 'million', 'recorded', '2009', '']
# Sentence after removing stopwords: ['Repeats', 'sees', '2008', 'EBITA', '18', 'pct', 'sales', '']
# Sentence after removing stopwords: ['Glaston', '', 'headquartered', 'Tampere', '', 'Finland', '', 'growing', '', 'international', 'glass', 'technology', 'company', '']
# Sentence after removing stopwords: ['The', 'amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'Company', '']
# Sentence after removing stopwords: ['Viking', 'Line', 'head', 'Jan', 'Kaarstroem', 'told', 'TT', 'company', 'ferries', 'well', 'equipped', 'handle', 'ice', 'passengers', 'safe', '']
# Sentence after removing stopwords: ['Diluted', 'loss', 'per', 'share', 'stood', 'EUR', '015', 'versus', 'EUR', '026', '']
# Sentence after removing stopwords: ['The', 'Basware', 'Connectivity', 'services', 'allow', 'companies', 'handle', 'purchase', 'pay', 'processes', 'online', 'make', 'internal', 'processes', 'efficient', '', '', 'said', 'CEO', 'Ilkka', 'Sihvo', '', 'Basware', 'Corporation', '']
# Sentence after removing stopwords: ['Profit', 'period', 'EUR', '156', 'mn', 'compared', 'EUR', '141', 'mn', '2007', '']
# Sentence after removing stopwords: ['', 'We', 'happy', 'working', 'Rapala', 'encourage', 'boaters', 'anglers', 'introduce', 'newcomers', 'sport', '', '', 'said', 'RBFF', 'President', '', 'CEO', 'Frank', 'Peterson', '']
# Sentence after removing stopwords: ['Ruukki', 'delivery', 'volumes', 'selling', 'prices', 'showed', 'favourable', 'development', 'company', 'comparable', 'net', 'sales', 'grew', '50', '', 'yearonyear', 'EUR647m', '', 'CEO', 'Sakari', 'Tamminen', 'said', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'threemonth', 'period', 'increased', 'EUR1', '2', '', 'revenue', 'increased', 'EUR20', '2', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'ElectrowattEkono', 'Philippines', '', 'Inc', 'also', 'awarded', 'threeyear', 'operation', 'maintenance', '', 'OM', '', 'contract', 'FR', 'Cement', 'Corporation', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'Latin', 'America', '']
# Sentence after removing stopwords: ['Cramo', 'Group', 'financial', 'targets', '20102013', 'sales', 'growth', 'higher', '10', 'percent', 'per', 'year', '', 'return', 'equity', '15', 'percent', '']
# Sentence after removing stopwords: ['Those', 'partially', 'offset', '186', 'mln', 'eur', 'gain', 'sale', 'Celbi', 'pulp', 'plant', 'Portugal', '']
# Sentence after removing stopwords: ['Arvo', 'Vuorenmaa', '', 'Loviisa', 'plant', 'general', 'manager', 'said', 'application', 'new', 'licence', '', 'standard', '', 'procedure', '', 'quite', 'confident', '', 'approval', 'granted', '']
# Sentence after removing stopwords: ['', 'I', 'pleased', 'Bjorn', 'Wahlroos', 'accepted', 'nomination', '']
# Sentence after removing stopwords: ['Finnair', 'able', 'operate', 'leisure', 'flights', 'despite', 'strike', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '052', 'versus', 'EUR', '009', '']
# Sentence after removing stopwords: ['At', 'time', '', 'sales', 'development', 'Russia', 'boosted', 'opening', 'Stockmann', 'Nevsky', 'Centre', 'St', 'Petersburg', '']
# Sentence after removing stopwords: ['Cost', 'savings', 'rise', '20', 'mln', 'eur', 'year', '2007', '', 'OKO', 'said', '']
# Sentence after removing stopwords: ['Known', 'Post', 'Bank', '', 'concept', 'would', 'see', 'Fidelity', 'Bank', 'rolling', '75', 'offices', 'Ghana', 'Post', 'premises', '', 'provide', 'financial', 'services', 'people', '']
# Sentence after removing stopwords: ['The', 'soapstone', 'deposits', 'Medvezhyegorsk', 'area', 'expected', 'increase', 'Tulikivi', 'current', 'reserves', 'considerably', '']
# Sentence after removing stopwords: ['Finnish', 'financial', 'software', 'developer', 'Basware', 'Oyj', 'said', 'today', 'provide', 'invoice', 'automation', '', 'IA', '', 'solution', 'unnamed', 'major', 'retail', 'company', 'USA', 'deal', '', 'worth', 'EUR300', '000', '']
# Sentence after removing stopwords: ['Acquisitions', 'made', 'businesses', 'well', 'integrated', '']
# Sentence after removing stopwords: ['Cargotec', 'Corporation', '', 'Press', 'Release', '', 'April', '28', '', '2008', '200', 'pm', 'Finnish', 'time', 'Cargotec', 'MacGREGOR', 'business', 'area', 'providing', 'marine', 'cargo', 'handling', 'offshore', 'load', 'handling', 'solutions', 'received', 'significant', 'hatch', 'cover', 'orders', 'bulk', 'carriers', '']
# Sentence after removing stopwords: ['The', 'groups', 'turnover', 'full', 'fiscal', 'year', 'expected', 'show', 'slight', 'increase', 'previous', 'fiscal', 'year', '']
# Sentence after removing stopwords: ['Sales', 'rose', '3009', 'mln', 'eur', 'compared', 'last', 'year', '2761', 'mln', 'eur', 'line', '299', 'mln', 'eur', 'consensus', 'figure', '']
# Sentence after removing stopwords: ['', 'We', 'tailored', 'solutions', 'meet', 'Solel', 'technical', 'requirements', '', 'result', 'costeffective', 'manufacturing', 'highestquality', 'reflectors', '', '']
# Sentence after removing stopwords: ['Last', 'month', '', 'Outokumpu', 'sold', '80', 'percent', 'technology', 'unit', '', 'Outokumpu', 'Technology', 'Oyj', '', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Finnish', 'pharmaceuticals', 'company', 'Orion', 'net', 'sales', 'rose', 'EUR', '190mn', 'first', 'quarter', '2009', 'EUR', '180mn', 'first', 'quarter', '2008', '']
# Sentence after removing stopwords: ['Kalmar', 'awarded', 'new', '5year', 'contract', 'supply', 'Rough', 'Terrain', 'Container', 'Handler', 'RTCH', '']
# Sentence after removing stopwords: ['Nokian', 'Capacitors', '', 'equipment', 'used', 'raise', 'capacity', 'reliability', 'Indian', 'grid', '']
# Sentence after removing stopwords: ['Talentum', 'expects', 'net', 'sales', 'core', 'business', 'increase', '2008', '', 'compared', '2007', '']
# Sentence after removing stopwords: ['The', 'move', 'aimed', 'boosting', 'sales', '', 'costefficiency', 'market', 'share', 'Finland', '']
# Sentence after removing stopwords: ['Operating', 'income', 'rose', 'EUR', '6964', 'mn', 'EUR', '6003', 'mn', '2009', '']
# Sentence after removing stopwords: ['Net', 'sales', 'increased', 'EUR655m', 'April', 'June', '2010', 'EUR438m', 'year', 'earlier', '']
# Sentence after removing stopwords: ['The', 'company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'EUR', '671', 'million', '']
# Sentence after removing stopwords: ['Wartsila', 'contract', 'October', '2007', 'plant', 'installed', 'Manturovo', 'Kostroma', 'region', 'Russia', '', '600', 'km', 'northeast', 'Moscow', '', 'Russia', '']
# Sentence after removing stopwords: ['Jarmo', 'Honkamaa', '', 'head', 'oil', 'refining', 'business', 'Neste', 'Oil', '', 'says', 'situation', 'looks', 'promising', 'viewpoint', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'saw', 'net', 'profit', 'jump', 'EUR2', '1', 'last', 'quarter', '2010', 'EUR995', '000', 'period', '2009', '']
# Sentence after removing stopwords: ['Profit', 'taxes', 'EUR', '01', 'mn', '', 'compared', 'EUR', '04', 'mn', 'previous', 'year', '']
# Sentence after removing stopwords: ['When', 'situation', 'normalises', '', 'company', 'able', 'increase', 'amount', 'residential', 'units', 'sale', 'St', 'Petersburg', 'Moscow', '', 'particular', '']
# Sentence after removing stopwords: ['According', 'SeppÆnen', '', 'new', 'technology', 'UMTS900', 'solution', 'network', 'building', 'costs', 'onethird', 'lower', 'building', '35', 'G', 'networks', '', 'operating', '2100', 'MHz', 'frequency', '']
# Sentence after removing stopwords: ['Uponor', 'made', 'operating', 'profit', 'EUR', '1510', 'mn', '', 'EUR', '1437', 'mn', '', 'made', '2007', 'record', 'year', '']
# Sentence after removing stopwords: ['UPMKymmene', 'working', 'closely', 'shipping', 'agents', 'reduce', 'fuel', 'consumption', 'greenhouse', 'gas', 'emissions', '']
# Sentence after removing stopwords: ['', 'Our', 'strategic', 'cooperation', 'Rentakran', 'brings', 'us', 'new', 'customers', 'alreadyworking', 'relationships', 'authorities', 'new', 'territories', '', '', 'said', 'Jarmo', 'Laasanen', '', 'senior', 'manager', 'Cramo', '']
# Sentence after removing stopwords: ['To', 'prove', 'efficiency', 'China', 'Mobile', 'system', '', 'Rod', 'Baber', '', 'English', 'climber', '', 'climbed', 'Mount', 'Everest', 'summit', 'successfully', 'made', 'calls', '']
# Sentence after removing stopwords: ['Biohit', 'already', 'services', 'many', 'current', 'Genesis', 'customers', 'customer', 'base', 'expected', 'expand', 'result', 'agreement', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '029', 'EUR', '005', '']
# Sentence after removing stopwords: ['We', 'proud', 'able', 'use', 'kind', 'innovative', 'mobile', 'service', 'voting', 'elections', '']
# Sentence after removing stopwords: ['Marimekko', 'Group', 'fullyear', 'net', 'sales', 'estimated', 'increase', '10', '', '']
# Sentence after removing stopwords: ['Componenta', 'objective', 'agreement', 'increase', 'business', 'existing', 'production', 'lines', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Shares', 'closed', 'higher', '', 'led', 'Nokia', 'announced', 'plans', 'team', 'Sanyo', 'manufacture', '3G', 'handsets', '', 'Nokian', 'Tyres', 'fourthquarter', 'earnings', 'report', 'beat', 'analysts', '', 'expectations', '', 'dealers', 'said', '']
# Sentence after removing stopwords: ['Construction', 'volumes', 'meanwhile', 'grow', 'rate', '1015', 'percent', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'Suominen', 'Corporation', 'specialises', 'wet', 'wipes', '', 'nonwovens', '', 'flexible', 'packaging', 'reports', 'net', 'sales', 'EUR', '441', 'mn', 'second', 'quarter', '2010', '', 'EUR', '433', 'mn', 'second', 'quarter', '2009', '']
# Sentence after removing stopwords: ['', 'The', 'additional', 'flight', 'linking', 'Mumbai', 'Helsinki', 'dictated', 'strong', 'traffic', 'demand', 'Asia', 'Europe', '']
# Sentence after removing stopwords: ['STORA', 'ENSO', '', 'NORSKE', 'SKOG', '', 'MREAL', '', 'UPMKYMMENE', 'Credit', 'Suisse', 'First', 'Boston', '', 'CFSB', '', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'Nordic', 'forestry', 'groups', '']
# ...
# Sentence after removing stopwords: ['Calls', 'switchboard', 'directory', 'services', 'decreased', 'significantly', 'since', 'employees', 'uptodate', 'contact', 'information', 'colleagues', 'customers', 'phone', 'place', 'call', 'directly', '']
# Sentence after removing stopwords: ['Also', '', 'Westpac', 'issue', 'benchmark', '', '18', 'month', 'FRN', 'deal', 'Euros', '']
# Sentence after removing stopwords: ['Sales', 'local', 'currencies', 'decreased', '05', 'percent', 'number', 'subscribers', 'rose', '127', 'million', 'total', '1476', 'million', 'end', 'fourth', 'quarter', '', 'company', 'said', '']
# Sentence after removing stopwords: ['BG', 'Crane', 'strong', 'customer', 'base', 'onroad', 'load', 'handling', 'related', 'installation', 'service', 'businesses', '']
# Sentence after removing stopwords: ['Why', 'subscribe', 'magazine', '']
# Sentence after removing stopwords: ['Atria', 'chose', 'DeLight', 'attract', 'consumers', '2545', 'age', 'group', 'Atria', 'Fresh', 'range', 'microwaveable', 'meals', '']
# Sentence after removing stopwords: ['The', 'largest', 'construction', 'company', 'Finland', '', 'YIT', 'Corporation', '', 'acquire', '70', '', 'shares', 'Slovak', 'construction', 'company', 'Reding', 'Bratislava', '']
# Sentence after removing stopwords: ['The', 'final', 'price', 'specified', '14', 'May', '2010', '', 'acquiring', 'company', 'said', '']
# Sentence after removing stopwords: ['Previously', '', 'Grimaldi', 'held', '4643', 'pct', 'stake', 'Finnish', 'company', 'following', 'takeover', 'bid', 'launched', 'November', '2006', '']
# Sentence after removing stopwords: ['The', 'figure', 'includes', 'change', 'fair', 'value', 'property', 'portfolio', '', 'EUR', '262', 'million', '']
# Sentence after removing stopwords: ['Nokia', 'OYJ', 'production', 'site', 'Bochum', '', 'Germany', '', 'posted', 'profit', 'interest', '134', 'mln', 'eur', '2007', '', 'Capital', 'reported', 'excerpt', 'article', 'released', 'tomorrow', '', 'citing', 'internal', 'documents', '']
# Sentence after removing stopwords: ['The', 'construction', 'project', 'scheduled', 'start', 'second', 'quarter', '2009', 'new', 'building', 'scheduled', 'place', 'end', '2010', '']
# Sentence after removing stopwords: ['The', 'Nokia', 'Music', 'Store', 'begins', 'trading', 'Tuesday', '', 'selling', 'singles', 'albums', 'well', 'live', 'music', 'streaming', '']
# Sentence after removing stopwords: ['BAWAG', '', 'Is', 'issue', 'benchmark', '', 'covered', 'deal', '']
# Sentence after removing stopwords: ['The', 'third', 'quarter', 'result', 'also', 'includes', '400000', 'euro', '', '', '575000', '', 'provision', 'downsizing', 'lure', 'manufacturing', 'Ireland', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'quarter', 'AprilJune', '2006', 'amounted', 'EUR182', '2', 'sales', 'EUR3', '62', 'bn', '']
# Sentence after removing stopwords: ['Thus', 'group', 'balance', 'sheet', 'EUR25', '8', 'goodwill', '', 'company', 'added', '']
# Sentence after removing stopwords: ['Delivery', 'due', 'second', 'half', '2011', '']
# Sentence after removing stopwords: ['Philips', 'available', 'comment', 'report', '']
# Sentence after removing stopwords: ['Thus', 'group', 'balance', 'sheet', 'EUR', '258', 'million', 'goodwill', '', 'company', 'added', '']
# Sentence after removing stopwords: ['According', 'HK', 'Ruokatalo', '', 'almost', 'meat', 'used', 'company', 'comes', 'Finland', '']
# Sentence after removing stopwords: ['The', 'devices', 'would', 'launched', 'Chinese', 'market', 'late', '2006', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'bank', 'leasing', 'arm', 'Nordea', 'Liising', 'ended', 'year', 'profit', '44', 'million', 'euros', '']
# Sentence after removing stopwords: ['We', 'went', 'market', 'yield', 'guidance', '725', '', 'area', '', 'gave', 'us', 'flexibility', 'go', '18th', '']
# Sentence after removing stopwords: ['When', 'investment', 'place', '', 'Atria', 'plans', 'expand', 'Moscow', 'market', '']
# Sentence after removing stopwords: ['Via', 'plant', '', 'Belgian', 'company', 'feed', '84', 'MW', 'electricity', 'distribution', 'grid', 'able', 'deliver', '14', 'MW', 'heat', '']
# Sentence after removing stopwords: ['The', 'ECB', 'mainly', 'target', 'inflation', '']
# Sentence after removing stopwords: ['A', 'merger', 'UPM', 'FinnishSwedish', 'Stora', 'Enso', 'likely', 'either', '']
# Sentence after removing stopwords: ['The', 'amendment', 'incur', 'additional', 'costs', '']
# Sentence after removing stopwords: ['Tyrvaan', 'Sanomat', '', 'published', 'twice', 'week', 'Tyrvaan', 'Sanomat', 'Oy', '', 'appears', 'Sastamala', 'Kiikoinen', '']
# Sentence after removing stopwords: ['Aldata', 'Share', 'Space', 'Optimization', 'Vision', 'Apollo', 'User', 'Group', '2009', 'Category', 'Management', 'Association', 'Conferences', '', 'Company', 'Will', 'Unveil', 'New', 'Solution', 'Combines', 'Business', 'Intelligence', 'Space', 'Planning', 'Data', 'Conferences']
# Sentence after removing stopwords: ['Meanwhile', '', 'Alfa', 'owns', '251', '', 'MegaFon', 'Altimo', '', '499', '', 'Turkcell', 'via', '185', '', 'stake', 'Cukurova', 'Holding', '']
# Sentence after removing stopwords: ['business', 'sectors', 'building', 'construction', '', 'infrastructure', 'construction', 'technical', 'building', 'services', '']
# Sentence after removing stopwords: ['The', 'company', 'says', 'difficult', 'estimate', 'market', 'situation', 'whole', 'year', '2009', '']
# Sentence after removing stopwords: ['JuhaPekka', 'Weckstr¦m', 'appointed', 'President', 'telecom', 'group', 'TeliaSonera', 'Finland', 'succeed', 'Esa', 'Rautalinko', '']
# Sentence after removing stopwords: ['The', 'technology', 'become', 'available', 'businesses', 'fourth', 'quarter', '', 'Nokia', 'said', '']
# Sentence after removing stopwords: ['The', 'reductions', 'implemented', 'mainly', 'course', 'first', 'half', '2009', '']
# Sentence after removing stopwords: ['KONE', '', 'headquartered', 'Espoo', '', 'Finland', '', 'one', 'world', 'leading', 'elevator', 'escalator', 'companies', '']
# Sentence after removing stopwords: ['Combined', 'Basware', 'Enterprise', 'Purchase', 'Pay', 'portfolio', '', 'provides', 'high', 'level', 'automation', 'procurement', 'invoice', 'workflows', '']
# Sentence after removing stopwords: ['The', 'firm', 'builds', 'components', 'mobile', 'phones', 'communications', 'products', '']
# Sentence after removing stopwords: ['In', 'Baltic', 'countries', '', 'Atria', 'target', 'organic', 'growth', '']
# Sentence after removing stopwords: ['The', 'broker', 'started', 'UPMKymmene', '', 'Stora', 'Enso', 'Sappi', '', 'equalweight', '', 'recommendations', 'Holmen', 'Norske', 'Skog', '', 'underweight', '', 'ratings', '']
# Sentence after removing stopwords: ['The', 'EUR', '07', 'million', 'nonrecurring', 'expenses', 'recorded', 'third', 'quarter', '']
# Sentence after removing stopwords: ['The', 'Court', 'decision', 'also', 'promote', 'genuine', 'competition', 'services']
# Sentence after removing stopwords: ['The', 'guidance', 'set', '90', 'basis', 'points', 'midswaps', '', 'report', 'said', '']
# Sentence after removing stopwords: ['The', 'company', 'supports', 'global', 'customers', 'developing', 'new', 'technologies', 'offers', 'fast', 'route', 'product', 'development', 'applications', 'volume', 'production', '']
# Sentence after removing stopwords: ['Therefore', '', 'Phase', 'III', 'research', 'conducted', 'Abbott', '']
# Sentence after removing stopwords: ['Liquid', 'handling', 'products', 'include', 'electronic', 'mechanical', 'pipettes', '', 'disposable', 'tips', 'well', 'pipette', 'maintenance', 'calibration', 'services', 'research', 'institutions', '', 'healthcare', 'industrial', 'laboratories', '']
# Sentence after removing stopwords: ['It', '', 'fingerfriendly', '', '', 'opinion', '', 'really', 'fast', '']
# Sentence after removing stopwords: ['We', 'look', 'forward', 'take', 'part', 'future', 'development', 'company', '', '', 'says', 'Tomas', 'Billing', '', 'President', 'Nordstjernan', '']
# Sentence after removing stopwords: ['BasWare', 'headquartered', 'Espoo', '', 'Finland', '']
# Sentence after removing stopwords: ['The', 'new', 'chain', '700', 'discount', 'stores', '250', 'supermarkets', '']
# Sentence after removing stopwords: ['Its', 'total', 'annual', 'revenue', 'comes', '160', 'mln', 'zloty', '', '', '569', 'mln42', '3', 'mln', 'euro', '', '']
# Sentence after removing stopwords: ['The', 'building', 'complex', 'consists', 'highquality', 'office', 'retail', 'space', 'totalling', '49200', 'square', 'metres', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Our', 'key', 'geographical', 'markets', 'Europe', '', 'Russian', 'Federation', '', 'MiddleEast', '', 'SouthAfrica', 'Japan', '']
# Sentence after removing stopwords: ['OMEO', '', 'wwwomeose', '', 'employs', '55', 'expects', 'net', 'sales', '23', 'mln', 'euro', '', '', '298', 'mln', '', 'fiscal', '20062007', '', 'ending', 'April', '30', '', '2007', '']
# Sentence after removing stopwords: ['Unit', 'prices', 'straddle', 'carriers', 'vary', 'EUR700', '000', 'EUR900', '000', '', 'company', 'added', '']
# Sentence after removing stopwords: ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '82', 'mn', '']
# Sentence after removing stopwords: ['The', 'company', 'continuous', 'need', 'alloys', 'nickel', '', 'ferrochrome', '', 'molybdenum', 'manganese', 'production', '', 'said', 'Talvivaara', '']
# Sentence after removing stopwords: ['MILAN', '', 'AFX', '', '', 'The', 'Italian', 'shipping', 'group', 'Grimaldi', 'increased', 'stake', 'Finnish', 'company', 'Finnlines', '354', 'pct', '305', 'pct', 'held', 'June', '', 'according', 'news', 'agency', 'ANSA', '']
# Sentence after removing stopwords: ['In', 'end', '', 'Sanoma', 'News', 'wants', 'secure', 'foundation', 'savings', '']
# Sentence after removing stopwords: ['The', 'closing', 'transaction', 'took', 'place', 'today', '']
# Sentence after removing stopwords: ['', 'BG', 'Crane', 'strong', 'partner', 'Hiab', 'Australia', 'many', 'years', '']
# Sentence after removing stopwords: ['The', 'transaction', '', 'includes', 'US', '15', 'billion', 'euro1', 'billion', 'cash', '', 'vendor', 'notes', 'share', 'purchases', '', 'expected', 'completed', 'first', 'quarter', '2008', '', 'FinnishSwedish', 'paper', 'maker', 'said', '']
# Sentence after removing stopwords: ['The', 'continued', 'operations', 'mean', 'structure', 'restructuring', 'Aspocomp', 'group', 'including', 'Aspocomp', 'Oulu', 'headquarter', 'operations', '']
# Sentence after removing stopwords: ['The', 'company', 'earlier', 'said', 'considering', 'different', 'strategic', 'options', 'struggling', 'lowcost', 'mobile', 'operator', '', 'including', 'divestment', 'holding', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'Martela', 'offers', 'comprehensive', 'service', 'cover', 'entire', 'process', 'change', 'initial', 'inventory', 'design', 'removal', 'maintenance', '']
# Sentence after removing stopwords: ['One', 'also', 'apply', 'jobs', 'directly', 'iPad', '', 'select', 'CV', 'attach', 'covering', 'letter', 'appropriate', 'position', '']
# Sentence after removing stopwords: ['These', 'sections', 'put', 'place', 'form', 'loadbearing', 'steel', 'structure', 'bridge', '', '', 'says', 'Sami', 'Eronen', '', 'Senior', 'Vice', 'President', '', 'Infrastructure', 'Northern', 'Europe', '', 'Ruukki', 'Construction', '']
# Sentence after removing stopwords: ['Cohen', '', 'Steers', '', 'Inc', '', '5', '534', '626', 'shares', 'representing', '4985', '', 'share', 'capital', 'voting', 'rights', '']
# Sentence after removing stopwords: ['The', 'podcast', '', 'sees', 'Harple', 'provide', 'lowdown', 'GyPSii', 'platform', '', 'takes', 'someone', 'location', 'demographic', 'information', 'produce', 'contextual', 'index', 'world', 'around', '']
# Sentence after removing stopwords: ['compensation', 'news', '', 'opinions', 'distributions', '']
# Sentence after removing stopwords: ['One', 'even', 'receive', 'spot', 'alerts', 'soon', 'jobs', 'posted', '', 'putting', 'front', 'queue', 'opportunities', '']
# Sentence after removing stopwords: ['According', 'report', '', 'Elisa', 'DNA', 'joint', 'market', 'share', 'Finland', 'telecom', 'market', '59', '', '']
# Sentence after removing stopwords: ['Pharmaceutical', 'market', 'Italy', 'Global', 'Research', '', 'Data', 'Services', 'published', 'recently', 'market', 'analysis', 'pharmaceutical', 'markets', 'Italy', '']
# Sentence after removing stopwords: ['The', 'commission', 'found', 'evidence', 'several', 'meetings', 'discuss', 'cartel', '', 'including', 'one', 'Brussels', 'restaurant', 'November', '1997', 'companies', 'discussed', 'price', 'increases', '']
# Sentence after removing stopwords: ['We', 'also', 'pleased', 'welcome', 'new', 'employees', 'Tieto', '', '']
# Sentence after removing stopwords: ['The', 'business', 'idea', 'Budget', 'Sport', 'offer', 'customers', 'wide', 'range', 'highquality', 'sports', 'equipment', 'clothing', 'low', 'prices', '', 'company', 'said', '']
# Sentence after removing stopwords: ['POYRY', 'PLCCompany', 'Announcement', '10', 'December', '2010', '410', 'pm', 'Pursuant', 'Poyry', 'PLC', 'stock', 'option', 'program', '2004', '', '63', '792', 'new', 'shares', 'company', 'subscribed', 'since', '27', 'October', '2010', 'stock', 'options', '2004B', '']
# Sentence after removing stopwords: ['Anttila', 'online', 'department', 'store', '', 'NetAnttila', '', 'established', 'position', 'bestknown', '', 'visited', 'shopped', 'online', 'store', 'Finland', '', '']
# Sentence after removing stopwords: ['The', 'Annual', 'Report', 'contains', 'financial', 'statements', '', 'consolidated', 'financial', 'statements', '', 'report', 'Board', 'Directors', 'auditor', 'report', '']
# Sentence after removing stopwords: ['The', 'Group', 'consolidated', 'net', 'sales', '2008', 'totaled', '34', 'billion', 'euros', 'employs', 'approximately', '13000', 'persons', '']
# Sentence after removing stopwords: ['The', 'StoneGate', 'product', 'centrally', 'manageable', 'suited', 'physical', 'virtual', 'environments', '']
# Sentence after removing stopwords: ['The', 'handset', 'maker', 'disclose', 'financial', 'details', '']
# Sentence after removing stopwords: ['Local', 'government', 'commissioner', 'ml', '', 'Kurt', 'Svensson', '', 'says', 'contact', 'management', 'Finnish', 'company', 'Componenta', 'find', 'alternatives', 'company', 'decision', 'close', 'plant', 'ml', '']
# Sentence after removing stopwords: ['As', 'consequence', 'Works', 'Council', 'withdrawn', 'petition', 'suspend', 'reorganisation', '']
# Sentence after removing stopwords: ['Finnish', 'investment', 'group', 'Neomarkka', 'Oyj', '', 'HEL', '', 'NEMBV', '', 'said', 'today', 'buy', 'former', 'production', 'facilities', 'Kuitu', 'Finland', 'Ltd', '', 'part', 'negotiations', 'option', 'invest', 'specialty', 'cellulose', 'fiber', 'business', '']
# Sentence after removing stopwords: ['Ulefos', 'Group', 'leading', 'supplier', 'manhole', 'covers', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['Okmetic', 'global', 'customer', 'base', 'sales', 'network', '', 'production', 'plants', 'Finland', 'US', 'contract', 'manufacturers', 'Japan', 'China', '']
# Sentence after removing stopwords: ['OPPohjola', 'Group', 'capital', 'adequacy', 'ratio', 'Act', 'Credit', 'Institutions', 'stood', '121', '', 'Tier', '1', 'ratio', '121', '', '']
# Sentence after removing stopwords: ['Entire', 'paper', 'mills', 'may', 'set', '', 'especially', 'new', 'EU', 'member', 'states', '']
# Sentence after removing stopwords: ['These', 'companies', '20000', 'sq', 'office', 'commercial', 'building', 'substantial', 'amount', 'building', 'right', 'new', 'shopping', 'center', 'Liljeholmen', '', 'Stockholm', '']
# Sentence after removing stopwords: ['For', 'fiscal', 'year', 'ending', 'September', '30', '', '2009', 'revenue', 'customers', '', '10012', 'million', 'around', '110', '', 'transportation', 'group', 'revenue', '']
# Sentence after removing stopwords: ['The', 'veneer', 'plywood', 'industry', 'Sweden', 'quite', 'small', 'despite', 'raw', 'material', 'resources', '']

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive2=pd.DataFrame(sorted(positiveValues2.items(),key=lambda x:x[1],reverse=True))
df_negative2=pd.DataFrame(sorted(negativeValues2.items(),key=lambda x:x[1],reverse=True))
df_neutral2=pd.DataFrame(sorted(neutralValues2.items(),key=lambda x:x[1],reverse=True))

# %%
pd1bi=df_positive2[0][:10]
pd2bi=df_positive2[1][:10]

ned1bi=df_negative2[0][:10]
ned2bi=df_negative2[1][:10]

nud1bi=df_neutral2[0][:10]
nud2bi=df_neutral2[1][:10]

plt.figure(1,figsize=(16,4))

plt.bar(pd1bi,pd2bi, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-BIGRAM ANALYSIS")

plt.savefig("positive-bigram.png")
plt.show()

# %%
df_positive2.head(10)
# Out:
#            0    1
# 0             127
# 1  net sales   53
# 2        mn    46
# 3      2009    46
# 4       said   42
# 5        EUR   41
# 6      2008    41
# 7      2010    36
# 8   million    36
# 9      said    33

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1bi,ned2bi, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-BIGRAM ANALYSIS")

plt.savefig("negative-bigram.png")
plt.show()

# %%
df_negative2.head(10)
# Out:
#                       0   1
# 0                        66
# 1                   mn   48
# 2                 2009   36
# 3                 2008   35
# 4                   EUR  31
# 5              compared  26
# 6                 2007   24
# 7      Operating profit  23
# 8  corresponding period  23
# 9              million   21

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1bi,nud2bi, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-BIGRAM ANALYSIS")

plt.savefig("neutral-bigram.png")
plt.show()

# %%
df_neutral2.head(10)
# Out:
#              0    1
# 0               194
# 1     Finland    80
# 2  The company   59
# 3    net sales   53
# 4        2007    48
# 5      Finland   46
# 6        said    46
# 7        2010    44
# 8        2008    42
# 9      company   42

# %% [markdown]
# **Creating trigrams**

# %%
positiveValues3=defaultdict(int)
negativeValues3=defaultdict(int)
neutralValues3=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text,3):
    positiveValues3[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text,3):
    negativeValues3[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text,3):
    neutralValues3[word]+=1
# Out:
# Sentence after removing stopwords: ['It', 'also', 'strengthen', 'Ruukki', 'offshore', 'business', '']
# Sentence after removing stopwords: ['Efore', 'results', 'last', 'quarter', 'showed', 'even', 'faster', 'improvement', 'company', 'managed', 'better', 'source', 'components', '']
# Sentence after removing stopwords: ['Ruukki', 'Romania', '', 'local', 'arm', 'Finnish', 'metal', 'producer', 'Ruukki', '', 'increased', 'capital', '900000', 'euro', '', '', '114', 'mln', '', 'cash', 'contribution', '', 'reported', 'September', '19', '', '2006', '']
# Sentence after removing stopwords: ['The', 'representative', 'body', 'Swedish', 'Meats', 'approved', 'improved', 'offer', 'Finnish', 'HK', 'Ruokatalo', 'acquire', 'company', '']
# Sentence after removing stopwords: ['In', 'third', 'quarter', '2010', '', 'net', 'sales', 'increased', '52', '', 'EUR', '2055', 'mn', '', 'operating', 'profit', '349', '', 'EUR', '235', 'mn', '']
# Sentence after removing stopwords: ['Our', 'superior', 'customer', 'centricity', 'expertise', 'digital', 'services', 'set', 'us', 'apart', 'competitors', '']
# Sentence after removing stopwords: ['This', 'much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'Finland', 'Canada', '']
# Sentence after removing stopwords: ['Finnish', 'lifting', 'equipment', 'maker', 'Konecranes', 'Oyj', 'said', 'July', '30', '', '2008', 'net', 'profit', 'rose', '712', 'mln', 'euro', '', '', '1111', 'mln', '', 'first', 'half', '2008', '571', 'mln', 'euro', '', '', '891', 'mln', '', 'period', '2007', '']
# Sentence after removing stopwords: ['Both', 'net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history', '']
# Sentence after removing stopwords: ['The', 'estimated', 'synergy', 'benefits', 'least', 'EUR7m', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'Swedish', 'construction', 'markets', 'still', 'experiencing', 'estimated', '4', '', 'annual', 'growth', '2008', '']
# Sentence after removing stopwords: ['Besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', '', '', 'Paavel', 'said', '']
# Sentence after removing stopwords: ['', 'Very', 'recommendable', '', 'Nokian', 'Z', 'G2', 'according', '', 'ADAC', 'judgement', '', 'latest', 'summer', 'tyre', 'test', 'German', 'automobile', 'association', 'ADAC', '']
# Sentence after removing stopwords: ['Sales', 'rose', '10', 'pct', '566', 'mln', 'eur', 'back', 'strong', 'volume', 'favourable', 'currency', 'effects', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'company', 'operating', 'profit', 'grew', '432', '', 'EUR', '6', 'million', '']
# Sentence after removing stopwords: ['Finland', 'Neste', 'Oil', 'awarded', 'Chemical', 'Industry', 'Federation', 'Finland', 'Innovation', 'Award', 'NExBTL', 'technology', '', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat', '']
# Sentence after removing stopwords: ['SRV', 'raise', 'holding', 'company', 'summer', '2008', '', 'majority', '']
# Sentence after removing stopwords: ['Rautaruukki', 'Corporation', 'Stock', 'exchange', 'release', '3', 'December', '2009', '12', 'noon', 'Ruukki', 'construction', 'engineering', 'divisions', 'improve', 'adjust', 'operations', 'Finland', '']
# Sentence after removing stopwords: ['Jens', 'SchulteBockum', '', 'Vodafone', 'global', 'director', 'terminals', '', 'said', 'company', 'expects', 'sell', 'one', 'two', 'million', 'Vodafone', '125', '225', 'models', 'first', 'year', 'launch', '', 'potentially', 'tens', 'millions', 'lifetime', 'device', '']
# Sentence after removing stopwords: ['Finnishowned', 'contract', 'manufacturer', 'electronics', 'Elcoteq', 'Hungary', 'Kft', 'announced', 'plans', 'recruit', '650', 'new', 'staffers', 'fulfill', 'new', 'orders', 'Pcs', '', 'company', 'two', 'plants', '']
# Sentence after removing stopwords: ['The', 'Australian', 'company', 'Mirabela', 'Nickel', 'awarded', 'Outokumpu', 'Technology', 'contract', 'grinding', 'technology', 'nickel', 'sulfide', 'project', 'Bahia', 'State', '', 'Brazil', '']
# Sentence after removing stopwords: ['', 'Consumers', 'well', 'received', 'packed', 'fresh', 'meat', '']
# Sentence after removing stopwords: ['Fiskars', 'strong', 'portfolio', 'international', 'brands', '', 'include', 'Fiskars', '', 'Iittala', '', 'Gerber', '', 'Silva', 'Buster', '']
# Sentence after removing stopwords: ['Nokia', 'Elisa', 'work', 'together', 'bring', 'superior', 'mobile', 'gaming', 'experience', 'Elisa', 'customers', '']
# Sentence after removing stopwords: ['The', 'company', 'established', '3G', 'base', 'station', '17000', 'feet', 'foot', 'Mount', 'Everest', 'enable', 'mountain', 'climbers', '29035foot', 'summit', 'surf', 'Internet', 'even', 'send', 'videos', 'exploits', '']
# Sentence after removing stopwords: ['Finnish', 'Outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'OZK', 'Kardzhali', 'zinc', 'smelter', 'Bulgaria', '']
# Sentence after removing stopwords: ['A', 'Helsinki', '', 'ELIiV', 'today', 'reported', 'EPS', 'EUR1', '13', '2009', '', 'increase', 'EPS', 'EUR1', '12', '2008', '']
# Sentence after removing stopwords: ['Q1', '2010', '18', 'May', '2010', '', 'Finnish', 'electrical', 'components', 'maker', 'Salcomp', 'Oy', '', 'HEL', '', 'SAL1V', '', 'said', 'today', 'turned', 'net', 'profit', 'EUR1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'EUR2m', 'corresponding', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['In', 'JanuarySeptember', '2010', '', 'Fiskars', '', 'net', 'profit', 'went', '14', '', 'yearonyear', 'EUR', '654', 'million', 'net', 'sales', 'EUR', '5253', 'million', 'EUR', '4877', 'million', '']
# Sentence after removing stopwords: ['The', 'transaction', 'line', 'Aspo', 'strategy', 'expand', 'Baltic', 'Sea', 'region', 'eastern', 'markets', '']
# Sentence after removing stopwords: ['', 'UPMKymmene', 'upgraded', '', 'inline', '', '', 'underperform', '', 'Goldman', 'Sachs', '']
# Sentence after removing stopwords: ['The', 'Lithuanian', 'beer', 'market', 'made', '1441', 'million', 'liters', 'January', '', 'rise', '08', 'percent', 'yearearlier', 'figure', '', 'Lithuanian', 'Brewers', '', 'Association', 'reporting', 'citing', 'results', 'members', '']
# Sentence after removing stopwords: ['We', 'capitalize', 'experience', 'number', 'similar', 'bridge', 'projects', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['', 'The', 'CHF', 'great', 'product', '']
# Sentence after removing stopwords: ['The', 'group', 'expand', 'chain', 'include', '45', 'stores', '']
# Sentence after removing stopwords: ['We', 'aim', 'ensure', 'Vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', '', '', 'comments', 'Vacon', 'Plc', 'President', 'CEO', 'Vesa', 'Laisi', '']
# Sentence after removing stopwords: ['The', 'cooperation', 'double', 'The', 'Switch', 'converter', 'capacity', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', '', 'EPS', '', 'first', 'quarter', '2007', 'amounted', 'EUR0', '07', '', 'EUR0', '04', '']
# Sentence after removing stopwords: ['1', 'Block', 'lamp', 'Harri', 'Koskinen', 'light', 'introduced', '1996', 'bestseller', 'ever', 'since', '']
# Sentence after removing stopwords: ['Nordea', 'sees', 'return', 'positive', 'growth', 'Baltic', 'countries', '2011', '']
# Sentence after removing stopwords: ['3', 'January', '2011', '', 'Finnish', 'flag', 'carrier', 'Finnair', 'Oyj', '', 'HEL', '', 'FIA1S', '', 'said', 'today', 'sealed', 'nineyear', 'sale', 'leaseback', 'agreement', 'newest', 'Airbus', 'A330', 'aircraft', 'syndication', 'Japanese', 'operating', 'lease', 'market', '']
# Sentence after removing stopwords: ['Growth', 'expected', 'continue', '2008', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'guided', 'EBIT', 'sales', 'growth', '20', 'pct', '10', 'pct', 'respectively', 'year', '']
# Sentence after removing stopwords: ['The', 'program', 'target', 'structural', 'cost', 'reductions', 'EUR', '30mn', '2009', '']
# Sentence after removing stopwords: ['Revenue', 'grew', '12', 'percent', '', '', 'x20ac', '', '36', 'billion', '', 'US', '45', 'billion', '', '']
# Sentence after removing stopwords: ['', 'The', 'second', 'quarter', '2010', 'firstquarter', 'growth', 'net', 'sales', 'since', 'third', 'quarter', 'of2008', '', '', 'said', 'Magnus', 'Rosen', '', 'Ramirent', 'CEO', '']
# Sentence after removing stopwords: ['The', 'stock', 'price', 'rose', '700', 'ores', '09', '', 'close', 'SEK77', '65', '', 'ending', 'twoday', 'streak', 'losses', '']
# Sentence after removing stopwords: ['Hkan', 'Dahlstr¦m', '', 'head', 'mobility', 'services', 'TeliaSonera', '', 'forecast', 'mobile', 'data', 'volume', 'TeliaSonera', 'network', 'Sweden', 'rise', 'eightfold', '200000', 'TB', '2014', '']
# Sentence after removing stopwords: ['Press', 'release', '9', 'October', '2009', 'Ruukki', 'signed', 'contract', 'deliver', 'install', 'steel', 'structures', 'bridge', 'Kyronsalmi', 'strait', 'Savonlinna', '', 'Finland', '']
# Sentence after removing stopwords: ['Finland', 'leading', 'metals', 'group', 'Outokumpu', 'said', 'fourthquarter', 'net', 'profit', 'tripled', 'back', 'strong', 'global', 'demand', 'stainless', 'steel', '', 'soaring', 'base', 'metal', 'prices', 'proceeds', 'sale', 'technology', 'unit', '']
# Sentence after removing stopwords: ['Previously', '', 'EB', 'delivered', 'custom', 'solution', 'LG', 'Electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators', '']
# Sentence after removing stopwords: ['Finnish', 'telecoms', 'software', 'developer', 'Tecnomen', 'Oyj', 'said', 'December', '5', '', '2006', '', '33', 'mln', '', '25', 'mln', 'euro', '', 'order', 'supply', 'expansion', 'charging', 'messaging', 'systems', 'mobile', 'fixed', 'networks', 'Brasil', 'Telecom', '']
# Sentence after removing stopwords: ['Kesko', 'pursues', 'strategy', 'healthy', '', 'focused', 'growth', 'concentrating', 'sales', 'services', 'consumercustomers', '']
# Sentence after removing stopwords: ['Ixonos', 'estimates', 'hire', '20', 'specialists', 'mechanical', 'engineering', '', 'electronics', 'design', '', 'RD', 'new', 'unit', 'Jyvaeskylae', 'end', '2009', '']
# Sentence after removing stopwords: ['', 'Our', 'customer', 'satisfied', 'Basware', 'Invoice', 'Automation', 'solution', 'extends', 'implementation', 'new', 'geographies', '']
# Sentence after removing stopwords: ['Salo', '', 'Finland', '', '29', 'August', '2006', '', 'Benefon', 'today', 'announced', 'plans', 'strengthen', 'inhouse', 'technology', 'platform', '', 'licensing', 'complete', 'mobile', 'software', 'platform', '', 'Opna', '', 'longstanding', 'technology', 'partner', '', 'Pollex', '']
# Sentence after removing stopwords: ['Profit', 'per', 'share', 'EUR', '103', '', 'EUR', '087', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Retail', 'wholesale', 'group', 'Kesko', 'reported', 'net', 'sales', '6594', 'mln', 'eur', 'February', '', 'increase', '108', 'pct', 'yearonyear', '']
# Sentence after removing stopwords: ['', 'We', 'pleased', 'working', 'Fujitsu', 'NTT', 'DoCoMo', 'advance', 'progress', 'LTE', '', '', 'said', 'Juergen', 'Walter', '', 'Head', 'Converged', 'Core', '', 'Nokia', 'Siemens', 'Networks', '']
# Sentence after removing stopwords: ['SINGAPORE', '', 'ICIS', '', '', '', '1', '', 'Kemira', 'Indian', 'water', 'infrastructure', 'firm', '', '2', '', 'IVRCL', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'Andhra', 'Pradesh', 'state', '', 'India', '', 'Finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'Tuesday', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'totalled', 'EUR', '20', 'mn', '', 'compared', 'loss', 'EUR', '1592', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['London', 'leading', 'shares', 'today', 'jumped', 'almost', '100', 'points', '', '17', '', '', 'market', 'opened', '']
# Sentence after removing stopwords: ['Net', 'sales', 'increased', 'EUR193', '3', 'EUR179', '9', 'pretax', 'profit', 'rose', '342', '', 'EUR43', '1', '', 'EUR1', '', 'USD1', '4', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['A', 'new', 'production', 'line', 'completed', 'contract', 'production', 'hormone', 'treatments', '']
# Sentence after removing stopwords: ['Kaupthing', 'forecasts', 'significant', 'price', 'increase', 'printing', 'paper', '2007', '']
# Sentence after removing stopwords: ['Rautaruukki', 'said', 'construction', 'group', 'YIT', 'awarded', '25', 'mln', 'eur', 'contract', 'supply', 'steel', 'structures', 'new', 'bridge', 'spanning', 'Kemijoki', 'river', 'Northern', 'Finland', '']
# Sentence after removing stopwords: ['When', 'open', 'next', 'year', '', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat', '']
# Sentence after removing stopwords: ['It', 'also', 'strong', 'assets', 'electronic', 'media', '', 'employing', '18500', 'increase', '9', 'percent', 'last', 'year', '']
# Sentence after removing stopwords: ['These', 'companies', 'able', 'keep', 'market', 'positions', '']
# Sentence after removing stopwords: ['A', 'memorandum', 'understanding', 'cooperation', 'Finnish', 'Global', 'Chemical', 'Company', 'KEMIRA', 'Vietnam', 'National', 'Chemicals', 'Group', '', 'Vinachem', '', 'signed', 'occasion', '']
# Sentence after removing stopwords: ['Furthermore', '', 'Bunge', 'also', 'sign', 'licensing', 'agreement', 'Sunnuntai', 'Carlshamn', 'Mejeri', 'brands', '']
# Sentence after removing stopwords: ['', 'IH', '', 'move', 'enhance', 'growth', '']
# Sentence after removing stopwords: ['Q1', '10', '19', 'April', '2010', '', 'Finnish', 'forest', 'machinery', 'equipment', 'maker', 'Ponsse', 'Oyj', 'HEL', '', 'PON1V', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'EUR6', '3', 'first', 'quarter', '2010', '', 'EUR9', '6', 'loss', 'year', 'earlier', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['Also', '', 'bringing', '', 'right', 'kind', 'people', '', 'upgrade', 'human', 'resources', '']
# Sentence after removing stopwords: ['In', 'release', '', 'Company', 'said', 'Vocollect', 'T2', 'customers', 'North', 'America', 'take', 'advantage', 'Voice', 'Directed', 'Warehousing', 'solution', 'increase', 'warehouse', 'efficiency', 'productivity', 'gains', 'discounted', 'price', '']
# Sentence after removing stopwords: ['Olvi', '', 'controls', '94', 'percent', 'stake', 'Ragutis', 'A', 'Le', 'Coq', '', 'said', 'annual', 'report', 'published', 'earlier', 'year', 'Lithuanian', 'brewery', 'sales', 'reached', '1504', 'million', 'euros', 'last', 'year', '', 'rise', '204', 'percent', '1249', 'million', 'euros', '2004', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['In', 'first', 'nine', 'months', '2010', '', 'company', 'net', 'loss', 'narrowed', 'EUR', '415000', 'EUR', '74', 'million', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['The', 'District', 'Court', 'Helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005', '']
# Sentence after removing stopwords: ['EPS', 'continuing', 'operations', 'came', '030', 'eur', '', '017', '']
# Sentence after removing stopwords: ['Production', 'expand', 'Elcoteq', 'locations', 'including', 'Mexico', 'Hungary', '2010', '']
# Sentence after removing stopwords: ['Advertising', 'circulation', 'revenues', 'grew', '34', '', '04', '', '', 'respectively', '']
# Sentence after removing stopwords: ['It', 'solid', 'credit', 'compared', 'DZ', 'Bank', 'Rabobank', '']
# Sentence after removing stopwords: ['The', 'longstanding', 'partnership', 'commitment', 'enable', 'parties', 'develop', 'respective', 'operations', '', 'ESL', 'Shipping', 'also', 'opportunity', 'update', 'fleet', 'improve', 'efficiency', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Metso', 'said', 'upgrade', 'one', 'UPMKymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'Jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', '', 'machine', 'process', 'controls', 'quality', 'measurements', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'net', 'sales', 'rose', '8', '', 'yearonyear', 'EUR64', '3', '', 'due', 'business', 'acquisitions', 'realized', 'first', 'half', '200809', '', 'effect', 'EUR10', '9', 'review', 'period', '']
# Sentence after removing stopwords: ['Exports', 'grew', '165', 'percent', '191', 'million', 'liters', '']
# Sentence after removing stopwords: ['', 'The', 'lowering', 'prices', 'us', 'competitors', 'shows', 'real', 'estate', 'market', 'stabilised', 'returned', 'balance', 'apartments', 'acquiring', 'fair', 'price', 'eyes', 'clients', '']
# Sentence after removing stopwords: ['Sales', 'Latin', 'America', 'increased', '42', '', 'EUR', '432mn', '', 'total', '87', 'mn', 'mobile', 'devices', 'sold', 'area', '', 'representing', 'increase', '32', '', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'supply', 'WCDMA', '3GHSPA', 'radio', 'network', '', 'including', 'modular', '', 'high', 'capacity', 'Nokia', 'Flexi', 'WCDMA', 'base', 'station', 'East', 'Java', '', 'Bali', '', 'Sumatra', 'Batam', '']
# Sentence after removing stopwords: ['In', 'first', 'quarter', '2010', '', 'marktomarket', 'result', 'pretax', 'profit', 'EUR', '133', 'million', 'versus', 'loss', 'EUR', '32', 'million', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', '', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'Klabin', 'Tel\x97maco', 'Borba', 'mill', 'Brazilian', 'state', 'Paranè', '']
# Sentence after removing stopwords: ['Our', 'standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'Itella', '']
# Sentence after removing stopwords: ['Finnair', 'PLC', 'carried', 'record', '88', 'million', 'passengers', '2006', '', 'increase', '35', 'percent', 'previous', 'year', '', 'Finnish', 'national', 'carrier', 'reported', 'Tuesday', '']
# Sentence after removing stopwords: ['Earnings', 'per', 'share', 'EPS', 'amounted', 'EUR0', '03', '', 'loss', 'EUR0', '08', '']
# Sentence after removing stopwords: ['Orion', 'Pharma', 'operating', 'profit', 'increased', '425', '', '2004', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Dec', '11', '', '2008', '', 'Finnish', 'construction', 'engineering', 'company', 'Outotec', 'Oyj', '', 'OMX', '', 'OTE1V', '', 'said', 'today', 'EUR', '28', 'million', '', 'USD', '368', '', 'order', 'expand', 'phosphate', 'concentrator', 'Siilinjarvi', 'Norwegian', 'minera']
# Sentence after removing stopwords: ['By', 'cutting', 'number', 'plants', '', 'group', 'trim', 'fixed', 'costs', '']
# Sentence after removing stopwords: ['KESKO', 'FOOD', 'LTD', 'PRESS', 'RELEASE', '04012006', 'AT', '1300', 'Kesko', 'Food', 'Ltd', 'launching', 'major', 'TV', 'campaign', 'recruit', 'many', 'one', 'hundred', 'new', 'Kfood', 'retailers', '']
# Sentence after removing stopwords: ['Estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'margin', 'increased', '112', '', '117', '', '']
# Sentence after removing stopwords: ['Cash', 'flow', 'operations', 'totalled', 'EUR', '74', 'mn', '', 'compared', 'negative', 'EUR', '686', 'mn', 'second', 'quarter', '2008', '']
# Sentence after removing stopwords: ['In', 'addition', '', 'Kone', 'signed', 'twoyear', 'maintenance', 'contract', 'escalators', '']
# Sentence after removing stopwords: ['Finnish', 'elevators', 'escalators', 'maker', 'KONE', 'Corporation', 'said', 'Tuesday', '', '18', 'March', '', 'received', 'major', 'order', 'Sir', 'Robert', 'McAlpine', 'supply', 'elevators', 'escalators', 'Watermark', 'Place', 'project', 'City', 'London', '']
# Sentence after removing stopwords: ['UPMKymmene', 'generated', 'thirtyone', 'consecutive', 'quarters', 'positive', 'EBITDA', '']
# Sentence after removing stopwords: ['Mr', 'Priit', 'Kasak', '', 'Balti', 'Metsamasina', 'owner', '', 'said', 'Rakverebased', 'company', 'wishes', 'increase', 'Valmet', 'market', 'share', '27', '', 'third', 'couple', 'years', '']
# Sentence after removing stopwords: ['Stora', 'Enso', 'thirdquarter', 'pretax', 'profit', 'doubled', 'EUR', '197mn', '']
# Sentence after removing stopwords: ['narrows', 'EUR2', '8', '9mo', '09', '29', 'October', '2009', '', 'Finnish', 'software', 'hardware', 'developer', 'Elektrobit', 'Oyj', 'HEL', '', 'EBG1V', '', 'EB', '', 'said', 'today', 'net', 'loss', 'narrowed', 'EUR2', '8', 'first', 'nine', 'months', '2009', 'EUR35', '6', 'period', 'year', 'ago', '']
# Sentence after removing stopwords: ['Tim', 'Cockroft', 'brings', 'excellent', 'track', 'record', '18', 'years', 'experience', '', 'moreover', '', 'Tim', 'successfully', 'developed', 'Capital', 'Markets', 'operations', 'Kaupthing', 'Singer', '', 'Friedlander', 'involving', 'corporate', 'finance', 'broking', 'focus', 'midmarket', 'companies', '']
# Sentence after removing stopwords: ['The', 'company', 'net', 'profit', 'amounted', 'EE', '555', 'mn', '', '36', '', '2004', '']
# Sentence after removing stopwords: ['VDW', 'combined', 'LXE', 'devices', 'enhances', 'productivity', '', 'enabling', 'workers', 'use', 'single', 'device', 'perform', 'voice', '', 'scanning', 'keyboard', 'functions', '']
# Sentence after removing stopwords: ['The', 'longterm', 'contract', 'global', '']
# Sentence after removing stopwords: ['In', 'Homeware', 'area', '', 'Fiskars', 'provides', 'leading', 'branded', 'products', 'home', '', 'kitchen', '', 'interior', 'design', '']
# Sentence after removing stopwords: ['The', 'loss', 'third', 'quarter', '2007', 'EUR', '03', 'mn', 'smaller', 'loss', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'airline', 'Finnair', 'deal', 'UK', 'public', 'sector', 'official', 'airline', 'flights', 'London', 'Heathrow', 'Osaka', 'Japan', '', 'well', 'flights', 'Manchester', 'UK', 'Helsinki', 'Finland', '']
# Sentence after removing stopwords: ['Finnish', 'Ahlstrom', 'Corporation', 'double', 'investments', 'new', 'specialty', 'glassfiber', 'reinforcement', 'plant', 'South', 'Carolina', '', 'US', '']
# Sentence after removing stopwords: ['Speaking', 'justdrinks', 'today', '', 'spokesperson', 'Olvi', 'said', '', '', 'We', 'performed', 'well', 'four', 'countries', 'operate', '', 'namely', '', 'Finland', '', 'Estonia', '', 'Latvia', 'Lithuania', '', '']
# Sentence after removing stopwords: ['The', 'company', 'strength', 'Apetit', 'brand', '']
# Sentence after removing stopwords: ['Both', 'loans', 'used', 'finance', 'strategic', 'investments', 'shopping', 'center', 'redevelopment', 'projects', 'refinancing', 'maturing', 'debt', '']
# Sentence after removing stopwords: ['In', 'fourth', 'quarter', '2009', '', 'Atria', 'net', 'loss', 'shrank', 'EUR', '12', 'million', 'EUR', '59', 'million', 'net', 'sales', 'contracted', 'EUR', '3404', 'million', 'EUR', '3611', 'million', '']
# Sentence after removing stopwords: ['European', 'traffic', 'grew', 'nearly', '30', '', '']
# Sentence after removing stopwords: ['The', 'CL51', 'designed', 'measure', 'cloud', 'base', 'height', 'vertical', 'visibility', 'weather', 'conditions', '', 'makes', 'ideal', 'instrument', 'meteorological', 'applications', 'rely', 'reliable', 'cloud', 'height', 'detection', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '1034', 'mn', 'EUR', '232', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Nokian', 'Tyres', 'reported', 'fourth', 'quarter', 'pretax', 'profit', '615', 'mln', 'eur', '', '486', 'mln', 'back', 'strong', 'sales', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['Net', 'interest', 'income', 'increased', '45', '', 'EUR', '314', 'mn', 'EUR', '300', 'mn', '2004', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'Nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout', '']
# Sentence after removing stopwords: ['Atria', 'Group', 'leading', 'Scandinavian', 'meat', 'products', 'group', '']
# Sentence after removing stopwords: ['HK', 'Ruokatalo', 'accounts', '50', '', 'poultry', 'sales', 'Finland', '', 'profitability', 'good', 'level', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'property', 'portfolio', 'doubled', 'result', 'Kapiteeli', 'acquisition', 'totalled', 'EUR', '26862', '12597', 'million', '']
# Sentence after removing stopwords: ['Finland', 'Poyry', 'Energy', 'contract', 'advise', 'builders', 'new', 'cogeneration', 'power', 'plant', 'Lithuania', 'secondbiggest', 'city', 'Kaunas', 'supervise', 'construction', 'process', '']
# Sentence after removing stopwords: ['Finnair', 'expands', '', 'Finnair', 'plans', 'add', 'flights', 'routes', 'Hong', 'Kong', '', 'India', 'Russia', '']
# Sentence after removing stopwords: ['One', 'installed', 'elevators', 'doubledeck', 'elevator', '', 'enables', 'efficient', 'use', 'building', 'core', 'space', '']
# Sentence after removing stopwords: ['According', 'company', '', 'operating', 'profit', '', 'excluding', 'nonrecurring', 'items', '', 'fourth', 'quarter', '2009', 'significantly', 'better', 'expected', '', 'also', 'better', 'figures', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', '', 'buy', '', 'recommendation', 'reiterated', '']
# Sentence after removing stopwords: ['Other', 'carriers', 'handset', 'makers', 'spin', 'positive', 'event', 'raise', 'interest', 'higherend', 'phones', 'pricier', 'data', 'plans', '']
# Sentence after removing stopwords: ['The', 'Ministry', 'Water', 'Tanzania', 'awarded', 'Poyry', 'water', 'sanitation', 'engineering', 'assignment', 'rehabilitation', 'extension', 'water', 'supply', 'sanitation', 'infrastructure', 'Bukoba', 'Musoma', '', 'situated', 'Lake', 'Victoria', 'northern', 'Tanzania', '']
# Sentence after removing stopwords: ['Dubbed', 'Nokia', 'Money', 'Solutions', '', 'company', 'officials', 'say', 'initiative', 'would', 'seek', 'bridge', 'gap', 'banked', 'unbanked', 'developing', 'countries', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Eesti', '', 'retailer', 'wholesaler', 'grain', '', 'agricultural', 'warehousing', 'machinery', 'accessories', '', 'net', 'sales', '81', 'million', 'euros', '2007', '', 'increase', 'onetenth', 'preceding', 'year', '']
# Sentence after removing stopwords: ['Most', 'increase', 'net', 'sales', 'due', 'acquisition', 'Swedish', 'Silva', 'produces', 'garden', 'tools', 'boats', '']
# Sentence after removing stopwords: ['UPMKymmene', 'generated', 'seventeen', 'consecutive', 'quarters', 'positive', 'Cash', 'Flow', 'Operations', '']
# Sentence after removing stopwords: ['The', 'company', 'aims', 'maintain', 'trend', 'profitability', 'current', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'Talentum', 'reports', 'operating', 'profit', 'increased', 'EUR', '205', 'mn', '2005', 'EUR', '93', 'mn', '2004', '', 'net', 'sales', 'totaled', 'EUR', '1033', 'mn', '', 'EUR', '964', 'mn', '']
# Sentence after removing stopwords: ['After', 'takeover', '', 'Cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'Latvian', 'market', '']
# Sentence after removing stopwords: ['9', 'September', '2010', '', 'Finnish', 'stationery', 'gift', 'retailer', 'Tiimari', 'HEL', '', 'TII1V', 'said', 'today', 'net', 'sales', 'rose', '2', '', 'yearonyear', 'EUR5', '7', 'August', '2010', '', 'driven', 'growth', 'Finland', '', 'demand', 'Baltics', 'remained', 'weak', '']
# Sentence after removing stopwords: ['The', 'offer', 'represents', 'premium', '24', '', 'stock', 'closing', 'price', 'Friday', '']
# Sentence after removing stopwords: ['Finland', 'national', 'carrier', 'Finnair', 'PLC', 'carried', 'record', '85', 'million', 'passengers', '2005', '', 'increase', '45', 'percent', 'previous', 'year', '', 'airline', 'reported', 'Tuesday', '']
# Sentence after removing stopwords: ['The', 'stock', 'new', 'machines', 'reasonably', 'small', 'new', 'orders', 'bring', 'work', '']
# Sentence after removing stopwords: ['The', 'optimization', 'steel', 'components', 'heating', 'process', 'reduce', 'energy', 'consumption', '']
# Sentence after removing stopwords: ['I', 'looking', 'forward', 'contribute', 'SRV', 'success', 'competence', '', '', 'says', 'Taneli', 'Hassinen', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'insurance', 'company', 'Pohjola', 'Finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', '', 'traffic', 'safety', '']
# Sentence after removing stopwords: ['The', 'Finnish', 'group', 'anticipates', 'sales', 'gain', 'EUR42m', 'tax', 'expenses', '']
# Sentence after removing stopwords: ['We', 'pleased', 'fine', 'cooperation', 'two', 'countries', 'recent', 'times', '', 'said', '']
# Sentence after removing stopwords: ['After', 'transaction', '', 'Alma', 'Media', 'raised', 'stake', 'Talentum', '3065', '', 'shares', '3112', '', 'voting', 'rights', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['Overall', '', '50', 'percent', 'respondents', 'confident', 'security', 'banking', 'online', '']
# Sentence after removing stopwords: ['The', 'agreement', 'signed', 'Biohit', 'Healthcare', 'Ltd', '', 'UKbased', 'subsidiary', 'Biohit', 'Oyj', '', 'Finnish', 'public', 'company', 'develops', '', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'announce', 'support', 'Intel', 'based', 'handheld', 'platforms', '', 'capabilities', 'made', 'development', 'easier', 'faster', '']
# Sentence after removing stopwords: ['Ruukki', 'signed', 'contract', 'Norwegian', 'company', 'Veidekke', 'Entreprenor', 'AS', '']
# Sentence after removing stopwords: ['Compared', 'FTSE', '100', 'index', '', 'rose', '283', 'points', '05', '', 'day', '', 'relative', 'price', 'change', '23', '', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['The', 'EBITDA', 'EUR116m', 'compared', 'EUR115m', '', 'corresponding', 'EBITDA', 'margin', '33', '', '']
# Sentence after removing stopwords: ['For', 'current', 'year', '', 'Raute', 'expects', 'net', 'sales', 'increase', 'operating', 'result', '', 'positive', '']
# Sentence after removing stopwords: ['The', 'company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', '', 'adding', '', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year', '', '']
# Sentence after removing stopwords: ['The', 'company', 'operating', 'income', '', 'EBIT', '', 'totalled', 'EUR', '00', 'mn', '', 'EUR', '03', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'Kalmar', 'received', 'significant', 'order', 'US', 'Department', 'Defense', '']
# Sentence after removing stopwords: ['These', 'moderate', 'significant', 'changes', 'resulted', 'significant', '2432', '', 'reduction', 'estimated', 'CVD', 'risk', '']
# Sentence after removing stopwords: ['', 'The', 'priority', '2009', 'strengthen', 'company', 'balance', 'sheet', 'increase', 'cash', 'flow', '', '', 'CEO', 'Hannu', 'Krook', 'said', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '1019', 'mn', 'EUR', '1007', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['The', 'company', 'consolidated', 'operating', 'profit', 'amounted', 'EUR', '1586', 'mn', '', 'EUR', '414', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Turnover', 'rose', 'EUR21m', 'EUR17m', '']
# Sentence after removing stopwords: ['Diluted', 'EPS', 'rose', 'EUR3', '68', 'EUR0', '50', '']
# Sentence after removing stopwords: ['OriolaKD', 'expects', 'invoicing', '2008', 'higher', 'comparable', 'invoicing', '2007', '']
# Sentence after removing stopwords: ['CEO', 'company', 'Tarmo', 'Noop', 'said', 'growth', 'sale', 'premium', 'beers', 'biggest', '']
# Sentence after removing stopwords: ['Sales', 'climbed', '192', 'pct', '1002', 'bln', 'eur', '', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure', '']
# Sentence after removing stopwords: ['Sales', 'Department', 'Store', 'Division', 'increased', '15', '', 'sales', 'clothing', 'store', 'subsidiary', 'Seppala', 'increased', '8', '', 'Meanwhile', 'sales', 'Hobby', 'Hall', 'decreased', '12', '', '']
# Sentence after removing stopwords: ['The', 'terms', 'financing', 'approved', 'Annual', 'General', 'Meeting', 'Company', 'held', 'June', '30', '', '2010', '']
# Sentence after removing stopwords: ['', 'They', 'would', 'invest', 'physical', 'infrastructure', '', 'would', 'also', 'provide', 'knowhow', 'managing', 'developing', 'science', 'technology', 'parks', '', '', 'said', 'Sunrise', 'Valley', 'director', 'Andrius', 'Bagdonas', '']
# Sentence after removing stopwords: ['The', 'Group', 'aims', 'increase', 'net', 'sales', 'comparable', 'operating', 'profit', '2006', '']
# Sentence after removing stopwords: ['Finnish', 'food', 'company', 'Raisio', 'Oyj', 'HEL', '', 'RAIVV', 'said', 'today', 'buy', 'British', 'snacks', 'confectionery', 'company', 'Big', 'Bear', 'Group', 'plc', 'enterprise', 'value', 'EUR', '953', 'million', 'USD', '1299', '']
# Sentence after removing stopwords: ['The', 'original', 'name', 'Componenta', 'ml', '', 'subsidiary', 'Finnish', 'Componenta', 'Group', '', 'changed', 'ml', 'Components', 'company', 'seen', '63', '', 'growth', 'Q1', '2010', '', 'comparison', 'Q1', '2009', '']
# Sentence after removing stopwords: ['SysOpen', 'Digia', 'Plc', '', 'Press', 'release', '', '7', 'February', '2006', 'IBM', 'Finland', 'rewarded', 'distinguished', 'partner', 'companies', '2005', '']
# Sentence after removing stopwords: ['Under', 'terms', 'offtake', 'agreement', 'Talvivaara', '', 'Cameco', 'provide', 'upfront', 'investment', '', 'maximum', '', '60', 'million', '', 'cover', 'construction', 'cost', 'uranium', 'extraction', 'circuit', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'Kauppalehti', 'group', 'rose', 'EUR', '15', 'mn', 'EUR', '13', 'mn', '', 'Marketplaces', 'EUR', '13', 'mn', 'EUR', '10', 'mn', 'third', 'quarter', '2006', '']
# Sentence after removing stopwords: ['The', 'upgrade', 'intended', 'raise', 'network', 'capacity', '450', 'MHz', '630', 'MHz', 'several', 'cities', '', 'enabling', 'bidirectional', 'services', 'digital', 'television', 'well', 'broadband', 'data', '']
# Sentence after removing stopwords: ['Thus', 'method', 'cut', 'working', 'costs', '', 'fasten', 'planning', 'building', 'processes', '']
# Sentence after removing stopwords: ['Ragutis', '', 'controlled', 'Finnish', 'brewery', '', 'reported', '54percent', 'rise', 'beer', 'sales', '1044', 'million', 'litres', 'held', '1109percent', 'market', 'share', '']
# Sentence after removing stopwords: ['Vaisala', 'also', 'said', 'expects', 'net', 'sales', 'EUR', '2532', 'million', '2010', '', 'compared', 'EUR', '2522', 'million', 'recorded', '2009', '']
# Sentence after removing stopwords: ['Repeats', 'sees', '2008', 'EBITA', '18', 'pct', 'sales', '']
# Sentence after removing stopwords: ['Glaston', '', 'headquartered', 'Tampere', '', 'Finland', '', 'growing', '', 'international', 'glass', 'technology', 'company', '']
# Sentence after removing stopwords: ['The', 'amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'Company', '']
# Sentence after removing stopwords: ['Viking', 'Line', 'head', 'Jan', 'Kaarstroem', 'told', 'TT', 'company', 'ferries', 'well', 'equipped', 'handle', 'ice', 'passengers', 'safe', '']
# Sentence after removing stopwords: ['Diluted', 'loss', 'per', 'share', 'stood', 'EUR', '015', 'versus', 'EUR', '026', '']
# Sentence after removing stopwords: ['The', 'Basware', 'Connectivity', 'services', 'allow', 'companies', 'handle', 'purchase', 'pay', 'processes', 'online', 'make', 'internal', 'processes', 'efficient', '', '', 'said', 'CEO', 'Ilkka', 'Sihvo', '', 'Basware', 'Corporation', '']
# Sentence after removing stopwords: ['Profit', 'period', 'EUR', '156', 'mn', 'compared', 'EUR', '141', 'mn', '2007', '']
# Sentence after removing stopwords: ['', 'We', 'happy', 'working', 'Rapala', 'encourage', 'boaters', 'anglers', 'introduce', 'newcomers', 'sport', '', '', 'said', 'RBFF', 'President', '', 'CEO', 'Frank', 'Peterson', '']
# Sentence after removing stopwords: ['Ruukki', 'delivery', 'volumes', 'selling', 'prices', 'showed', 'favourable', 'development', 'company', 'comparable', 'net', 'sales', 'grew', '50', '', 'yearonyear', 'EUR647m', '', 'CEO', 'Sakari', 'Tamminen', 'said', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'threemonth', 'period', 'increased', 'EUR1', '2', '', 'revenue', 'increased', 'EUR20', '2', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Meanwhile', '', 'ElectrowattEkono', 'Philippines', '', 'Inc', 'also', 'awarded', 'threeyear', 'operation', 'maintenance', '', 'OM', '', 'contract', 'FR', 'Cement', 'Corporation', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'Latin', 'America', '']
# Sentence after removing stopwords: ['Cramo', 'Group', 'financial', 'targets', '20102013', 'sales', 'growth', 'higher', '10', 'percent', 'per', 'year', '', 'return', 'equity', '15', 'percent', '']
# Sentence after removing stopwords: ['Those', 'partially', 'offset', '186', 'mln', 'eur', 'gain', 'sale', 'Celbi', 'pulp', 'plant', 'Portugal', '']
# Sentence after removing stopwords: ['Arvo', 'Vuorenmaa', '', 'Loviisa', 'plant', 'general', 'manager', 'said', 'application', 'new', 'licence', '', 'standard', '', 'procedure', '', 'quite', 'confident', '', 'approval', 'granted', '']
# Sentence after removing stopwords: ['', 'I', 'pleased', 'Bjorn', 'Wahlroos', 'accepted', 'nomination', '']
# Sentence after removing stopwords: ['Finnair', 'able', 'operate', 'leisure', 'flights', 'despite', 'strike', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '052', 'versus', 'EUR', '009', '']
# Sentence after removing stopwords: ['At', 'time', '', 'sales', 'development', 'Russia', 'boosted', 'opening', 'Stockmann', 'Nevsky', 'Centre', 'St', 'Petersburg', '']
# Sentence after removing stopwords: ['Cost', 'savings', 'rise', '20', 'mln', 'eur', 'year', '2007', '', 'OKO', 'said', '']
# Sentence after removing stopwords: ['Known', 'Post', 'Bank', '', 'concept', 'would', 'see', 'Fidelity', 'Bank', 'rolling', '75', 'offices', 'Ghana', 'Post', 'premises', '', 'provide', 'financial', 'services', 'people', '']
# Sentence after removing stopwords: ['The', 'soapstone', 'deposits', 'Medvezhyegorsk', 'area', 'expected', 'increase', 'Tulikivi', 'current', 'reserves', 'considerably', '']
# Sentence after removing stopwords: ['Finnish', 'financial', 'software', 'developer', 'Basware', 'Oyj', 'said', 'today', 'provide', 'invoice', 'automation', '', 'IA', '', 'solution', 'unnamed', 'major', 'retail', 'company', 'USA', 'deal', '', 'worth', 'EUR300', '000', '']
# Sentence after removing stopwords: ['Acquisitions', 'made', 'businesses', 'well', 'integrated', '']
# Sentence after removing stopwords: ['Cargotec', 'Corporation', '', 'Press', 'Release', '', 'April', '28', '', '2008', '200', 'pm', 'Finnish', 'time', 'Cargotec', 'MacGREGOR', 'business', 'area', 'providing', 'marine', 'cargo', 'handling', 'offshore', 'load', 'handling', 'solutions', 'received', 'significant', 'hatch', 'cover', 'orders', 'bulk', 'carriers', '']
# Sentence after removing stopwords: ['The', 'groups', 'turnover', 'full', 'fiscal', 'year', 'expected', 'show', 'slight', 'increase', 'previous', 'fiscal', 'year', '']
# Sentence after removing stopwords: ['Sales', 'rose', '3009', 'mln', 'eur', 'compared', 'last', 'year', '2761', 'mln', 'eur', 'line', '299', 'mln', 'eur', 'consensus', 'figure', '']
# Sentence after removing stopwords: ['', 'We', 'tailored', 'solutions', 'meet', 'Solel', 'technical', 'requirements', '', 'result', 'costeffective', 'manufacturing', 'highestquality', 'reflectors', '', '']
# Sentence after removing stopwords: ['Last', 'month', '', 'Outokumpu', 'sold', '80', 'percent', 'technology', 'unit', '', 'Outokumpu', 'Technology', 'Oyj', '', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Finnish', 'pharmaceuticals', 'company', 'Orion', 'net', 'sales', 'rose', 'EUR', '190mn', 'first', 'quarter', '2009', 'EUR', '180mn', 'first', 'quarter', '2008', '']
# Sentence after removing stopwords: ['Kalmar', 'awarded', 'new', '5year', 'contract', 'supply', 'Rough', 'Terrain', 'Container', 'Handler', 'RTCH', '']
# Sentence after removing stopwords: ['Nokian', 'Capacitors', '', 'equipment', 'used', 'raise', 'capacity', 'reliability', 'Indian', 'grid', '']
# Sentence after removing stopwords: ['Talentum', 'expects', 'net', 'sales', 'core', 'business', 'increase', '2008', '', 'compared', '2007', '']
# Sentence after removing stopwords: ['The', 'move', 'aimed', 'boosting', 'sales', '', 'costefficiency', 'market', 'share', 'Finland', '']
# Sentence after removing stopwords: ['Operating', 'income', 'rose', 'EUR', '6964', 'mn', 'EUR', '6003', 'mn', '2009', '']
# Sentence after removing stopwords: ['Net', 'sales', 'increased', 'EUR655m', 'April', 'June', '2010', 'EUR438m', 'year', 'earlier', '']
# Sentence after removing stopwords: ['The', 'company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'EUR', '671', 'million', '']
# Sentence after removing stopwords: ['Wartsila', 'contract', 'October', '2007', 'plant', 'installed', 'Manturovo', 'Kostroma', 'region', 'Russia', '', '600', 'km', 'northeast', 'Moscow', '', 'Russia', '']
# Sentence after removing stopwords: ['Jarmo', 'Honkamaa', '', 'head', 'oil', 'refining', 'business', 'Neste', 'Oil', '', 'says', 'situation', 'looks', 'promising', 'viewpoint', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'saw', 'net', 'profit', 'jump', 'EUR2', '1', 'last', 'quarter', '2010', 'EUR995', '000', 'period', '2009', '']
# Sentence after removing stopwords: ['Profit', 'taxes', 'EUR', '01', 'mn', '', 'compared', 'EUR', '04', 'mn', 'previous', 'year', '']
# Sentence after removing stopwords: ['When', 'situation', 'normalises', '', 'company', 'able', 'increase', 'amount', 'residential', 'units', 'sale', 'St', 'Petersburg', 'Moscow', '', 'particular', '']
# Sentence after removing stopwords: ['According', 'SeppÆnen', '', 'new', 'technology', 'UMTS900', 'solution', 'network', 'building', 'costs', 'onethird', 'lower', 'building', '35', 'G', 'networks', '', 'operating', '2100', 'MHz', 'frequency', '']
# Sentence after removing stopwords: ['Uponor', 'made', 'operating', 'profit', 'EUR', '1510', 'mn', '', 'EUR', '1437', 'mn', '', 'made', '2007', 'record', 'year', '']
# Sentence after removing stopwords: ['UPMKymmene', 'working', 'closely', 'shipping', 'agents', 'reduce', 'fuel', 'consumption', 'greenhouse', 'gas', 'emissions', '']
# Sentence after removing stopwords: ['', 'Our', 'strategic', 'cooperation', 'Rentakran', 'brings', 'us', 'new', 'customers', 'alreadyworking', 'relationships', 'authorities', 'new', 'territories', '', '', 'said', 'Jarmo', 'Laasanen', '', 'senior', 'manager', 'Cramo', '']
# Sentence after removing stopwords: ['To', 'prove', 'efficiency', 'China', 'Mobile', 'system', '', 'Rod', 'Baber', '', 'English', 'climber', '', 'climbed', 'Mount', 'Everest', 'summit', 'successfully', 'made', 'calls', '']
# Sentence after removing stopwords: ['Biohit', 'already', 'services', 'many', 'current', 'Genesis', 'customers', 'customer', 'base', 'expected', 'expand', 'result', 'agreement', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '029', 'EUR', '005', '']
# Sentence after removing stopwords: ['We', 'proud', 'able', 'use', 'kind', 'innovative', 'mobile', 'service', 'voting', 'elections', '']
# Sentence after removing stopwords: ['Marimekko', 'Group', 'fullyear', 'net', 'sales', 'estimated', 'increase', '10', '', '']
# Sentence after removing stopwords: ['Componenta', 'objective', 'agreement', 'increase', 'business', 'existing', 'production', 'lines', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Shares', 'closed', 'higher', '', 'led', 'Nokia', 'announced', 'plans', 'team', 'Sanyo', 'manufacture', '3G', 'handsets', '', 'Nokian', 'Tyres', 'fourthquarter', 'earnings', 'report', 'beat', 'analysts', '', 'expectations', '', 'dealers', 'said', '']
# Sentence after removing stopwords: ['Construction', 'volumes', 'meanwhile', 'grow', 'rate', '1015', 'percent', 'annually', '']
# Sentence after removing stopwords: ['Finnish', 'Suominen', 'Corporation', 'specialises', 'wet', 'wipes', '', 'nonwovens', '', 'flexible', 'packaging', 'reports', 'net', 'sales', 'EUR', '441', 'mn', 'second', 'quarter', '2010', '', 'EUR', '433', 'mn', 'second', 'quarter', '2009', '']
# Sentence after removing stopwords: ['', 'The', 'additional', 'flight', 'linking', 'Mumbai', 'Helsinki', 'dictated', 'strong', 'traffic', 'demand', 'Asia', 'Europe', '']
# Sentence after removing stopwords: ['STORA', 'ENSO', '', 'NORSKE', 'SKOG', '', 'MREAL', '', 'UPMKYMMENE', 'Credit', 'Suisse', 'First', 'Boston', '', 'CFSB', '', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'Nordic', 'forestry', 'groups', '']
# ...
# Sentence after removing stopwords: ['Calls', 'switchboard', 'directory', 'services', 'decreased', 'significantly', 'since', 'employees', 'uptodate', 'contact', 'information', 'colleagues', 'customers', 'phone', 'place', 'call', 'directly', '']
# Sentence after removing stopwords: ['Also', '', 'Westpac', 'issue', 'benchmark', '', '18', 'month', 'FRN', 'deal', 'Euros', '']
# Sentence after removing stopwords: ['Sales', 'local', 'currencies', 'decreased', '05', 'percent', 'number', 'subscribers', 'rose', '127', 'million', 'total', '1476', 'million', 'end', 'fourth', 'quarter', '', 'company', 'said', '']
# Sentence after removing stopwords: ['BG', 'Crane', 'strong', 'customer', 'base', 'onroad', 'load', 'handling', 'related', 'installation', 'service', 'businesses', '']
# Sentence after removing stopwords: ['Why', 'subscribe', 'magazine', '']
# Sentence after removing stopwords: ['Atria', 'chose', 'DeLight', 'attract', 'consumers', '2545', 'age', 'group', 'Atria', 'Fresh', 'range', 'microwaveable', 'meals', '']
# Sentence after removing stopwords: ['The', 'largest', 'construction', 'company', 'Finland', '', 'YIT', 'Corporation', '', 'acquire', '70', '', 'shares', 'Slovak', 'construction', 'company', 'Reding', 'Bratislava', '']
# Sentence after removing stopwords: ['The', 'final', 'price', 'specified', '14', 'May', '2010', '', 'acquiring', 'company', 'said', '']
# Sentence after removing stopwords: ['Previously', '', 'Grimaldi', 'held', '4643', 'pct', 'stake', 'Finnish', 'company', 'following', 'takeover', 'bid', 'launched', 'November', '2006', '']
# Sentence after removing stopwords: ['The', 'figure', 'includes', 'change', 'fair', 'value', 'property', 'portfolio', '', 'EUR', '262', 'million', '']
# Sentence after removing stopwords: ['Nokia', 'OYJ', 'production', 'site', 'Bochum', '', 'Germany', '', 'posted', 'profit', 'interest', '134', 'mln', 'eur', '2007', '', 'Capital', 'reported', 'excerpt', 'article', 'released', 'tomorrow', '', 'citing', 'internal', 'documents', '']
# Sentence after removing stopwords: ['The', 'construction', 'project', 'scheduled', 'start', 'second', 'quarter', '2009', 'new', 'building', 'scheduled', 'place', 'end', '2010', '']
# Sentence after removing stopwords: ['The', 'Nokia', 'Music', 'Store', 'begins', 'trading', 'Tuesday', '', 'selling', 'singles', 'albums', 'well', 'live', 'music', 'streaming', '']
# Sentence after removing stopwords: ['BAWAG', '', 'Is', 'issue', 'benchmark', '', 'covered', 'deal', '']
# Sentence after removing stopwords: ['The', 'third', 'quarter', 'result', 'also', 'includes', '400000', 'euro', '', '', '575000', '', 'provision', 'downsizing', 'lure', 'manufacturing', 'Ireland', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'quarter', 'AprilJune', '2006', 'amounted', 'EUR182', '2', 'sales', 'EUR3', '62', 'bn', '']
# Sentence after removing stopwords: ['Thus', 'group', 'balance', 'sheet', 'EUR25', '8', 'goodwill', '', 'company', 'added', '']
# Sentence after removing stopwords: ['Delivery', 'due', 'second', 'half', '2011', '']
# Sentence after removing stopwords: ['Philips', 'available', 'comment', 'report', '']
# Sentence after removing stopwords: ['Thus', 'group', 'balance', 'sheet', 'EUR', '258', 'million', 'goodwill', '', 'company', 'added', '']
# Sentence after removing stopwords: ['According', 'HK', 'Ruokatalo', '', 'almost', 'meat', 'used', 'company', 'comes', 'Finland', '']
# Sentence after removing stopwords: ['The', 'devices', 'would', 'launched', 'Chinese', 'market', 'late', '2006', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'bank', 'leasing', 'arm', 'Nordea', 'Liising', 'ended', 'year', 'profit', '44', 'million', 'euros', '']
# Sentence after removing stopwords: ['We', 'went', 'market', 'yield', 'guidance', '725', '', 'area', '', 'gave', 'us', 'flexibility', 'go', '18th', '']
# Sentence after removing stopwords: ['When', 'investment', 'place', '', 'Atria', 'plans', 'expand', 'Moscow', 'market', '']
# Sentence after removing stopwords: ['Via', 'plant', '', 'Belgian', 'company', 'feed', '84', 'MW', 'electricity', 'distribution', 'grid', 'able', 'deliver', '14', 'MW', 'heat', '']
# Sentence after removing stopwords: ['The', 'ECB', 'mainly', 'target', 'inflation', '']
# Sentence after removing stopwords: ['A', 'merger', 'UPM', 'FinnishSwedish', 'Stora', 'Enso', 'likely', 'either', '']
# Sentence after removing stopwords: ['The', 'amendment', 'incur', 'additional', 'costs', '']
# Sentence after removing stopwords: ['Tyrvaan', 'Sanomat', '', 'published', 'twice', 'week', 'Tyrvaan', 'Sanomat', 'Oy', '', 'appears', 'Sastamala', 'Kiikoinen', '']
# Sentence after removing stopwords: ['Aldata', 'Share', 'Space', 'Optimization', 'Vision', 'Apollo', 'User', 'Group', '2009', 'Category', 'Management', 'Association', 'Conferences', '', 'Company', 'Will', 'Unveil', 'New', 'Solution', 'Combines', 'Business', 'Intelligence', 'Space', 'Planning', 'Data', 'Conferences']
# Sentence after removing stopwords: ['Meanwhile', '', 'Alfa', 'owns', '251', '', 'MegaFon', 'Altimo', '', '499', '', 'Turkcell', 'via', '185', '', 'stake', 'Cukurova', 'Holding', '']
# Sentence after removing stopwords: ['business', 'sectors', 'building', 'construction', '', 'infrastructure', 'construction', 'technical', 'building', 'services', '']
# Sentence after removing stopwords: ['The', 'company', 'says', 'difficult', 'estimate', 'market', 'situation', 'whole', 'year', '2009', '']
# Sentence after removing stopwords: ['JuhaPekka', 'Weckstr¦m', 'appointed', 'President', 'telecom', 'group', 'TeliaSonera', 'Finland', 'succeed', 'Esa', 'Rautalinko', '']
# Sentence after removing stopwords: ['The', 'technology', 'become', 'available', 'businesses', 'fourth', 'quarter', '', 'Nokia', 'said', '']
# Sentence after removing stopwords: ['The', 'reductions', 'implemented', 'mainly', 'course', 'first', 'half', '2009', '']
# Sentence after removing stopwords: ['KONE', '', 'headquartered', 'Espoo', '', 'Finland', '', 'one', 'world', 'leading', 'elevator', 'escalator', 'companies', '']
# Sentence after removing stopwords: ['Combined', 'Basware', 'Enterprise', 'Purchase', 'Pay', 'portfolio', '', 'provides', 'high', 'level', 'automation', 'procurement', 'invoice', 'workflows', '']
# Sentence after removing stopwords: ['The', 'firm', 'builds', 'components', 'mobile', 'phones', 'communications', 'products', '']
# Sentence after removing stopwords: ['In', 'Baltic', 'countries', '', 'Atria', 'target', 'organic', 'growth', '']
# Sentence after removing stopwords: ['The', 'broker', 'started', 'UPMKymmene', '', 'Stora', 'Enso', 'Sappi', '', 'equalweight', '', 'recommendations', 'Holmen', 'Norske', 'Skog', '', 'underweight', '', 'ratings', '']
# Sentence after removing stopwords: ['The', 'EUR', '07', 'million', 'nonrecurring', 'expenses', 'recorded', 'third', 'quarter', '']
# Sentence after removing stopwords: ['The', 'Court', 'decision', 'also', 'promote', 'genuine', 'competition', 'services']
# Sentence after removing stopwords: ['The', 'guidance', 'set', '90', 'basis', 'points', 'midswaps', '', 'report', 'said', '']
# Sentence after removing stopwords: ['The', 'company', 'supports', 'global', 'customers', 'developing', 'new', 'technologies', 'offers', 'fast', 'route', 'product', 'development', 'applications', 'volume', 'production', '']
# Sentence after removing stopwords: ['Therefore', '', 'Phase', 'III', 'research', 'conducted', 'Abbott', '']
# Sentence after removing stopwords: ['Liquid', 'handling', 'products', 'include', 'electronic', 'mechanical', 'pipettes', '', 'disposable', 'tips', 'well', 'pipette', 'maintenance', 'calibration', 'services', 'research', 'institutions', '', 'healthcare', 'industrial', 'laboratories', '']
# Sentence after removing stopwords: ['It', '', 'fingerfriendly', '', '', 'opinion', '', 'really', 'fast', '']
# Sentence after removing stopwords: ['We', 'look', 'forward', 'take', 'part', 'future', 'development', 'company', '', '', 'says', 'Tomas', 'Billing', '', 'President', 'Nordstjernan', '']
# Sentence after removing stopwords: ['BasWare', 'headquartered', 'Espoo', '', 'Finland', '']
# Sentence after removing stopwords: ['The', 'new', 'chain', '700', 'discount', 'stores', '250', 'supermarkets', '']
# Sentence after removing stopwords: ['Its', 'total', 'annual', 'revenue', 'comes', '160', 'mln', 'zloty', '', '', '569', 'mln42', '3', 'mln', 'euro', '', '']
# Sentence after removing stopwords: ['The', 'building', 'complex', 'consists', 'highquality', 'office', 'retail', 'space', 'totalling', '49200', 'square', 'metres', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Our', 'key', 'geographical', 'markets', 'Europe', '', 'Russian', 'Federation', '', 'MiddleEast', '', 'SouthAfrica', 'Japan', '']
# Sentence after removing stopwords: ['OMEO', '', 'wwwomeose', '', 'employs', '55', 'expects', 'net', 'sales', '23', 'mln', 'euro', '', '', '298', 'mln', '', 'fiscal', '20062007', '', 'ending', 'April', '30', '', '2007', '']
# Sentence after removing stopwords: ['Unit', 'prices', 'straddle', 'carriers', 'vary', 'EUR700', '000', 'EUR900', '000', '', 'company', 'added', '']
# Sentence after removing stopwords: ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '82', 'mn', '']
# Sentence after removing stopwords: ['The', 'company', 'continuous', 'need', 'alloys', 'nickel', '', 'ferrochrome', '', 'molybdenum', 'manganese', 'production', '', 'said', 'Talvivaara', '']
# Sentence after removing stopwords: ['MILAN', '', 'AFX', '', '', 'The', 'Italian', 'shipping', 'group', 'Grimaldi', 'increased', 'stake', 'Finnish', 'company', 'Finnlines', '354', 'pct', '305', 'pct', 'held', 'June', '', 'according', 'news', 'agency', 'ANSA', '']
# Sentence after removing stopwords: ['In', 'end', '', 'Sanoma', 'News', 'wants', 'secure', 'foundation', 'savings', '']
# Sentence after removing stopwords: ['The', 'closing', 'transaction', 'took', 'place', 'today', '']
# Sentence after removing stopwords: ['', 'BG', 'Crane', 'strong', 'partner', 'Hiab', 'Australia', 'many', 'years', '']
# Sentence after removing stopwords: ['The', 'transaction', '', 'includes', 'US', '15', 'billion', 'euro1', 'billion', 'cash', '', 'vendor', 'notes', 'share', 'purchases', '', 'expected', 'completed', 'first', 'quarter', '2008', '', 'FinnishSwedish', 'paper', 'maker', 'said', '']
# Sentence after removing stopwords: ['The', 'continued', 'operations', 'mean', 'structure', 'restructuring', 'Aspocomp', 'group', 'including', 'Aspocomp', 'Oulu', 'headquarter', 'operations', '']
# Sentence after removing stopwords: ['The', 'company', 'earlier', 'said', 'considering', 'different', 'strategic', 'options', 'struggling', 'lowcost', 'mobile', 'operator', '', 'including', 'divestment', 'holding', '']
# Sentence after removing stopwords: ['In', 'Finland', '', 'Martela', 'offers', 'comprehensive', 'service', 'cover', 'entire', 'process', 'change', 'initial', 'inventory', 'design', 'removal', 'maintenance', '']
# Sentence after removing stopwords: ['One', 'also', 'apply', 'jobs', 'directly', 'iPad', '', 'select', 'CV', 'attach', 'covering', 'letter', 'appropriate', 'position', '']
# Sentence after removing stopwords: ['These', 'sections', 'put', 'place', 'form', 'loadbearing', 'steel', 'structure', 'bridge', '', '', 'says', 'Sami', 'Eronen', '', 'Senior', 'Vice', 'President', '', 'Infrastructure', 'Northern', 'Europe', '', 'Ruukki', 'Construction', '']
# Sentence after removing stopwords: ['Cohen', '', 'Steers', '', 'Inc', '', '5', '534', '626', 'shares', 'representing', '4985', '', 'share', 'capital', 'voting', 'rights', '']
# Sentence after removing stopwords: ['The', 'podcast', '', 'sees', 'Harple', 'provide', 'lowdown', 'GyPSii', 'platform', '', 'takes', 'someone', 'location', 'demographic', 'information', 'produce', 'contextual', 'index', 'world', 'around', '']
# Sentence after removing stopwords: ['compensation', 'news', '', 'opinions', 'distributions', '']
# Sentence after removing stopwords: ['One', 'even', 'receive', 'spot', 'alerts', 'soon', 'jobs', 'posted', '', 'putting', 'front', 'queue', 'opportunities', '']
# Sentence after removing stopwords: ['According', 'report', '', 'Elisa', 'DNA', 'joint', 'market', 'share', 'Finland', 'telecom', 'market', '59', '', '']
# Sentence after removing stopwords: ['Pharmaceutical', 'market', 'Italy', 'Global', 'Research', '', 'Data', 'Services', 'published', 'recently', 'market', 'analysis', 'pharmaceutical', 'markets', 'Italy', '']
# Sentence after removing stopwords: ['The', 'commission', 'found', 'evidence', 'several', 'meetings', 'discuss', 'cartel', '', 'including', 'one', 'Brussels', 'restaurant', 'November', '1997', 'companies', 'discussed', 'price', 'increases', '']
# Sentence after removing stopwords: ['We', 'also', 'pleased', 'welcome', 'new', 'employees', 'Tieto', '', '']
# Sentence after removing stopwords: ['The', 'business', 'idea', 'Budget', 'Sport', 'offer', 'customers', 'wide', 'range', 'highquality', 'sports', 'equipment', 'clothing', 'low', 'prices', '', 'company', 'said', '']
# Sentence after removing stopwords: ['POYRY', 'PLCCompany', 'Announcement', '10', 'December', '2010', '410', 'pm', 'Pursuant', 'Poyry', 'PLC', 'stock', 'option', 'program', '2004', '', '63', '792', 'new', 'shares', 'company', 'subscribed', 'since', '27', 'October', '2010', 'stock', 'options', '2004B', '']
# Sentence after removing stopwords: ['Anttila', 'online', 'department', 'store', '', 'NetAnttila', '', 'established', 'position', 'bestknown', '', 'visited', 'shopped', 'online', 'store', 'Finland', '', '']
# Sentence after removing stopwords: ['The', 'Annual', 'Report', 'contains', 'financial', 'statements', '', 'consolidated', 'financial', 'statements', '', 'report', 'Board', 'Directors', 'auditor', 'report', '']
# Sentence after removing stopwords: ['The', 'Group', 'consolidated', 'net', 'sales', '2008', 'totaled', '34', 'billion', 'euros', 'employs', 'approximately', '13000', 'persons', '']
# Sentence after removing stopwords: ['The', 'StoneGate', 'product', 'centrally', 'manageable', 'suited', 'physical', 'virtual', 'environments', '']
# Sentence after removing stopwords: ['The', 'handset', 'maker', 'disclose', 'financial', 'details', '']
# Sentence after removing stopwords: ['Local', 'government', 'commissioner', 'ml', '', 'Kurt', 'Svensson', '', 'says', 'contact', 'management', 'Finnish', 'company', 'Componenta', 'find', 'alternatives', 'company', 'decision', 'close', 'plant', 'ml', '']
# Sentence after removing stopwords: ['As', 'consequence', 'Works', 'Council', 'withdrawn', 'petition', 'suspend', 'reorganisation', '']
# Sentence after removing stopwords: ['Finnish', 'investment', 'group', 'Neomarkka', 'Oyj', '', 'HEL', '', 'NEMBV', '', 'said', 'today', 'buy', 'former', 'production', 'facilities', 'Kuitu', 'Finland', 'Ltd', '', 'part', 'negotiations', 'option', 'invest', 'specialty', 'cellulose', 'fiber', 'business', '']
# Sentence after removing stopwords: ['Ulefos', 'Group', 'leading', 'supplier', 'manhole', 'covers', 'Nordic', 'countries', '']
# Sentence after removing stopwords: ['Okmetic', 'global', 'customer', 'base', 'sales', 'network', '', 'production', 'plants', 'Finland', 'US', 'contract', 'manufacturers', 'Japan', 'China', '']
# Sentence after removing stopwords: ['OPPohjola', 'Group', 'capital', 'adequacy', 'ratio', 'Act', 'Credit', 'Institutions', 'stood', '121', '', 'Tier', '1', 'ratio', '121', '', '']
# Sentence after removing stopwords: ['Entire', 'paper', 'mills', 'may', 'set', '', 'especially', 'new', 'EU', 'member', 'states', '']
# Sentence after removing stopwords: ['These', 'companies', '20000', 'sq', 'office', 'commercial', 'building', 'substantial', 'amount', 'building', 'right', 'new', 'shopping', 'center', 'Liljeholmen', '', 'Stockholm', '']
# Sentence after removing stopwords: ['For', 'fiscal', 'year', 'ending', 'September', '30', '', '2009', 'revenue', 'customers', '', '10012', 'million', 'around', '110', '', 'transportation', 'group', 'revenue', '']
# Sentence after removing stopwords: ['The', 'veneer', 'plywood', 'industry', 'Sweden', 'quite', 'small', 'despite', 'raw', 'material', 'resources', '']

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive3=pd.DataFrame(sorted(positiveValues3.items(),key=lambda x:x[1],reverse=True))
df_negative3=pd.DataFrame(sorted(negativeValues3.items(),key=lambda x:x[1],reverse=True))
df_neutral3=pd.DataFrame(sorted(neutralValues3.items(),key=lambda x:x[1],reverse=True))

# %%
pd1tri=df_positive3[0][:10]
pd2tri=df_positive3[1][:10]

ned1tri=df_negative3[0][:10]
ned2tri=df_negative3[1][:10]

nud1tri=df_neutral3[0][:10]
nud2tri=df_neutral3[1][:10]

plt.figure(1,figsize=(16,4))

plt.bar(pd1tri,pd2tri, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-TRIGRAM ANALYSIS")

plt.savefig("positive-trigram.png")
plt.show()

# %%
df_positive3.head(10)
# Out:
#                          0   1
# 0                mln euro   22
# 1                  mn  EUR  16
# 2                net sales  14
# 3  mn corresponding period  14
# 4                   euro    12
# 5                     HEL   12
# 6               said today  12
# 7                 Oyj HEL   12
# 8            year earlier   12
# 9        first nine months  12

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1tri,ned2tri, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-TRIGRAM ANALYSIS")

plt.savefig("negative-trigram.png")
plt.show()

# %%
df_negative3.head(10)
# Out:
#                          0   1
# 0                  mn  EUR  19
# 1                mln euro   17
# 2  mn corresponding period  14
# 3            year earlier   13
# 4                   euro    12
# 5             mn  compared  12
# 6                 Oyj HEL    9
# 7             period 2008    9
# 8         mn third quarter   9
# 9                    2009    8

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1tri,nud2tri, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-TRIGRAM ANALYSIS")

plt.savefig("neutral-trigram.png")
plt.show()

# %%
df_neutral3.head(10)
# Out:
#                 0   1
# 0        Finland   35
# 1       mln euro   21
# 2            HEL   17
# 3        Oyj  HEL  13
# 4    company said  13
# 5          euro    13
# 6  ALEXANDRIA  Va  12
# 7             Va   12
# 8   OMX Helsinki   11
# 9   company said   11

# %% [markdown]
# **Using CountVectorizer()**
#
# -can also b used to check the most common bigrams
